# %% [markdown]
# # Data Collection

# %% [markdown]
# ### Obtain and Clean the Data

# %% [markdown]
# kaggle datatsets:
# - https://www.kaggle.com/datasets/zynicide/nfl-football-player-stats?select=games_1512362753.8735218.json
# - https://www.kaggle.com/datasets/kendallgillies/nflstatistics
# - https://www.kaggle.com/datasets/tobycrabtree/nfl-scores-and-betting-data?select=spreadspoke_scores.csv  !!!
# - https://www.kaggle.com/datasets/grayengineering425/nfl-box-scores  !!!
# - https://www.kaggle.com/datasets/shanyachaubey/nfl20102021offdefplayoffteamstats  !!!
#
# kaggle notebook:
# - https://www.kaggle.com/code/sanjayv007/nfl-big-data-bowl-beginner-s-complete-eda#Data-Cleaning
# - https://www.kaggle.com/code/zwartfreak/nfl-games-players-analysis-and-visualization#Data-visualization
#
# scrape:
# - pro-football-reference.com

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### NFL 2010 to 2022 Stats Kaggle Dataset

# %%
nfl_game_data = pd.read_csv('data/NFL_data.csv')
nfl_game_data.head()
# Out:
#                    Team  WinLoss perc   PD  Year  FGM  FG_perc  RedZone_perc  \
# 0  New England Patriots          87.5  205  2010   22     88.0          62.7
# 1         New York Jets          68.8   63  2010   30     76.9          40.0
# 2        Miami Dolphins          43.8  -60  2010   30     73.2          52.9
# 3         Buffalo Bills          25.0 -142  2010   16     76.2          51.4
# 4   Pittsburgh Steelers          75.0  143  2010   29     78.4          48.0
#
#    playoff_win_perc  Score_perc  Turnover_perc  RushYperG  PassYperG  \
# 0             87.50        47.0            5.4      123.3      240.4
# 1             68.75        32.2           10.6      148.4      203.2
# 2              0.00        29.7           15.7      102.7      220.4
# 3              0.00        25.3           19.2      107.5      197.8
# 4             75.00        36.9            9.5      120.2      225.0
#
#    PointperG  possperG  YallowedperG  PointallowedperG  perc_punt_20 Result
# 0       32.4  0.490000         366.9              19.6          30.6   Loss
# 1       22.9  0.543611         291.4              19.0          45.5   Loss
# 2       17.1  0.514722         309.3              20.8          42.5   Loss
# 3       17.7  0.476389         361.6              26.6          22.7   Loss
# 4       23.4  0.540000         276.8              14.5          31.6   Loss

# %%
# drop columns that are not needed
nfl_game_data.drop(columns=['playoff_win_perc', 'Score_perc', 'Turnover_perc', 'perc_punt_20', 'Result'], inplace=True)

# %%
nfl_game_data.head()
# Out:
#                    Team  WinLoss perc   PD  Year  FGM  FG_perc  RedZone_perc  \
# 0  New England Patriots          87.5  205  2010   22     88.0          62.7
# 1         New York Jets          68.8   63  2010   30     76.9          40.0
# 2        Miami Dolphins          43.8  -60  2010   30     73.2          52.9
# 3         Buffalo Bills          25.0 -142  2010   16     76.2          51.4
# 4   Pittsburgh Steelers          75.0  143  2010   29     78.4          48.0
#
#    RushYperG  PassYperG  PointperG  possperG  YallowedperG  PointallowedperG
# 0      123.3      240.4       32.4  0.490000         366.9              19.6
# 1      148.4      203.2       22.9  0.543611         291.4              19.0
# 2      102.7      220.4       17.1  0.514722         309.3              20.8
# 3      107.5      197.8       17.7  0.476389         361.6              26.6
# 4      120.2      225.0       23.4  0.540000         276.8              14.5

# %%
nfl_game_data.isna().sum()
# Out:
# Team                0
# WinLoss perc        0
# PD                  0
# Year                0
# FGM                 0
# FG_perc             0
# RedZone_perc        0
# RushYperG           0
# PassYperG           0
# PointperG           0
# possperG            0
# YallowedperG        0
# PointallowedperG    0
# dtype: int64

# %%
nfl_game_data['Year'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021])

# %%
nfl_game_data.to_csv('cleaned-data/nfl_team_stats_2010_2021.csv')

# %% [markdown]
# ### NFL Scores and Betting Data Kaggle Dataset

# %% [markdown]
# #### NFL Game Data from 2010 to 2023 CSV

# %%
nfl_scores = pd.read_csv('data/spreadspoke_scores.csv')
nfl_scores.head()
# Out:
#   schedule_date  schedule_season schedule_week  schedule_playoff  \
# 0      9/2/1966             1966             1             False
# 1      9/3/1966             1966             1             False
# 2      9/4/1966             1966             1             False
# 3      9/9/1966             1966             2             False
# 4     9/10/1966             1966             1             False
#
#             team_home  score_home  score_away        team_away  \
# 0      Miami Dolphins        14.0        23.0  Oakland Raiders
# 1      Houston Oilers        45.0         7.0   Denver Broncos
# 2  San Diego Chargers        27.0         7.0    Buffalo Bills
# 3      Miami Dolphins        14.0        19.0    New York Jets
# 4   Green Bay Packers        24.0         3.0  Baltimore Colts
#
#   team_favorite_id  spread_favorite over_under_line         stadium  \
# 0              NaN              NaN             NaN     Orange Bowl
# 1              NaN              NaN             NaN    Rice Stadium
# 2              NaN              NaN             NaN  Balboa Stadium
# 3              NaN              NaN             NaN     Orange Bowl
# 4              NaN              NaN             NaN   Lambeau Field
#
#    stadium_neutral  weather_temperature  weather_wind_mph  weather_humidity  \
# 0            False                 83.0               6.0              71.0
# 1            False                 81.0               7.0              70.0
# 2            False                 70.0               7.0              82.0
# 3            False                 82.0              11.0              78.0
# 4            False                 64.0               8.0              62.0
#
#   weather_detail
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
nfl_scores.columns
# Out:
# Index(['schedule_date', 'schedule_season', 'schedule_week', 'schedule_playoff',
#        'team_home', 'score_home', 'score_away', 'team_away',
#        'team_favorite_id', 'spread_favorite', 'over_under_line', 'stadium',
#        'stadium_neutral', 'weather_temperature', 'weather_wind_mph',
#        'weather_humidity', 'weather_detail'],
#       dtype='object')

# %%
# drop columns that are not needed
nfl_scores.drop(columns=['schedule_playoff', 'over_under_line', 'stadium_neutral', 'weather_humidity', 'weather_detail'], inplace=True)
nfl_scores.head()
# Out:
#   schedule_date  schedule_season schedule_week           team_home  \
# 0      9/2/1966             1966             1      Miami Dolphins
# 1      9/3/1966             1966             1      Houston Oilers
# 2      9/4/1966             1966             1  San Diego Chargers
# 3      9/9/1966             1966             2      Miami Dolphins
# 4     9/10/1966             1966             1   Green Bay Packers
#
#    score_home  score_away        team_away team_favorite_id  spread_favorite  \
# 0        14.0        23.0  Oakland Raiders              NaN              NaN
# 1        45.0         7.0   Denver Broncos              NaN              NaN
# 2        27.0         7.0    Buffalo Bills              NaN              NaN
# 3        14.0        19.0    New York Jets              NaN              NaN
# 4        24.0         3.0  Baltimore Colts              NaN              NaN
#
#           stadium  weather_temperature  weather_wind_mph
# 0     Orange Bowl                 83.0               6.0
# 1    Rice Stadium                 81.0               7.0
# 2  Balboa Stadium                 70.0               7.0
# 3     Orange Bowl                 82.0              11.0
# 4   Lambeau Field                 64.0               8.0

# %%
# get rid of the years before 2010
nfl_scores = nfl_scores[nfl_scores['schedule_season'] >= 2010]
nfl_scores.head()
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 10008      9/9/2010             2010             1    New Orleans Saints
# 10009     9/12/2010             2010             1         Buffalo Bills
# 10010     9/12/2010             2010             1         Chicago Bears
# 10011     9/12/2010             2010             1        Houston Texans
# 10012     9/12/2010             2010             1  Jacksonville Jaguars
#
#        score_home  score_away           team_away team_favorite_id  \
# 10008        14.0         9.0   Minnesota Vikings               NO
# 10009        10.0        15.0      Miami Dolphins              MIA
# 10010        19.0        14.0       Detroit Lions              CHI
# 10011        34.0        24.0  Indianapolis Colts              IND
# 10012        24.0        17.0      Denver Broncos              JAX
#
#        spread_favorite               stadium  weather_temperature  \
# 10008             -5.0   Louisiana Superdome                 72.0
# 10009             -3.0  Ralph Wilson Stadium                 64.0
# 10010             -6.5         Soldier Field                 75.0
# 10011             -1.0       Reliant Stadium                 89.0
# 10012             -3.0        EverBank Field                 91.0
#
#        weather_wind_mph
# 10008               0.0
# 10009               7.0
# 10010               1.0
# 10011               5.0
# 10012               1.0

# %%
nfl_scores['schedule_season'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020,
#        2021, 2022, 2023])

# %%
# get rid of rows where score is na
nfl_scores = nfl_scores[nfl_scores['score_home'].notna() & nfl_scores['score_away'].notna()]

# %%
nfl_scores.isna().sum()
# Out:
# schedule_date            0
# schedule_season          0
# schedule_week            0
# team_home                0
# score_home               0
# score_away               0
# team_away                0
# team_favorite_id         0
# spread_favorite          0
# stadium                  0
# weather_temperature    765
# weather_wind_mph       766
# dtype: int64

# %%
# change date to datetime object
nfl_scores['schedule_date'] = pd.to_datetime(nfl_scores['schedule_date'])
nfl_scores.head()
# Out:
#       schedule_date  schedule_season schedule_week             team_home  \
# 10008    2010-09-09             2010             1    New Orleans Saints
# 10009    2010-09-12             2010             1         Buffalo Bills
# 10010    2010-09-12             2010             1         Chicago Bears
# 10011    2010-09-12             2010             1        Houston Texans
# 10012    2010-09-12             2010             1  Jacksonville Jaguars
#
#        score_home  score_away           team_away team_favorite_id  \
# 10008        14.0         9.0   Minnesota Vikings               NO
# 10009        10.0        15.0      Miami Dolphins              MIA
# 10010        19.0        14.0       Detroit Lions              CHI
# 10011        34.0        24.0  Indianapolis Colts              IND
# 10012        24.0        17.0      Denver Broncos              JAX
#
#        spread_favorite               stadium  weather_temperature  \
# 10008             -5.0   Louisiana Superdome                 72.0
# 10009             -3.0  Ralph Wilson Stadium                 64.0
# 10010             -6.5         Soldier Field                 75.0
# 10011             -1.0       Reliant Stadium                 89.0
# 10012             -3.0        EverBank Field                 91.0
#
#        weather_wind_mph
# 10008               0.0
# 10009               7.0
# 10010               1.0
# 10011               5.0
# 10012               1.0

# %%
nfl_scores.to_csv('cleaned-data/nfl_game_data_2010_2023.csv')

# %% [markdown]
# #### NFL Teams CSV

# %%
nfl_teams = pd.read_csv('data/nfl_teams.csv')
nfl_teams.head()
# Out:
#            team_name team_name_short team_id team_id_pfr team_conference  \
# 0  Arizona Cardinals       Cardinals     ARI         CRD             NFC
# 1    Atlanta Falcons         Falcons     ATL         ATL             NFC
# 2    Baltimore Colts           Colts     IND         CLT             AFC
# 3   Baltimore Ravens          Ravens     BAL         RAV             AFC
# 4    Boston Patriots        Patriots      NE         NWE             AFC
#
#   team_division team_conference_pre2002 team_division_pre2002
# 0      NFC West                     NFC              NFC West
# 1     NFC South                     NFC              NFC West
# 2           NaN                     AFC              AFC East
# 3     AFC North                     AFC           AFC Central
# 4           NaN                     AFC                   NaN

# %%
# drop columns that are not needed
nfl_teams.drop(columns=['team_id_pfr', 'team_conference_pre2002', 'team_division_pre2002'], inplace=True)
nfl_teams.head()
# Out:
#            team_name team_name_short team_id team_conference team_division
# 0  Arizona Cardinals       Cardinals     ARI             NFC      NFC West
# 1    Atlanta Falcons         Falcons     ATL             NFC     NFC South
# 2    Baltimore Colts           Colts     IND             AFC           NaN
# 3   Baltimore Ravens          Ravens     BAL             AFC     AFC North
# 4    Boston Patriots        Patriots      NE             AFC           NaN

# %%
# drop rows where the team division is na
nfl_teams = nfl_teams[nfl_teams['team_division'].notna()]
nfl_teams.head()
# Out:
#            team_name team_name_short team_id team_conference team_division
# 0  Arizona Cardinals       Cardinals     ARI             NFC      NFC West
# 1    Atlanta Falcons         Falcons     ATL             NFC     NFC South
# 3   Baltimore Ravens          Ravens     BAL             AFC     AFC North
# 5      Buffalo Bills           Bills     BUF             AFC      AFC East
# 6  Carolina Panthers        Panthers     CAR             NFC     NFC South

# %%
nfl_teams = nfl_teams.sort_values(by=['team_division']).reset_index(drop=True)
nfl_teams.head()
# Out:
#               team_name team_name_short team_id team_conference team_division
# 0  New England Patriots        Patriots      NE             AFC      AFC East
# 1         Buffalo Bills           Bills     BUF             AFC      AFC East
# 2        Miami Dolphins        Dolphins     MIA             AFC      AFC East
# 3         New York Jets            Jets     NYJ             NFC      AFC East
# 4      Baltimore Ravens          Ravens     BAL             AFC     AFC North

# %%
# manually change jets conference to afc
nfl_teams.loc[3, 'team_conference'] = 'AFC'
nfl_teams.head()
# Out:
#               team_name team_name_short team_id team_conference team_division
# 0  New England Patriots        Patriots      NE             AFC      AFC East
# 1         Buffalo Bills           Bills     BUF             AFC      AFC East
# 2        Miami Dolphins        Dolphins     MIA             AFC      AFC East
# 3         New York Jets            Jets     NYJ             AFC      AFC East
# 4      Baltimore Ravens          Ravens     BAL             AFC     AFC North

# %%
nfl_teams.to_csv('cleaned-data/nfl_teams_info.csv')

# %% [markdown]
# ### NFL Box Scores Kaggle Dataset

# %% [markdown]
# #### Box Scores CSV

# %%
box_score = pd.read_csv('data/box_scores.csv')
box_score.head()
# Out:
#                 date       visitor          home  visitor_score  home_score  \
# 0  September 7, 2014     Cleveland    Pittsburgh             27          30
# 1  September 7, 2014  Jacksonville  Philadelphia             17          34
# 2  September 4, 2014     Green Bay       Seattle             16          36
# 3  September 7, 2014     Minnesota     St. Louis             34           6
# 4  September 7, 2014    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_rushing_first_downs  \
# 0                   23                            9
# 1                   18                            2
# 2                   19                            4
# 3                   18                            6
# 4                   16                            4
#
#    visitor_passing_first_downs  visitor_penalties  visitor_net_yards  ...  \
# 0                           11                  3                389  ...
# 1                           14                  2                306  ...
# 2                           13                  2                255  ...
# 3                           10                  2                355  ...
# 4                           11                  1                380  ...
#
#    home_kick_return_splits  home_int_return_splits  home_penalty_splits  \
# 0                     2-29                     0-0                11-96
# 1                     1-24                     0-0                 6-50
# 2                     3-60                    1-21                 4-69
# 3                     1-26                     0-0               13-121
# 4                    4-109                     0-0                 3-29
#
#    home_fumble_splits home_field_goals home_third_down_splits  \
# 0                 1-0              3-3               4-12-33%
# 1                 3-2              2-2               8-19-42%
# 2                 2-1              2-2               4-11-36%
# 3                 4-0              2-3               4-14-28%
# 4                 2-1              1-2               8-17-47%
#
#    home_fourth_down_splits  home_total_plays home_avg_gain  \
# 0                 1-1-100%                67           7.5
# 1                 1-1-100%                82           5.1
# 2                 1-1-100%                66           6.0
# 3                   0-0-0%                63           5.0
# 4                  1-2-50%                85           5.0
#
#    home_time_of_possession
# 0                    32:27
# 1                    30:46
# 2                    33:20
# 3                    31:43
# 4                    29:30
#
# [5 rows x 57 columns]

# %%
box_score.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4328 entries, 0 to 4327
# Data columns (total 57 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   date                         4328 non-null   object
#  1   visitor                      4328 non-null   object
#  2   home                         4328 non-null   object
#  3   visitor_score                4328 non-null   int64
#  4   home_score                   4328 non-null   int64
#  5   visitor_first_downs          4328 non-null   int64
#  6   visitor_rushing_first_downs  4328 non-null   int64
#  7   visitor_passing_first_downs  4328 non-null   int64
#  8   visitor_penalties            4328 non-null   int64
#  9   visitor_net_yards            4328 non-null   int64
#  10  visitor_net_yards_rushing    4328 non-null   int64
#  11  visitor_rushing_plays        4328 non-null   int64
#  12  visitor_avg_rush             4328 non-null   float64
#  13  visitor_net_yards_passing    4328 non-null   int64
#  14  visitor_passing_splits       4328 non-null   object
#  15  visitor_sack_splits          4328 non-null   object
#  16  visitor_gross_passing        4328 non-null   int64
#  17  visitor_yards_per_pass       4328 non-null   float64
#  18  visitor_punt_splits_avg      4328 non-null   object
#  19  visitor_punts_blocked        4311 non-null   float64
#  20  visitor_punt_return_splits   4328 non-null   object
#  21  visitor_kick_return_splits   4328 non-null   object
#  22  visitor_int_return_splits    4328 non-null   object
#  23  visitor_penalty_splits       4328 non-null   object
#  24  visitor_fumble_splits        4328 non-null   object
#  25  visitor_field_goals          4328 non-null   object
#  26  visitor_third_down_splits    4328 non-null   object
#  27  visitor_fourth_down_splits   4328 non-null   object
#  28  visitor_total_plays          4328 non-null   int64
#  29  visitor_avg_gain             4328 non-null   float64
#  30  visitor_time_of_possession   4328 non-null   object
#  31  home_first_downs             4328 non-null   int64
#  32  home_rushing_first_downs     4328 non-null   int64
#  33  home_passing_first_downs     4328 non-null   int64
#  34  home_penalties               4328 non-null   int64
#  35  home_net_yards               4328 non-null   int64
#  36  home_net_yards_rushing       4328 non-null   int64
#  37  home_rushing_plays           4328 non-null   int64
#  38  home_avg_rush                4328 non-null   float64
#  39  home_net_yards_passing       4328 non-null   int64
#  40  home_passing_splits          4328 non-null   object
#  41  home_sack_splits             4328 non-null   object
#  42  home_gross_passing           4328 non-null   int64
#  43  home_yards_per_pass          4328 non-null   float64
#  44  home_punt_splits_avg         4328 non-null   object
#  45  home_punts_blocked           4303 non-null   float64
#  46  home_punt_return_splits      4328 non-null   object
#  47  home_kick_return_splits      4328 non-null   object
#  48  home_int_return_splits       4328 non-null   object
#  49  home_penalty_splits          4328 non-null   object
#  50  home_fumble_splits           4328 non-null   object
#  51  home_field_goals             4328 non-null   object
#  52  home_third_down_splits       4328 non-null   object
#  53  home_fourth_down_splits      4328 non-null   object
#  54  home_total_plays             4328 non-null   int64
#  55  home_avg_gain                4328 non-null   float64
#  56  home_time_of_possession      4328 non-null   object
# dtypes: float64(8), int64(22), object(27)
# memory usage: 1.9+ MB

# %%
box_score.columns
# Out:
# Index(['date', 'visitor', 'home', 'visitor_score', 'home_score',
#        'visitor_first_downs', 'visitor_rushing_first_downs',
#        'visitor_passing_first_downs', 'visitor_penalties', 'visitor_net_yards',
#        'visitor_net_yards_rushing', 'visitor_rushing_plays',
#        'visitor_avg_rush', 'visitor_net_yards_passing',
#        'visitor_passing_splits', 'visitor_sack_splits',
#        'visitor_gross_passing', 'visitor_yards_per_pass',
#        'visitor_punt_splits_avg', 'visitor_punts_blocked',
#        'visitor_punt_return_splits', 'visitor_kick_return_splits',
#        'visitor_int_return_splits', 'visitor_penalty_splits',
#        'visitor_fumble_splits', 'visitor_field_goals',
#        'visitor_third_down_splits', 'visitor_fourth_down_splits',
#        'visitor_total_plays', 'visitor_avg_gain', 'visitor_time_of_possession',
#        'home_first_downs', 'home_rushing_first_downs',
#        'home_passing_first_downs', 'home_penalties', 'home_net_yards',
#        'home_net_yards_rushing', 'home_rushing_plays', 'home_avg_rush',
#        'home_net_yards_passing', 'home_passing_splits', 'home_sack_splits',
#        'home_gross_passing', 'home_yards_per_pass', 'home_punt_splits_avg',
#        'home_punts_blocked', 'home_punt_return_splits',
#        'home_kick_return_splits', 'home_int_return_splits',
#        'home_penalty_splits', 'home_fumble_splits', 'home_field_goals',
#        'home_third_down_splits', 'home_fourth_down_splits', 'home_total_plays',
#        'home_avg_gain', 'home_time_of_possession'],
#       dtype='object')

# %%
clean_box_score = box_score[['date', 'visitor', 'home', 'visitor_score', 'home_score', 'visitor_first_downs', 'visitor_net_yards', 'visitor_total_plays', 'visitor_avg_gain', 'visitor_time_of_possession', 
                             'home_first_downs', 'home_net_yards', 'home_total_plays', 'home_avg_gain', 'home_time_of_possession']]
clean_box_score.head()
# Out:
#                 date       visitor          home  visitor_score  home_score  \
# 0  September 7, 2014     Cleveland    Pittsburgh             27          30
# 1  September 7, 2014  Jacksonville  Philadelphia             17          34
# 2  September 4, 2014     Green Bay       Seattle             16          36
# 3  September 7, 2014     Minnesota     St. Louis             34           6
# 4  September 7, 2014    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   23                389                   64
# 1                   18                306                   70
# 2                   19                255                   57
# 3                   18                355                   57
# 4                   16                380                   64
#
#    visitor_avg_gain visitor_time_of_possession  home_first_downs  \
# 0               6.1                      27:33                24
# 1               4.4                      29:14                24
# 2               4.5                      26:40                25
# 3               6.2                      28:17                15
# 4               5.9                      30:30                26
#
#    home_net_yards  home_total_plays  home_avg_gain home_time_of_possession
# 0             503                67            7.5                   32:27
# 1             420                82            5.1                   30:46
# 2             398                66            6.0                   33:20
# 3             318                63            5.0                   31:43
# 4             423                85            5.0                   29:30

# %%
clean_box_score['date'] = pd.to_datetime(clean_box_score['date'])
clean_box_score.head()
# Out:
# /var/folders/q8/mqm68gfx7pjfpqftf7y_v6140000gn/T/ipykernel_68884/2612714237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   clean_box_score['date'] = pd.to_datetime(clean_box_score['date'])
#         date       visitor          home  visitor_score  home_score  \
# 0 2014-09-07     Cleveland    Pittsburgh             27          30
# 1 2014-09-07  Jacksonville  Philadelphia             17          34
# 2 2014-09-04     Green Bay       Seattle             16          36
# 3 2014-09-07     Minnesota     St. Louis             34           6
# 4 2014-09-07    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   23                389                   64
# 1                   18                306                   70
# 2                   19                255                   57
# 3                   18                355                   57
# 4                   16                380                   64
#
#    visitor_avg_gain visitor_time_of_possession  home_first_downs  \
# 0               6.1                      27:33                24
# 1               4.4                      29:14                24
# 2               4.5                      26:40                25
# 3               6.2                      28:17                15
# 4               5.9                      30:30                26
#
#    home_net_yards  home_total_plays  home_avg_gain home_time_of_possession
# 0             503                67            7.5                   32:27
# 1             420                82            5.1                   30:46
# 2             398                66            6.0                   33:20
# 3             318                63            5.0                   31:43
# 4             423                85            5.0                   29:30

# %%
clean_box_score = clean_box_score[clean_box_score['date'].dt.year >= 2010]
clean_box_score.head()
# Out:
#         date       visitor          home  visitor_score  home_score  \
# 0 2014-09-07     Cleveland    Pittsburgh             27          30
# 1 2014-09-07  Jacksonville  Philadelphia             17          34
# 2 2014-09-04     Green Bay       Seattle             16          36
# 3 2014-09-07     Minnesota     St. Louis             34           6
# 4 2014-09-07    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   23                389                   64
# 1                   18                306                   70
# 2                   19                255                   57
# 3                   18                355                   57
# 4                   16                380                   64
#
#    visitor_avg_gain visitor_time_of_possession  home_first_downs  \
# 0               6.1                      27:33                24
# 1               4.4                      29:14                24
# 2               4.5                      26:40                25
# 3               6.2                      28:17                15
# 4               5.9                      30:30                26
#
#    home_net_yards  home_total_plays  home_avg_gain home_time_of_possession
# 0             503                67            7.5                   32:27
# 1             420                82            5.1                   30:46
# 2             398                66            6.0                   33:20
# 3             318                63            5.0                   31:43
# 4             423                85            5.0                   29:30

# %%
clean_box_score.to_csv('cleaned-data/box_scores_2010_2017.csv')

# %% [markdown]
# ### Setting Up Data

# %%
# read all cleaned tables
box_scores = pd.read_csv("../phase2/cleaned-data/box_scores_2010_2017.csv").drop(columns=["Unnamed: 0"])
game_data = pd.read_csv("../phase2/cleaned-data/nfl_game_data_2010_2023.csv").drop(columns=["Unnamed: 0"])
team_stats = pd.read_csv("../phase2/cleaned-data/nfl_team_stats_2010_2021.csv").drop(columns=["Unnamed: 0"])
nfl_teams = pd.read_csv("../phase2/cleaned-data/nfl_teams_info.csv").drop(columns=["Unnamed: 0"])

# %%
# adding values for the St. Louis Rams and Las Vegas Raiders as they show up in the other datasets
rams = pd.DataFrame({"team_name": "St. Louis Rams", "team_name_short": "Rams", "team_id": "LAR", "team_conference": "NFC", "team_division": "NFC West"}, index=[0])
raiders = pd.DataFrame({"team_name": "Las Vegas Raiders", "team_name_short": "Raiders", "team_id": "LVR", "team_conference": "AFC", "team_division": "AFC West"}, index=[0])
nfl_teams = pd.concat([nfl_teams, rams, raiders], ignore_index=True)
nfl_teams = nfl_teams.sort_values(by=["team_division"]).reset_index(drop=True)
nfl_teams.head()
# Out:
#               team_name team_name_short team_id team_conference team_division
# 0  New England Patriots        Patriots      NE             AFC      AFC East
# 1         Buffalo Bills           Bills     BUF             AFC      AFC East
# 2        Miami Dolphins        Dolphins     MIA             AFC      AFC East
# 3         New York Jets            Jets     NYJ             AFC      AFC East
# 4      Baltimore Ravens          Ravens     BAL             AFC     AFC North

# %%
# function to get team id from city/team name
def get_team_id(city):
    # find the team name 
    for team in nfl_teams["team_name"]:
        if city in team:
            return nfl_teams[nfl_teams["team_name"] == team]["team_id"].values[0]
        elif city == "NY Giants":
            return "NYG"
        elif city == "NY Jets":
            return "NYJ"
        elif city == "LA Rams":
            return "LAR"
        elif city == "LA Chargers":
            return "LAC"

# %%
# adding team ids to the box scores dataset
box_scores["home_id"] = box_scores["home"].apply(get_team_id)
box_scores["away_id"] = box_scores["visitor"].apply(get_team_id)

box_scores.head()
# Out:
#          date       visitor          home  visitor_score  home_score  \
# 0  2014-09-07     Cleveland    Pittsburgh             27          30
# 1  2014-09-07  Jacksonville  Philadelphia             17          34
# 2  2014-09-04     Green Bay       Seattle             16          36
# 3  2014-09-07     Minnesota     St. Louis             34           6
# 4  2014-09-07    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   23                389                   64
# 1                   18                306                   70
# 2                   19                255                   57
# 3                   18                355                   57
# 4                   16                380                   64
#
#    visitor_avg_gain visitor_time_of_possession  home_first_downs  \
# 0               6.1                      27:33                24
# 1               4.4                      29:14                24
# 2               4.5                      26:40                25
# 3               6.2                      28:17                15
# 4               5.9                      30:30                26
#
#    home_net_yards  home_total_plays  home_avg_gain home_time_of_possession  \
# 0             503                67            7.5                   32:27
# 1             420                82            5.1                   30:46
# 2             398                66            6.0                   33:20
# 3             318                63            5.0                   31:43
# 4             423                85            5.0                   29:30
#
#   home_id away_id
# 0     PIT     CLE
# 1     PHI     JAX
# 2     SEA      GB
# 3     LAR     MIN
# 4     BAL     CIN

# %%
# adding team ids to the game data dataset
game_data["home_id"] = game_data["team_home"].apply(get_team_id)
game_data["away_id"] = game_data["team_away"].apply(get_team_id)

game_data.head()
# Out:
#   schedule_date  schedule_season schedule_week             team_home  \
# 0    2010-09-09             2010             1    New Orleans Saints
# 1    2010-09-12             2010             1         Buffalo Bills
# 2    2010-09-12             2010             1         Chicago Bears
# 3    2010-09-12             2010             1        Houston Texans
# 4    2010-09-12             2010             1  Jacksonville Jaguars
#
#    score_home  score_away           team_away team_favorite_id  \
# 0        14.0         9.0   Minnesota Vikings               NO
# 1        10.0        15.0      Miami Dolphins              MIA
# 2        19.0        14.0       Detroit Lions              CHI
# 3        34.0        24.0  Indianapolis Colts              IND
# 4        24.0        17.0      Denver Broncos              JAX
#
#    spread_favorite               stadium  weather_temperature  \
# 0             -5.0   Louisiana Superdome                 72.0
# 1             -3.0  Ralph Wilson Stadium                 64.0
# 2             -6.5         Soldier Field                 75.0
# 3             -1.0       Reliant Stadium                 89.0
# 4             -3.0        EverBank Field                 91.0
#
#    weather_wind_mph home_id away_id
# 0               0.0      NO     MIN
# 1               7.0     BUF     MIA
# 2               1.0     CHI     DET
# 3               5.0     HOU     IND
# 4               1.0     JAX     DEN

# %% [markdown]
# ### Joining Data

# %%
# merge the box scores and game data using inner join on date and home/away id
box_game_data_merged = pd.merge(box_scores, game_data, how="inner", left_on=["date", "home_id", "away_id"], right_on=["schedule_date", "home_id", "away_id"])
box_game_data_merged.head()
# Out:
#          date       visitor          home  visitor_score  home_score  \
# 0  2014-09-07     Cleveland    Pittsburgh             27          30
# 1  2014-09-07  Jacksonville  Philadelphia             17          34
# 2  2014-09-04     Green Bay       Seattle             16          36
# 3  2014-09-07     Minnesota     St. Louis             34           6
# 4  2014-09-07    Cincinnati     Baltimore             23          16
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   23                389                   64
# 1                   18                306                   70
# 2                   19                255                   57
# 3                   18                355                   57
# 4                   16                380                   64
#
#    visitor_avg_gain visitor_time_of_possession  ...  schedule_week  \
# 0               6.1                      27:33  ...              1
# 1               4.4                      29:14  ...              1
# 2               4.5                      26:40  ...              1
# 3               6.2                      28:17  ...              1
# 4               5.9                      30:30  ...              1
#
#              team_home  score_home  score_away             team_away  \
# 0  Pittsburgh Steelers        30.0        27.0      Cleveland Browns
# 1  Philadelphia Eagles        34.0        17.0  Jacksonville Jaguars
# 2     Seattle Seahawks        36.0        16.0     Green Bay Packers
# 3       St. Louis Rams         6.0        34.0     Minnesota Vikings
# 4     Baltimore Ravens        16.0        23.0    Cincinnati Bengals
#
#   team_favorite_id spread_favorite                  stadium  \
# 0              PIT            -5.5              Heinz Field
# 1              PHI           -10.0  Lincoln Financial Field
# 2              SEA            -4.5        CenturyLink Field
# 3              LAR            -3.0        Edward Jones Dome
# 4              BAL            -1.0         M&T Bank Stadium
#
#    weather_temperature weather_wind_mph
# 0                 72.0              6.0
# 1                 80.0              6.0
# 2                 70.0              5.0
# 3                 72.0              0.0
# 4                 78.0              0.0
#
# [5 rows x 29 columns]

# %%
# sort the merged dataset by date
box_game_data_merged = box_game_data_merged.sort_values(by=["date"]).reset_index(drop=True)
box_game_data_merged.head()
# Out:
#          date       visitor         home  visitor_score  home_score  \
# 0  2010-09-09     Minnesota  New Orleans              9          14
# 1  2010-09-12  Indianapolis      Houston             24          34
# 2  2010-09-12       Detroit      Chicago             14          19
# 3  2010-09-12       Arizona    St. Louis             17          13
# 4  2010-09-12      Carolina    NY Giants             18          31
#
#    visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0                   12                253                   51
# 1                   25                463                   69
# 2                   13                168                   57
# 3                   21                378                   64
# 4                   14                237                   63
#
#    visitor_avg_gain visitor_time_of_possession  ...  schedule_week  \
# 0               5.0                      26:17  ...              1
# 1               6.7                      29:07  ...              1
# 2               2.9                      25:18  ...              1
# 3               5.9                      27:09  ...              1
# 4               3.8                      25:21  ...              1
#
#             team_home  score_home  score_away           team_away  \
# 0  New Orleans Saints        14.0         9.0   Minnesota Vikings
# 1      Houston Texans        34.0        24.0  Indianapolis Colts
# 2       Chicago Bears        19.0        14.0       Detroit Lions
# 3      St. Louis Rams        13.0        17.0   Arizona Cardinals
# 4     New York Giants        31.0        18.0   Carolina Panthers
#
#   team_favorite_id spread_favorite              stadium  weather_temperature  \
# 0               NO            -5.0  Louisiana Superdome                 72.0
# 1              IND            -1.0      Reliant Stadium                 89.0
# 2              CHI            -6.5        Soldier Field                 75.0
# 3              ARI            -3.0    Edward Jones Dome                 72.0
# 4              NYG            -6.0      MetLife Stadium                 65.0
#
#   weather_wind_mph
# 0              0.0
# 1              5.0
# 2              1.0
# 3              0.0
# 4              1.0
#
# [5 rows x 29 columns]

# %%
# drop unnecessary columns
box_game_data_merged = box_game_data_merged.drop(columns=["schedule_date", "visitor", "home", "visitor_score", "home_score"])
box_game_data_merged.head()
# Out:
#          date  visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0  2010-09-09                   12                253                   51
# 1  2010-09-12                   25                463                   69
# 2  2010-09-12                   13                168                   57
# 3  2010-09-12                   21                378                   64
# 4  2010-09-12                   14                237                   63
#
#    visitor_avg_gain visitor_time_of_possession  home_first_downs  \
# 0               5.0                      26:17                18
# 1               6.7                      29:07                23
# 2               2.9                      25:18                23
# 3               5.9                      27:09                20
# 4               3.8                      25:21                21
#
#    home_net_yards  home_total_plays  home_avg_gain  ... schedule_week  \
# 0             308                62            5.0  ...             1
# 1             355                61            5.8  ...             1
# 2             463                70            6.6  ...             1
# 3             325                81            4.0  ...             1
# 4             376                67            5.6  ...             1
#
#             team_home score_home  score_away           team_away  \
# 0  New Orleans Saints       14.0         9.0   Minnesota Vikings
# 1      Houston Texans       34.0        24.0  Indianapolis Colts
# 2       Chicago Bears       19.0        14.0       Detroit Lions
# 3      St. Louis Rams       13.0        17.0   Arizona Cardinals
# 4     New York Giants       31.0        18.0   Carolina Panthers
#
#   team_favorite_id  spread_favorite              stadium weather_temperature  \
# 0               NO             -5.0  Louisiana Superdome                72.0
# 1              IND             -1.0      Reliant Stadium                89.0
# 2              CHI             -6.5        Soldier Field                75.0
# 3              ARI             -3.0    Edward Jones Dome                72.0
# 4              NYG             -6.0      MetLife Stadium                65.0
#
#   weather_wind_mph
# 0              0.0
# 1              5.0
# 2              1.0
# 3              0.0
# 4              1.0
#
# [5 rows x 24 columns]

# %%
# convert time of possession to a float for minutes
def convert_time_to_float(time):
  if time == "None":
    return 0
  else:
    time_split = time.split(":")
    return float(time_split[0]) + float(time_split[1])/60

# %%
box_game_data_merged["visitor_time_of_possession"] = box_game_data_merged["visitor_time_of_possession"].apply(convert_time_to_float)
box_game_data_merged["home_time_of_possession"] = box_game_data_merged["home_time_of_possession"].apply(convert_time_to_float)

# %%
def get_winner_id(row):
    if row["score_home"] > row["score_away"]:
      return 0
    elif row["score_home"] < row["score_away"]:
      return 1
    else:
      return 2

# %%
# apply the get_winner_id function to the merged dataset
box_game_data_merged["winner_id"] = box_game_data_merged.apply(get_winner_id, axis=1)
box_game_data_merged.head()
# Out:
#          date  visitor_first_downs  visitor_net_yards  visitor_total_plays  \
# 0  2010-09-09                   12                253                   51
# 1  2010-09-12                   25                463                   69
# 2  2010-09-12                   13                168                   57
# 3  2010-09-12                   21                378                   64
# 4  2010-09-12                   14                237                   63
#
#    visitor_avg_gain  visitor_time_of_possession  home_first_downs  \
# 0               5.0                   26.283333                18
# 1               6.7                   29.116667                23
# 2               2.9                   25.300000                23
# 3               5.9                   27.150000                20
# 4               3.8                   25.350000                21
#
#    home_net_yards  home_total_plays  home_avg_gain  ...           team_home  \
# 0             308                62            5.0  ...  New Orleans Saints
# 1             355                61            5.8  ...      Houston Texans
# 2             463                70            6.6  ...       Chicago Bears
# 3             325                81            4.0  ...      St. Louis Rams
# 4             376                67            5.6  ...     New York Giants
#
#   score_home score_away           team_away team_favorite_id spread_favorite  \
# 0       14.0        9.0   Minnesota Vikings               NO            -5.0
# 1       34.0       24.0  Indianapolis Colts              IND            -1.0
# 2       19.0       14.0       Detroit Lions              CHI            -6.5
# 3       13.0       17.0   Arizona Cardinals              ARI            -3.0
# 4       31.0       18.0   Carolina Panthers              NYG            -6.0
#
#                stadium  weather_temperature weather_wind_mph winner_id
# 0  Louisiana Superdome                 72.0              0.0         0
# 1      Reliant Stadium                 89.0              5.0         0
# 2        Soldier Field                 75.0              1.0         0
# 3    Edward Jones Dome                 72.0              0.0         1
# 4      MetLife Stadium                 65.0              1.0         0
#
# [5 rows x 25 columns]

# %%
# convert columns to ints / floats
box_game_data_merged["score_home"] = box_game_data_merged["score_home"].astype(int)
box_game_data_merged["score_away"] = box_game_data_merged["score_away"].astype(int)
box_game_data_merged["home_first_downs"] = box_game_data_merged["home_first_downs"].astype(int)
box_game_data_merged["home_net_yards"] = box_game_data_merged["home_net_yards"].astype(int)
box_game_data_merged["home_total_plays"] = box_game_data_merged["home_total_plays"].astype(int)
box_game_data_merged["home_avg_gain"] = box_game_data_merged["home_avg_gain"].astype(float)
box_game_data_merged["visitor_first_downs"] = box_game_data_merged["visitor_first_downs"].astype(int)
box_game_data_merged["visitor_net_yards"] = box_game_data_merged["visitor_net_yards"].astype(int)
box_game_data_merged["visitor_total_plays"] = box_game_data_merged["visitor_total_plays"].astype(int)
box_game_data_merged["visitor_avg_gain"] = box_game_data_merged["visitor_avg_gain"].astype(float)

# %%
box_game_data_merged.columns
# Out:
# Index(['date', 'visitor_first_downs', 'visitor_net_yards',
#        'visitor_total_plays', 'visitor_avg_gain', 'visitor_time_of_possession',
#        'home_first_downs', 'home_net_yards', 'home_total_plays',
#        'home_avg_gain', 'home_time_of_possession', 'home_id', 'away_id',
#        'schedule_season', 'schedule_week', 'team_home', 'score_home',
#        'score_away', 'team_away', 'team_favorite_id', 'spread_favorite',
#        'stadium', 'weather_temperature', 'weather_wind_mph', 'winner_id'],
#       dtype='object')

# %% [markdown]
# Most Important Columns: 'home_id', 'away_id', 'visitor_net_yards', 'visitor_time_of_possession', 'home_net_yards', 'home_time_of_possession', 'score_home', 'score_away', 'stadium'

# %%
# convert box_game_data_merged to csv
box_game_data_merged.to_csv('cleaned-data/box_game_data_merged.csv')
