# %% [markdown]
# # Hierarchical Data and JSON
#
# A lot of data in the real world is naturally hierarchical. As an example, consider a data set where each observation is a TV show. Many of the variables in this data set are what we would expect, such as the runtime of each show and what network it was broadcast on. But there are also variables that are unorthodox, such as the season and the cast. A TV show can have multiple seasons and multiple cast members, as illustated in the figure below.
#
# ![](https://github.com/dlsun/pods/blob/master/11-Hierarchical-Data/hierarchical_data.png?raw=1)
#
# Can we represent all of this information in a single `DataFrame`? If each row represents a single show, then it is straightforward to have columns containing the runtimes, the premiere dates, and so on. But it is not obvious how to incorporate the season information into this `DataFrame` in a way that still makes this information accessible for analysis. There are multiple challenges:
#
# - A show has multiple seasons. We will need multiple columns, one for each season.
# - The number of seasons varies from show to show. For example, "Girls" was on for 6 seasons, while "The Golden Girls" was on for 7. We will need to have at least 7 columns in our `DataFrame` to be able to store all the information for "The Golden Girls", even though we only need 6 columns for "Girls" (and perhaps even fewer for other shows).
# - Each season has multiple variables associated with it, such as the premiere date and the end date. We will need a separate column for each of these variables.
#
# The resulting `DataFrame` might look something like this.
#
# |name    | runtime |  premiered  | season1premiere | season1end | ... | season7premiere | season7end |
# |--------|---------|-------------|-----------------|------------|-----|-----------------|------------|
# | Girls | 30       | 2012-04-15  | 2012-04-15      | 2012-06-17 | ... | `NaN`           | `NaN`      |
# | The Golden Girls | 30 | 1985-09-14 | 1985-09-14 | 1986-05-10 | ... | 1991-09-21 | 1992-05-09      |
# | ... | ... | ... | ... | ... | ... | ... | ... |
#
# Furthermore, each season contains a different number of episodes. If we also want to store information about each episode, it is impractical to do so in a `DataFrame`.
#
# The problem is that this data is naturally hierarchical. A TV show can have multiple cast members and multiple seasons; furthermore, each season can have multiple episodes. Hierarchical data requires a different storage format, which we'll explore now.

# %% [markdown]
# # The JSON Data Format
#
# The JavaScript Object Notation, or **JSON**, data format is a popular way to represent hierarchical data. Despite its name, its application extends far beyond JavaScript, the language for which it was originally designed.
#
# Let's take a look at the first 1000 characters of a JSON file. (_Warning:_ Never try to print the entire contents of a JSON file in a Jupyter notebook; this will freeze the notebook if the file is large!)

# %%
# Fetch data from a URL
import requests
response = requests.get("https://dlsun.github.io/pods/data/tvshows.json")

print(response.text[:1000])
# Out:
# [{"id": 139, "url": "http://www.tvmaze.com/shows/139/girls", "name": "Girls", "type": "Scripted", "language": "English", "genres": ["Drama", "Romance"], "status": "Ended", "runtime": 30, "premiered": "2012-04-15", "officialSite": "http://www.hbo.com/girls", "schedule": {"time": "22:00", "days": ["Sunday"]}, "rating": {"average": 6.9}, "weight": 75, "network": {"id": 8, "name": "HBO", "country": {"name": "United States", "code": "US", "timezone": "America/New_York"}}, "webChannel": null, "externals": {"tvrage": 30124, "thetvdb": 220411, "imdb": "tt1723816"}, "image": {"medium": "http://static.tvmaze.com/uploads/images/medium_portrait/31/78286.jpg", "original": "http://static.tvmaze.com/uploads/images/original_untouched/31/78286.jpg"}, "summary": "<p>This Emmy winning series is a comic look at the assorted humiliations and rare triumphs of a group of girls in their 20s.</p>", "updated": 1577601053, "cast": [{"person": {"id": 27410, "url": "http://www.tvmaze.com/people/27410/lena-dunham",

# %% [markdown]
# This syntax should seem familiar if you are a regular user of Python. Except for a few cosmetic differences, this is exactly the syntax of a Python dictionary! The `json` library in Python automatically translates a JSON string or file into a Python dict.

# %%
import json
data_shows = json.loads(response.text)
data_shows
# Out:
# [{'id': 139,
#   'url': 'http://www.tvmaze.com/shows/139/girls',
#   'name': 'Girls',
#   'type': 'Scripted',
#   'language': 'English',
#   'genres': ['Drama', 'Romance'],
#   'status': 'Ended',
#   'runtime': 30,
#   'premiered': '2012-04-15',
#   'officialSite': 'http://www.hbo.com/girls',
#   'schedule': {'time': '22:00', 'days': ['Sunday']},
#   'rating': {'average': 6.9},
#   'weight': 75,
#   'network': {'id': 8,
#    'name': 'HBO',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'}},
#   'webChannel': None,
#   'externals': {'tvrage': 30124, 'thetvdb': 220411, 'imdb': 'tt1723816'},
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/31/78286.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/31/78286.jpg'},
#   'summary': '<p>This Emmy winning series is a comic look at the assorted humiliations and rare triumphs of a group of girls in their 20s.</p>',
#   'updated': 1577601053,
#   'cast': [{'person': {'id': 27410,
#      'url': 'http://www.tvmaze.com/people/27410/lena-dunham',
#      'name': 'Lena Dunham',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1986-05-13',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7597.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7597.jpg'}},
#     'character': {'id': 36886,
#      'url': 'http://www.tvmaze.com/characters/36886/girls-hannah-horvath',
#      'name': 'Hannah Horvath',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1954.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1954.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 11102,
#      'url': 'http://www.tvmaze.com/people/11102/allison-williams',
#      'name': 'Allison Williams',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1988-04-13',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7628.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7628.jpg'}},
#     'character': {'id': 36887,
#      'url': 'http://www.tvmaze.com/characters/36887/girls-marnie-michaels',
#      'name': 'Marnie Michaels',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1955.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1955.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 27411,
#      'url': 'http://www.tvmaze.com/people/27411/jemima-kirke',
#      'name': 'Jemima Kirke',
#      'country': {'name': 'United Kingdom',
#       'code': 'GB',
#       'timezone': 'Europe/London'},
#      'birthday': '1985-04-26',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7631.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7631.jpg'}},
#     'character': {'id': 36888,
#      'url': 'http://www.tvmaze.com/characters/36888/girls-jessa-johansson',
#      'name': 'Jessa Johansson',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1957.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1957.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 16405,
#      'url': 'http://www.tvmaze.com/people/16405/zosia-mamet',
#      'name': 'Zosia Mamet',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1988-02-02',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7634.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7634.jpg'}},
#     'character': {'id': 36889,
#      'url': 'http://www.tvmaze.com/characters/36889/girls-shoshanna-shapiro',
#      'name': 'Shoshanna Shapiro',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1956.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1956.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 24858,
#      'url': 'http://www.tvmaze.com/people/24858/adam-driver',
#      'name': 'Adam Driver',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1983-11-19',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/170/425572.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/170/425572.jpg'}},
#     'character': {'id': 36890,
#      'url': 'http://www.tvmaze.com/characters/36890/girls-adam-sackler',
#      'name': 'Adam Sackler',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1959.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1959.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 24970,
#      'url': 'http://www.tvmaze.com/people/24970/alex-karpovsky',
#      'name': 'Alex Karpovsky',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1975-09-23',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7638.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7638.jpg'}},
#     'character': {'id': 36891,
#      'url': 'http://www.tvmaze.com/characters/36891/girls-ray-ploshansky',
#      'name': 'Ray Ploshansky',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1958.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1958.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 27412,
#      'url': 'http://www.tvmaze.com/people/27412/andrew-rannells',
#      'name': 'Andrew Rannells',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1978-08-23',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1960.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1960.jpg'}},
#     'character': {'id': 36892,
#      'url': 'http://www.tvmaze.com/characters/36892/girls-elijah-krantz',
#      'name': 'Elijah Krantz',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38615.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38615.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 4896,
#      'url': 'http://www.tvmaze.com/people/4896/ebon-moss-bachrach',
#      'name': 'Ebon Moss-Bachrach',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1977-03-19',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/147/369955.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/147/369955.jpg'}},
#     'character': {'id': 37030,
#      'url': 'http://www.tvmaze.com/characters/37030/girls-desi',
#      'name': 'Desi',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38616.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38616.jpg'}},
#     'self': False,
#     'voice': False}],
#   'seasons': [{'id': 650,
#     'url': 'http://www.tvmaze.com/seasons/650/girls-season-1',
#     'number': 1,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2012-04-15',
#     'endDate': '2012-06-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114492.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114492.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10820,
#       'url': 'http://www.tvmaze.com/episodes/10820/girls-1x01-pilot',
#       'name': 'Pilot',
#       'season': 1,
#       'number': 1,
#       'airdate': '2012-04-15',
#       'airtime': '22:30',
#       'airstamp': '2012-04-16T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38639.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38639.jpg'},
#       'summary': "<p>In the premiere of this comedy about twentysomething women navigating their way through life in New York, Hannah swings and misses at two curves when her parents rescind their financial support and she loses her unpaid internship. Meanwhile, Hannah's roommate, Marnie, throws a dinner party for their nomadic friend Jessa, who's returned from yet another journey.</p>"},
#      {'id': 10821,
#       'url': 'http://www.tvmaze.com/episodes/10821/girls-1x02-vagina-panic',
#       'name': 'Vagina Panic',
#       'season': 1,
#       'number': 2,
#       'airdate': '2012-04-22',
#       'airtime': '22:30',
#       'airstamp': '2012-04-23T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38640.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38640.jpg'},
#       'summary': "<p>An appointment at a women's clinic doesn't go according to Marnie's detailed plans, mostly because Jessa will find any reason not to show up. Meanwhile, Hannah is preoccupied by an STD scare; and Shoshanna makes a startling revelation.</p>"},
#      {'id': 10822,
#       'url': 'http://www.tvmaze.com/episodes/10822/girls-1x03-all-adventurous-women-do',
#       'name': 'All Adventurous Women Do',
#       'season': 1,
#       'number': 3,
#       'airdate': '2012-04-29',
#       'airtime': '22:30',
#       'airstamp': '2012-04-30T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38641.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38641.jpg'},
#       'summary': '<p>Hannah contacts her college boyfriend to find out how she contracted an STD, but learns perhaps even more shocking news from him. Meanwhile, Marnie is smitten with a pretentious artist at a gallery opening; and Jessa lands a babysitting job.</p>'},
#      {'id': 10823,
#       'url': 'http://www.tvmaze.com/episodes/10823/girls-1x04-hannahs-diary',
#       'name': "Hannah's Diary",
#       'season': 1,
#       'number': 4,
#       'airdate': '2012-05-06',
#       'airtime': '22:30',
#       'airstamp': '2012-05-07T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38642.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38642.jpg'},
#       'summary': "<p>Adam's risqué text message sends Hannah over the edge; Jessa gets distracted while babysitting; Shoshanna reunites with a guy she knew at camp; Ray and Charlie stick their noses where they don't belong.</p>"},
#      {'id': 10824,
#       'url': 'http://www.tvmaze.com/episodes/10824/girls-1x05-hard-being-easy',
#       'name': 'Hard Being Easy',
#       'season': 1,
#       'number': 5,
#       'airdate': '2012-05-13',
#       'airtime': '22:30',
#       'airstamp': '2012-05-14T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38643.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38643.jpg'},
#       'summary': '<p>Hannah tries a different tack with her boss to counter his inappropriate office behavior—she propositions him. Meanwhile, Marnie does some soul-searching about her relationship with Charlie; and Jessa wants the last word with an ex.</p>'},
#      {'id': 10825,
#       'url': 'http://www.tvmaze.com/episodes/10825/girls-1x06-the-return',
#       'name': 'The Return',
#       'season': 1,
#       'number': 6,
#       'airdate': '2012-05-20',
#       'airtime': '22:30',
#       'airstamp': '2012-05-21T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38644.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38644.jpg'},
#       'summary': '<p>Hannah visits her parents in Michigan for their 30th anniversary, and winds up going on a date to a fund-raiser for a local family who suffered a tragic loss.</p>'},
#      {'id': 10826,
#       'url': 'http://www.tvmaze.com/episodes/10826/girls-1x07-welcome-to-bushwick-aka-the-crackcident',
#       'name': 'Welcome to Bushwick a.k.a. The Crackcident',
#       'season': 1,
#       'number': 7,
#       'airdate': '2012-05-27',
#       'airtime': '22:30',
#       'airstamp': '2012-05-28T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38645.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38645.jpg'},
#       'summary': "<p>At a raging party in the Bushwick section of Brooklyn, Hannah sees a different side of Adam; Jessa lures the sender of an anonymous text message; Marnie finds out what Charlie's been up to for the past two weeks; and Shoshanna gets a hand from Ray when she needs it most.</p>"},
#      {'id': 10827,
#       'url': 'http://www.tvmaze.com/episodes/10827/girls-1x08-weirdos-need-girlfriends-too',
#       'name': 'Weirdos Need Girlfriends Too',
#       'season': 1,
#       'number': 8,
#       'airdate': '2012-06-03',
#       'airtime': '22:40',
#       'airstamp': '2012-06-04T02:40:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38646.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38646.jpg'},
#       'summary': "<p>Marnie and Jessa bond and meet an eligible bachelor who's new in town; Hannah gets to know Adam in ways she could not have imagined.</p>"},
#      {'id': 10828,
#       'url': 'http://www.tvmaze.com/episodes/10828/girls-1x09-leave-me-alone',
#       'name': 'Leave Me Alone',
#       'season': 1,
#       'number': 9,
#       'airdate': '2012-06-10',
#       'airtime': '22:30',
#       'airstamp': '2012-06-11T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38647.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38647.jpg'},
#       'summary': "<p>Hannah's resentment of an old rival's literary success leads her to grudgingly accept an invitation to a reading hosted by her former professor, a pair of setbacks about which she could usually complain to Marnie—until now. Meanwhile, Jessa gets a surprise visit from her former boss; and Shoshanna schedules a date with someone she met online.</p>"},
#      {'id': 10829,
#       'url': 'http://www.tvmaze.com/episodes/10829/girls-1x10-she-did',
#       'name': 'She Did',
#       'season': 1,
#       'number': 10,
#       'airdate': '2012-06-17',
#       'airtime': '22:00',
#       'airstamp': '2012-06-18T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38648.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38648.jpg'},
#       'summary': '<p>In the first-season finale, Jessa brings everyone together for a "mystery party," but other surprises are in store when Hannah misjudges Adam\'s commitment; Marnie tries her free-spirited side on for size; and Shoshanna\'s quirkiness impresses a suitor.</p>'}]},
#    {'id': 651,
#     'url': 'http://www.tvmaze.com/seasons/651/girls-season-2',
#     'number': 2,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2013-01-13',
#     'endDate': '2013-03-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114491.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114491.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10830,
#       'url': 'http://www.tvmaze.com/episodes/10830/girls-2x01-its-about-time',
#       'name': "It's About Time",
#       'season': 2,
#       'number': 1,
#       'airdate': '2013-01-13',
#       'airtime': '21:00',
#       'airstamp': '2013-01-14T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38649.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38649.jpg'},
#       'summary': "<p>Hannah throws a housewarming party with brand-new roommate Elijah, but it's hard to move on when she's still playing nurse to Adam. Marnie gets bad news at work and a visit from her mom ; Shoshanna avoids Ray at the party; and sun-kissed Jessa returns from her honeymoon.</p>"},
#      {'id': 10831,
#       'url': 'http://www.tvmaze.com/episodes/10831/girls-2x02-i-get-ideas',
#       'name': 'I Get Ideas',
#       'season': 2,
#       'number': 2,
#       'airdate': '2013-01-20',
#       'airtime': '21:00',
#       'airstamp': '2013-01-21T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38650.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38650.jpg'},
#       'summary': '<p>Hannah gets unsolicited musical attention from heartbroken Adam and displeasing opinions on her writing from Sandy. Elijah questions his sexuality; Marnie makes a career compromise when her curatorial dreams are crushed; Jessa revels in married life; Shoshanna and Ray make magic; and Elijah and Marnie harbor a secret.</p>'},
#      {'id': 10832,
#       'url': 'http://www.tvmaze.com/episodes/10832/girls-2x03-bad-friend',
#       'name': 'Bad Friend',
#       'season': 2,
#       'number': 3,
#       'airdate': '2013-01-27',
#       'airtime': '21:00',
#       'airstamp': '2013-01-28T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38651.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38651.jpg'},
#       'summary': '<p>On a freelance writing assignment to get out of her comfort zone, Hannah befriends the junkie downstairs and parties hard with Elijah, who reveals an explosive secret. Meanwhile, Marnie has a long awaited run-in with artist Booth Jonathan.</p>'},
#      {'id': 10833,
#       'url': 'http://www.tvmaze.com/episodes/10833/girls-2x04-its-a-shame-about-ray',
#       'name': "It's a Shame About Ray",
#       'season': 2,
#       'number': 4,
#       'airdate': '2013-02-02',
#       'airtime': '22:05',
#       'airstamp': '2013-02-03T03:05:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38652.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38652.jpg'},
#       'summary': "<p>Hannah hosts a grown-up dinner party to celebrate her writing gig, but her friends' behavior doesn't live up to the setting. Marnie and Audrey square off; Shoshanna realizes she has inadvertently entered a new phase with Ray ; Jessa meets Thomas-John's parents.</p>"},
#      {'id': 10834,
#       'url': 'http://www.tvmaze.com/episodes/10834/girls-2x05-one-mans-trash',
#       'name': "One Man's Trash",
#       'season': 2,
#       'number': 5,
#       'airdate': '2013-02-10',
#       'airtime': '21:00',
#       'airstamp': '2013-02-11T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38653.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38653.jpg'},
#       'summary': '<p>Hannah is surprised to find herself drawn to a good-looking 42-year-old doctor and the trappings of his conventionally successful adult life.</p>'},
#      {'id': 10835,
#       'url': 'http://www.tvmaze.com/episodes/10835/girls-2x06-boys',
#       'name': 'Boys',
#       'season': 2,
#       'number': 6,
#       'airdate': '2013-02-17',
#       'airtime': '21:00',
#       'airstamp': '2013-02-18T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38654.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38654.jpg'},
#       'summary': "<p>Hannah signs an e-book deal with a dauntingly tight deadline; Marnie plays hostess for Booth Jonathan's art party; Adam coaxes Ray to go on a Staten Island adventure; a depressed Jessa crashes with Hannah.</p>"},
#      {'id': 10836,
#       'url': 'http://www.tvmaze.com/episodes/10836/girls-2x07-video-games',
#       'name': 'Video Games',
#       'season': 2,
#       'number': 7,
#       'airdate': '2013-02-24',
#       'airtime': '21:00',
#       'airstamp': '2013-02-25T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38655.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38655.jpg'},
#       'summary': "<p>Hannah accompanies Jessa upstate to visit Jessa's estranged father, his new-age girlfriend and her virginal teenage son, Frank.</p>"},
#      {'id': 10837,
#       'url': 'http://www.tvmaze.com/episodes/10837/girls-2x08-its-back',
#       'name': "It's Back",
#       'season': 2,
#       'number': 8,
#       'airdate': '2013-03-03',
#       'airtime': '21:00',
#       'airstamp': '2013-03-04T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38656.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38656.jpg'},
#       'summary': "<p>Hannah tries to hide mounting anxiety about her book from her visiting parents. Marnie is stunned to learn that Charlie has started a successful app company; at AA, Adam meets a boisterous woman who coaxes him into dating her daughter, Natalia ; and Ray's aversion to college parties gives Shoshanna pause.</p>"},
#      {'id': 10838,
#       'url': 'http://www.tvmaze.com/episodes/10838/girls-2x09-on-all-fours',
#       'name': 'On All Fours',
#       'season': 2,
#       'number': 9,
#       'airdate': '2013-03-10',
#       'airtime': '21:00',
#       'airstamp': '2013-03-11T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38657.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38657.jpg'},
#       'summary': "<p>Pressure from Hannah's aggressive publisher and a looming deadline further jeopardize her mental state. Adam and his new girlfriend have their first misunderstanding. At Charlie's work party, Shoshanna avoids Ray, and Marnie makes an unsettling step towards following her dreams.</p>"},
#      {'id': 10839,
#       'url': 'http://www.tvmaze.com/episodes/10839/girls-2x10-together',
#       'name': 'Together',
#       'season': 2,
#       'number': 10,
#       'airdate': '2013-03-17',
#       'airtime': '21:00',
#       'airstamp': '2013-03-18T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38658.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38658.jpg'},
#       'summary': "<p>To avoid being sued by her publisher, Hannah must write her book in a single day. Marnie misinterprets Charlie's intentions; Ray makes a career move that he hopes will impress Shoshanna.</p>"}]},
#    {'id': 652,
#     'url': 'http://www.tvmaze.com/seasons/652/girls-season-3',
#     'number': 3,
#     'name': '',
#     'episodeOrder': 12,
#     'premiereDate': '2014-01-12',
#     'endDate': '2014-03-23',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114490.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114490.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10840,
#       'url': 'http://www.tvmaze.com/episodes/10840/girls-3x01-females-only',
#       'name': 'Females Only',
#       'season': 3,
#       'number': 1,
#       'airdate': '2014-01-12',
#       'airtime': '22:00',
#       'airstamp': '2014-01-13T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38595.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38595.jpg'},
#       'summary': "<p>Reeling after a nasty run-in with Natalia at Ray's new coffee and pizza place, Hannah and a reluctant Adam host dinner at their apartment with Marnie, who is living at home in New Jersey and still raw from her breakup with Charlie, and Shoshanna, who is alternating nights of sexual freedom with academia after her breakup with Ray. Meanwhile, Jessa pushes buttons, and new friend Jasper illuminates her daddy issues.</p>"},
#      {'id': 10841,
#       'url': 'http://www.tvmaze.com/episodes/10841/girls-3x02-truth-or-dare',
#       'name': 'Truth or Dare',
#       'season': 3,
#       'number': 2,
#       'airdate': '2014-01-12',
#       'airtime': '22:30',
#       'airstamp': '2014-01-13T03:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38596.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38596.jpg'},
#       'summary': "<p>Hannah, Shoshanna and Adam take a road trip to reunite with Jessa, leaving Marnie feeling left out as she moves into her own place. On the trip, Hannah looks futilely for writing inspiration in order to meet her editor's deadline.</p>"},
#      {'id': 10842,
#       'url': 'http://www.tvmaze.com/episodes/10842/girls-3x03-she-said-ok',
#       'name': 'She Said OK',
#       'season': 3,
#       'number': 3,
#       'airdate': '2014-01-19',
#       'airtime': '22:00',
#       'airstamp': '2014-01-20T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38597.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38597.jpg'},
#       'summary': "<p>When Caroline, Adam's eccentric and emotionally toxic sister, shows up unannounced, Hannah offers her a place to stay, despite Adam's protests. Marnie's control-freak tendencies reach full tilt at Hannah's 25th birthday party. Ray settles into his role as manager at the new restaurant, but has a harder time keeping cool around Shoshanna.</p>"},
#      {'id': 10843,
#       'url': 'http://www.tvmaze.com/episodes/10843/girls-3x04-dead-inside',
#       'name': 'Dead Inside',
#       'season': 3,
#       'number': 4,
#       'airdate': '2014-01-26',
#       'airtime': '22:00',
#       'airstamp': '2014-01-27T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38598.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38598.jpg'},
#       'summary': '<p>Hannah tries to process an untimely death, but seems more concerned about its impact on her eBook deal. Jessa tracks down an old friend she thought was dead. Marnie is horrified to discover a video Charlie posted online.</p>'},
#      {'id': 10844,
#       'url': 'http://www.tvmaze.com/episodes/10844/girls-3x05-only-child',
#       'name': 'Only Child',
#       'season': 3,
#       'number': 5,
#       'airdate': '2014-02-01',
#       'airtime': '22:00',
#       'airstamp': '2014-02-02T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38599.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38599.jpg'},
#       'summary': '<p>Hannah is thrilled to attend an event alongside members of the literary illuminati, until she learns that her eBook deal may be in jeopardy. Later, she tries to help Adam and Caroline work through their anger issues; Jessa makes positive changes; and Ray gives Marnie candid advice.</p>'},
#      {'id': 10845,
#       'url': 'http://www.tvmaze.com/episodes/10845/girls-3x06-free-snacks',
#       'name': 'Free Snacks',
#       'season': 3,
#       'number': 6,
#       'airdate': '2014-02-09',
#       'airtime': '22:00',
#       'airstamp': '2014-02-10T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38600.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38600.jpg'},
#       'summary': "<p>Hannah gets a job writing advertorials at GQ, but worries that the corporate environment will kill her creative mojo. Shoshanna rethinks her breakup in light of Ray's newfound success, while he and Marnie butt heads over lunch.</p>"},
#      {'id': 10846,
#       'url': 'http://www.tvmaze.com/episodes/10846/girls-3x07-beach-house',
#       'name': 'Beach House',
#       'season': 3,
#       'number': 7,
#       'airdate': '2014-02-16',
#       'airtime': '22:00',
#       'airstamp': '2014-02-17T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38601.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38601.jpg'},
#       'summary': "<p>During a Long Island weekend getaway with the girls, Hannah runs into Elijah and invites him and his friends to their beach house, hoping to take the pressure off of Marnie's rigorous schedule for honesty and healing.</p>"},
#      {'id': 10847,
#       'url': 'http://www.tvmaze.com/episodes/10847/girls-3x08-incidentals',
#       'name': 'Incidentals',
#       'season': 3,
#       'number': 8,
#       'airdate': '2014-02-23',
#       'airtime': '22:00',
#       'airstamp': '2014-02-24T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38602.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38602.jpg'},
#       'summary': "<p>During a GQ advertorial interview, Patti LuPone warns Hannah that Adam's new career path may cause unexpected problems. Meanwhile, Jessa's boredom at work is interrupted by a surprise visit from an old acquaintance. Later, Hannah is assigned to review the Gramercy Park Hotel, and the group celebrates good news with Adam's new friend Desi, whom Marnie finds particularly captivating.</p>"},
#      {'id': 10848,
#       'url': 'http://www.tvmaze.com/episodes/10848/girls-3x09-flo',
#       'name': 'Flo',
#       'season': 3,
#       'number': 9,
#       'airdate': '2014-03-02',
#       'airtime': '22:00',
#       'airstamp': '2014-03-03T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38603.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38603.jpg'},
#       'summary': '<p>While visiting her ailing grandmother in the hospital, Hannah is surprised by a strange request from her mother. Later, Hannah shares an uncomfortable drink with Rebecca, her overachieving med student cousin.</p>'},
#      {'id': 10849,
#       'url': 'http://www.tvmaze.com/episodes/10849/girls-3x10-role-play',
#       'name': 'Role-Play',
#       'season': 3,
#       'number': 10,
#       'airdate': '2014-03-09',
#       'airtime': '22:00',
#       'airstamp': '2014-03-10T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38604.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38604.jpg'},
#       'summary': "<p>Alarmed by Adam's indifference when she fails to come home after a night out with co-workers, Hannah worries that the spark may be gone in their relationship. Marnie begins working at Soo Jin's art gallery, though not in the role she expected; later, Desi helps her rediscover her voice. Shoshanna has a surprise for Jessa.</p>"},
#      {'id': 10850,
#       'url': 'http://www.tvmaze.com/episodes/10850/girls-3x11-i-saw-you',
#       'name': 'I Saw You',
#       'season': 3,
#       'number': 11,
#       'airdate': '2014-03-16',
#       'airtime': '22:00',
#       'airstamp': '2014-03-17T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38605.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38605.jpg'},
#       'summary': "<p>Hannah gets a glimpse of some harsh realities when she invites Elijah to join her in her quest to complete an unfinished assignment. Jessa searches for a job. Hannah, Shoshanna and Elijah attend Marnie's open-mic performance.</p>"},
#      {'id': 10851,
#       'url': 'http://www.tvmaze.com/episodes/10851/girls-3x12-two-plane-rides',
#       'name': 'Two Plane Rides',
#       'season': 3,
#       'number': 12,
#       'airdate': '2014-03-23',
#       'airtime': '22:00',
#       'airstamp': '2014-03-24T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38606.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38606.jpg'},
#       'summary': "<p>On the day of Adam's opening night, Hannah gets news that could change the direction of her career and their relationship. Marnie chooses an inopportune moment to divulge a secret to Shoshanna, who is dealing with her own unexpected news. Jessa's boss asks for an unusual favor.</p>"}]},
#    {'id': 653,
#     'url': 'http://www.tvmaze.com/seasons/653/girls-season-4',
#     'number': 4,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2015-01-11',
#     'endDate': '2015-03-22',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114489.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114489.jpg'},
#     'summary': None,
#     'episodes': [{'id': 40963,
#       'url': 'http://www.tvmaze.com/episodes/40963/girls-4x01-iowa',
#       'name': 'Iowa',
#       'season': 4,
#       'number': 1,
#       'airdate': '2015-01-11',
#       'airtime': '21:00',
#       'airstamp': '2015-01-12T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38594.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38594.jpg'},
#       'summary': '<p>After a congratulatory dinner with her parents, Hannah and Adam pack up the last of her boxes and discuss "the plan" for their soon-to-be long-distance relationship. Marnie and Desi perform as part of a jazz brunch for a distracted crowd at a downtown restaurant. Shoshanna signs for her diploma with her parents, who make a bigger deal out of the event than she thinks necessary. Jessa is confronted by Beedie\'s daughter, Rickie, and later seems nonplussed by Hannah\'s impending departure.</p>'},
#      {'id': 93523,
#       'url': 'http://www.tvmaze.com/episodes/93523/girls-4x02-triggering',
#       'name': 'Triggering',
#       'season': 4,
#       'number': 2,
#       'airdate': '2015-01-18',
#       'airtime': '21:00',
#       'airstamp': '2015-01-19T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/7/19527.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/7/19527.jpg'},
#       'summary': "<p>In her first days as a grad student, Hannah discovers she can get more for her money, rent-wise, in Iowa. Later, during a video chat, she slyly prods Marnie for intel about Adam. At her first seminar, Hannah warns her fellow workshop writers that her piece might trigger some intense emotions - but doesn't get the feedback she had hoped for.</p>"},
#      {'id': 93524,
#       'url': 'http://www.tvmaze.com/episodes/93524/girls-4x03-female-author',
#       'name': 'Female Author',
#       'season': 4,
#       'number': 3,
#       'airdate': '2015-01-25',
#       'airtime': '21:00',
#       'airstamp': '2015-01-26T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/7/19836.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/7/19836.jpg'},
#       'summary': "<p>With only one class a week, Hannah finds herself doing a lot of nothing in her free time, while a visiting Elijah has become the social butterfly of Iowa. Ray gives Marnie a wake-up call about Desi's true intentions before their meeting with a record label. Shoshanna aces, then blows, a job interview. Adam unwittingly gets drawn into Jessa's chaotic web after an AA meeting. At a poets' party in Iowa, Hannah rants about the undue expectations put on women writers, and takes things too far in critiquing her classmates.</p>"},
#      {'id': 108508,
#       'url': 'http://www.tvmaze.com/episodes/108508/girls-4x04-cubbies',
#       'name': 'Cubbies',
#       'season': 4,
#       'number': 4,
#       'airdate': '2015-02-08',
#       'airtime': '21:00',
#       'airstamp': '2015-02-09T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/21344.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/21344.jpg'},
#       'summary': '<p>Hannah is confronted by her classmates after leaving a non-apology apology letter in their cubbies. After being rejected at yet another job interview, a frustrated Shoshanna spends a day with Ray. Creative and romantic tensions between Marnie and Desi reach a breaking point.</p>'},
#      {'id': 120501,
#       'url': 'http://www.tvmaze.com/episodes/120501/girls-4x05-sit-in',
#       'name': 'Sit-In',
#       'season': 4,
#       'number': 5,
#       'airdate': '2015-02-15',
#       'airtime': '21:00',
#       'airstamp': '2015-02-16T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/21752.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/21752.jpg'},
#       'summary': '<p>Friends try to help Hannah through a crisis; Hannah and Adam have an honest conversation about their relationship.</p><p><br><br></p>'},
#      {'id': 120502,
#       'url': 'http://www.tvmaze.com/episodes/120502/girls-4x06-close-up',
#       'name': 'Close-Up',
#       'season': 4,
#       'number': 6,
#       'airdate': '2015-02-22',
#       'airtime': '21:00',
#       'airstamp': '2015-02-23T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/22209.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/22209.jpg'},
#       'summary': '<p>Soul-searching leads Hannah to an epiphany. Meanwhile, another disastrous interview for Shoshanna ends in a positive; Ray attempts to solve his neighborhood noise issue at a community board meeting; Marnie and Desi disagree on how to define their sound; Adam is shocked by a revelation.</p>'},
#      {'id': 131210,
#       'url': 'http://www.tvmaze.com/episodes/131210/girls-4x07-ask-me-my-name',
#       'name': 'Ask Me My Name',
#       'season': 4,
#       'number': 7,
#       'airdate': '2015-03-01',
#       'airtime': '21:00',
#       'airstamp': '2015-03-02T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/22748.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/22748.jpg'},
#       'summary': "<p>Hannah goes for drinks with Fran, a new coworker, before attending an unusual art show. Later, she spends time alone with Mimi-Rose, while Adam is unnerved by Ace, Mimi-Rose's friend. Meanwhile, Shoshanna helps Ray with his community board election campaign.</p>"},
#      {'id': 131211,
#       'url': 'http://www.tvmaze.com/episodes/131211/girls-4x08-tad-loreen-avi-shanaz',
#       'name': 'Tad & Loreen & Avi & Shanaz',
#       'season': 4,
#       'number': 8,
#       'airdate': '2015-03-08',
#       'airtime': '21:00',
#       'airstamp': '2015-03-09T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/23230.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/23230.jpg'},
#       'summary': '<p>Hannah spends an afternoon with a new young friend; Marnie and Desi fight over money; Jessa gives Shoshanna advice on the art of seduction; Loreen and Tad have a tense dinner party with their friends Avi and Shanaz.</p>'},
#      {'id': 131212,
#       'url': 'http://www.tvmaze.com/episodes/131212/girls-4x09-daddy-issues',
#       'name': 'Daddy Issues',
#       'season': 4,
#       'number': 9,
#       'airdate': '2015-03-15',
#       'airtime': '21:00',
#       'airstamp': '2015-03-16T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/23943.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/23943.jpg'},
#       'summary': "<p>Hannah's maturity is called into question after she is confronted with a family dilemma; Jessa, Ace, Mimi-Rose and Adam have an awkward encounter; Marnie makes an announcement at Ray's campaign party.</p>"},
#      {'id': 131213,
#       'url': 'http://www.tvmaze.com/episodes/131213/girls-4x10-home-birth',
#       'name': 'Home Birth',
#       'season': 4,
#       'number': 10,
#       'airdate': '2015-03-22',
#       'airtime': '21:00',
#       'airstamp': '2015-03-23T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/24316.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/24316.jpg'},
#       'summary': "<p>Hannah, Adam and Jessa each try to convince Caroline and Laird to forgo their planned home birth. Shoshanna faces a crucial decision when presented with a unique job opportunity. After Marnie and Desi's meeting with a record label exec, Ray lets Desi know what he really thinks of him.</p>"}]},
#    {'id': 21282,
#     'url': 'http://www.tvmaze.com/seasons/21282/girls-season-5',
#     'number': 5,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2016-02-21',
#     'endDate': '2016-04-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': None,
#     'summary': '',
#     'episodes': [{'id': 409239,
#       'url': 'http://www.tvmaze.com/episodes/409239/girls-5x01-wedding-day',
#       'name': 'Wedding Day',
#       'season': 5,
#       'number': 1,
#       'airdate': '2016-02-21',
#       'airtime': '22:00',
#       'airstamp': '2016-02-22T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/46/115008.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/46/115008.jpg'},
#       'summary': "<p>Marnie micromanages her upstate wedding to Desi while trying to maintain the facade of the breezy bride, and tasks Shoshanna with kicking out Fran, Hannah's date, so the girls can get ready. Banished to the boys' den, Fran has an awkward moment with Adam. A dejected Ray steps in to help Desi with his wedding-day jitters.</p>"},
#      {'id': 530407,
#       'url': 'http://www.tvmaze.com/episodes/530407/girls-5x02-good-man',
#       'name': 'Good Man',
#       'season': 5,
#       'number': 2,
#       'airdate': '2016-02-28',
#       'airtime': '22:00',
#       'airstamp': '2016-02-29T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/47/117623.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/47/117623.jpg'},
#       'summary': '<p>In New York, an erratic roommate leads Fran to move in with Hannah. Later, Hannah gets an urgent call from her dad, who is trying to navigate a new type of dating. After a run-in at an AA meeting, Adam and Jessa spend the day together. Ray fears that the new cafe across the street is hurting his business. Elijah is hit on by a famous news anchor.</p>'},
#      {'id': 530408,
#       'url': 'http://www.tvmaze.com/episodes/530408/girls-5x03-japan',
#       'name': 'Japan',
#       'season': 5,
#       'number': 3,
#       'airdate': '2016-03-06',
#       'airtime': '22:00',
#       'airstamp': '2016-03-07T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/47/119821.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/47/119821.jpg'},
#       'summary': '<p>Thriving at her new job in Japan, Shoshanna flirts with the boss, but reminds her work friends that she has a "kind of" boyfriend back in America. Hannah makes a shocking discovery on Fran\'s phone and struggles with how to react. After viewing Adam\'s performance on a TV police procedural, Jessa shares her insights into his character.</p>'},
#      {'id': 530409,
#       'url': 'http://www.tvmaze.com/episodes/530409/girls-5x04-old-loves',
#       'name': 'Old Loves',
#       'season': 5,
#       'number': 4,
#       'airdate': '2016-03-13',
#       'airtime': '22:00',
#       'airstamp': '2016-03-14T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/175/438842.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/175/438842.jpg'},
#       'summary': "<p>Hannah and Fran disagree about their teaching methods. Marnie fumes over Desi's decision to launch a major construction project in their studio apartment. Jessa pushes Hannah away over an awkward rice-pudding meetup. Elijah gets closer to Dill Harcourt.</p>"},
#      {'id': 530410,
#       'url': 'http://www.tvmaze.com/episodes/530410/girls-5x05-queen-for-two-days',
#       'name': 'Queen for Two Days',
#       'season': 5,
#       'number': 5,
#       'airdate': '2016-03-20',
#       'airtime': '22:00',
#       'airstamp': '2016-03-21T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/49/124456.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/49/124456.jpg'},
#       'summary': '<p>Hannah and her mom, Loreen, embark on a female-empowerment retreat, where Loreen hopes for clarity in her situation with Tad, and Hannah relishes time away from Fran. In Tokyo, Shoshanna enjoys her budding romance with Yoshi, and gets a surprise visitor from the U.S. Jessa meets up with her sister Minerva and asks for a favor.</p>'},
#      {'id': 530411,
#       'url': 'http://www.tvmaze.com/episodes/530411/girls-5x06-the-panic-in-central-park',
#       'name': 'The Panic in Central Park',
#       'season': 5,
#       'number': 6,
#       'airdate': '2016-03-27',
#       'airtime': '22:00',
#       'airstamp': '2016-03-28T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/127185.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/127185.jpg'},
# ...
#      {'id': 47613,
#       'url': 'http://www.tvmaze.com/episodes/47613/gilmore-girls-6x18-the-real-paul-anka',
#       'name': 'The Real Paul Anka',
#       'season': 6,
#       'number': 18,
#       'airdate': '2006-04-11',
#       'airtime': '21:00',
#       'airstamp': '2006-04-12T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>In the city of Brotherly Love for April's field trip, Luke visits Jess at his electric publishing house. Someone else drops in: Rory, who's growing weary of Logan's drinking and pranks.</p>"},
#      {'id': 47614,
#       'url': 'http://www.tvmaze.com/episodes/47614/gilmore-girls-6x19-i-get-a-sidekick-out-of-you',
#       'name': 'I Get a Sidekick Out of You',
#       'season': 6,
#       'number': 19,
#       'airdate': '2006-04-18',
#       'airtime': '21:00',
#       'airstamp': '2006-04-19T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Lane and Zach's wedding day is a glorious mix of Buddhist and Christian, red silk and white satin, ceremonial awe and awesome partying. Lorelai suddenly realizes that Rory may be next...and she may be never.</p>"},
#      {'id': 47615,
#       'url': 'http://www.tvmaze.com/episodes/47615/gilmore-girls-6x20-super-cool-party-people',
#       'name': 'Super Cool Party People',
#       'season': 6,
#       'number': 20,
#       'airdate': '2006-04-25',
#       'airtime': '21:00',
#       'airstamp': '2006-04-26T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Major disaster: Logan, unconscious and badly hurt after a Life-and-Death-Brigade stunt goes wrong. Minor disaster: April's birthday celebration, hosted by wholehearted but fun-challenged Luke.</p>"},
#      {'id': 47616,
#       'url': 'http://www.tvmaze.com/episodes/47616/gilmore-girls-6x21-driving-miss-gilmore',
#       'name': 'Driving Miss Gilmore',
#       'season': 6,
#       'number': 21,
#       'airdate': '2006-05-02',
#       'airtime': '21:00',
#       'airstamp': '2006-05-03T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Lorelai chauffeurs Emily, who's recovering from eye surgery. Paris and Doyle take care of Logan, home from the hospital. And Sookie and Jackson try to play it cool as they dispose of bags and bags of pot someone grew on their property.</p>"},
#      {'id': 47617,
#       'url': 'http://www.tvmaze.com/episodes/47617/gilmore-girls-6x22-partings',
#       'name': 'Partings',
#       'season': 6,
#       'number': 22,
#       'airdate': '2006-05-09',
#       'airtime': '21:00',
#       'airstamp': '2006-05-10T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Goodbye. The town troubadour departs Stars Hollow for his Neil Young gig (creating a stampede of would-be troubadours to town). Logan graduates and leaves for London. And the Lorelai-Luke love affair may be ciao, adios, game over.</p>'}]},
#    {'id': 2086,
#     'url': 'http://www.tvmaze.com/seasons/2086/gilmore-girls-season-7',
#     'number': 7,
#     'name': '',
#     'episodeOrder': 22,
#     'premiereDate': '2006-09-26',
#     'endDate': '2007-05-15',
#     'network': {'id': 5,
#      'name': 'The CW',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': None,
#     'summary': '',
#     'episodes': [{'id': 47618,
#       'url': 'http://www.tvmaze.com/episodes/47618/gilmore-girls-7x01-the-long-morrow',
#       'name': 'The Long Morrow',
#       'season': 7,
#       'number': 1,
#       'airdate': '2006-09-26',
#       'airtime': '21:00',
#       'airstamp': '2006-09-27T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>From bed to worse. The morning after her blowup with Luke, Lorelai wakes up next to...well, someone else. And complications definitely ensue. Logan leaves Rory a puzzling parting gift.</p>'},
#      {'id': 47619,
#       'url': 'http://www.tvmaze.com/episodes/47619/gilmore-girls-7x02-thats-what-you-get-folks-for-makin-whoopee',
#       'name': "That's What You Get, Folks, for Makin' Whoopee",
#       'season': 7,
#       'number': 2,
#       'airdate': '2006-10-03',
#       'airtime': '21:00',
#       'airstamp': '2006-10-04T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Mexico sucks: Lane returns from her honeymoon with a flinty attitude towards sex, an interesting parasite and a souvenir. And Luke has a tough time telling TJ and Liz that his engagement is disengaged.</p>'},
#      {'id': 47620,
#       'url': 'http://www.tvmaze.com/episodes/47620/gilmore-girls-7x03-lorelais-first-cotillion',
#       'name': "Lorelai's First Cotillion",
#       'season': 7,
#       'number': 3,
#       'airdate': '2006-10-10',
#       'airtime': '21:00',
#       'airstamp': '2006-10-11T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>"What if I don\'t want to do what I want to do because I want to do it, but because they don\'t want me to?" Friday dinner and a pop tart get Lorelai wondering what has been motivating her actions for over 20 years.</p>'},
#      {'id': 47621,
#       'url': 'http://www.tvmaze.com/episodes/47621/gilmore-girls-7x04-s-wonderful-s-marvelous',
#       'name': "'S Wonderful, 'S Marvelous",
#       'season': 7,
#       'number': 4,
#       'airdate': '2006-10-17',
#       'airtime': '21:00',
#       'airstamp': '2006-10-18T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Togetherness: Lorelai and Christopher start dating. Rory meets some artistic new friends. April moves in with Luke short-term and Emily gets up close and personal with the local constabulary.</p>'},
#      {'id': 47622,
#       'url': 'http://www.tvmaze.com/episodes/47622/gilmore-girls-7x05-the-great-stink',
#       'name': 'The Great Stink',
#       'season': 7,
#       'number': 5,
#       'airdate': '2006-10-24',
#       'airtime': '21:00',
#       'airstamp': '2006-10-25T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>A dill wind. A derailed trainload of pickles lends Stars Hollow a certain air. And that's not the only sour situation: Lorelai and Christopher quarrel about his ex's sudden devotion to motherhood.</p>"},
#      {'id': 47623,
#       'url': 'http://www.tvmaze.com/episodes/47623/gilmore-girls-7x06-go-bulldogs',
#       'name': 'Go, Bulldogs!',
#       'season': 7,
#       'number': 6,
#       'airdate': '2006-11-07',
#       'airtime': '21:00',
#       'airstamp': '2006-11-08T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>A perfect autumn weekend finds Lorelai and Christopher attending Parents' Weekend at Yale - with Richard and Emily. Meanwhile, Luke has a date with a vegan. Yeah, that's going to work out.</p>"},
#      {'id': 47624,
#       'url': 'http://www.tvmaze.com/episodes/47624/gilmore-girls-7x07-french-twist',
#       'name': 'French Twist',
#       'season': 7,
#       'number': 7,
#       'airdate': '2006-11-14',
#       'airtime': '21:00',
#       'airstamp': '2006-11-15T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>In Stars Hollow, Rory is clueless about her future. In Paris, Christopher has his and Lorelai's future all mapped out. In panic mode, Lane discovers her future: She's expecting twins.</p>"},
#      {'id': 47625,
#       'url': 'http://www.tvmaze.com/episodes/47625/gilmore-girls-7x08-introducing-lorelai-planetarium',
#       'name': 'Introducing Lorelai Planetarium',
#       'season': 7,
#       'number': 8,
#       'airdate': '2006-11-21',
#       'airtime': '21:00',
#       'airstamp': '2006-11-22T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Christopher knows exactly how Rory will feel when he and Lorelai tell her they're married: happy! They tell her. How does she feel? Not happy. And when April falls ill, Luke calls the one person he can depend on: Lorelai.</p>"},
#      {'id': 47626,
#       'url': 'http://www.tvmaze.com/episodes/47626/gilmore-girls-7x09-knit-people-knit',
#       'name': 'Knit, People, Knit!',
#       'season': 7,
#       'number': 9,
#       'airdate': '2006-11-28',
#       'airtime': '21:00',
#       'airstamp': '2006-11-29T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Odd man out! Eager to make Christopher part of Stars Hollow community, Lorelai sets him up on a man date with Jackson. After holding his newborn niece, Luke makes a big decision about April.</p>'},
#      {'id': 47627,
#       'url': 'http://www.tvmaze.com/episodes/47627/gilmore-girls-7x10-merry-fisticuffs',
#       'name': 'Merry Fisticuffs',
#       'season': 7,
#       'number': 10,
#       'airdate': '2006-12-05',
#       'airtime': '21:00',
#       'airstamp': '2006-12-06T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Peace on Earth. The Yuletide finds everyone spoiling for a fight: Rory vs. Logan, Rory vs. Lucy, Luke vs. Anna, Luke vs. Christopher, Lorelai vs. Christopher, and Kirk vs. the local middle-school kids.</p>'},
#      {'id': 47628,
#       'url': 'http://www.tvmaze.com/episodes/47628/gilmore-girls-7x11-santas-secret-stuff',
#       'name': "Santa's Secret Stuff",
#       'season': 7,
#       'number': 11,
#       'airdate': '2007-01-23',
#       'airtime': '21:00',
#       'airstamp': '2007-01-24T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Big problem: an XXL-sized Lane fears motherhood means the end of personhood. Big secret: Lorelai writes Luke a character reference for his custody case...but doesn't tell Christopher.</p>"},
#      {'id': 47629,
#       'url': 'http://www.tvmaze.com/episodes/47629/gilmore-girls-7x12-to-whom-it-may-concern',
#       'name': 'To Whom It May Concern',
#       'season': 7,
#       'number': 12,
#       'airdate': '2007-01-30',
#       'airtime': '21:00',
#       'airstamp': '2007-01-31T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>This is all a new marriage needs : Christopher finds the reference Lorelai wrote for Luke...and freaks. And what more could an established marriage need? Jackson and Sookie find out.</p>'},
#      {'id': 47630,
#       'url': 'http://www.tvmaze.com/episodes/47630/gilmore-girls-7x13-id-rather-be-in-philadelphia',
#       'name': "I'd Rather Be in Philadelphia",
#       'season': 7,
#       'number': 13,
#       'airdate': '2007-02-06',
#       'airtime': '21:00',
#       'airstamp': '2007-02-07T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>After Richard's heart attack, Lorelai, Rory and Emily anxiously await news in the hospital waiting room. Then Logan arrives. Then Luke. But - despite frantic repeated phone calls from Lorelai - not Christopher.</p>"},
#      {'id': 47631,
#       'url': 'http://www.tvmaze.com/episodes/47631/gilmore-girls-7x14-farewell-my-pet',
#       'name': 'Farewell, My Pet',
#       'season': 7,
#       'number': 14,
#       'airdate': '2007-02-13',
#       'airtime': '21:00',
#       'airstamp': '2007-02-14T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>When one of Michel's beloved chows goes to that great doggy house in the sky, Lorelai organizes a memorial service. Maybe she ought to organize another memorial service, too - for her marriage.</p>"},
#      {'id': 47632,
#       'url': 'http://www.tvmaze.com/episodes/47632/gilmore-girls-7x15-im-a-kayak-hear-me-roar',
#       'name': "I'm a Kayak, Hear Me Roar",
#       'season': 7,
#       'number': 15,
#       'airdate': '2007-02-20',
#       'airtime': '21:00',
#       'airstamp': '2007-02-21T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Lorelai finally gets up the nerve to tell Emily that she and Christopher are phfffft. And Logan thought he bought an internet company. Instead his dreams of entrepreneurial glory bought the farm.</p>'},
#      {'id': 47633,
#       'url': 'http://www.tvmaze.com/episodes/47633/gilmore-girls-7x16-will-you-be-my-lorelai-gilmore',
#       'name': 'Will You Be My Lorelai Gilmore?',
#       'season': 7,
#       'number': 16,
#       'airdate': '2007-02-27',
#       'airtime': '21:00',
#       'airstamp': '2007-02-28T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Just before Lane's baby shower, Lorelai must mediate a Kim family grudge match. And Logan finally tells Rory that his business has gone belly-up...then takes off for Vegas with his old prankster buddies.</p>"},
#      {'id': 47634,
#       'url': 'http://www.tvmaze.com/episodes/47634/gilmore-girls-7x17-gilmore-girls-only',
#       'name': 'Gilmore Girls Only',
#       'season': 7,
#       'number': 17,
#       'airdate': '2007-03-06',
#       'airtime': '21:00',
#       'airstamp': '2007-03-07T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>All three Gilmore girls hit the road for North Carolina and Mia's wedding. With Lane due any minute, Zack turns to Luke for advice on being a dad. And - surprise! - Logan may be growing up at last.</p>"},
#      {'id': 47635,
#       'url': 'http://www.tvmaze.com/episodes/47635/gilmore-girls-7x18-hay-bale-maze',
#       'name': 'Hay Bale Maze',
#       'season': 7,
#       'number': 18,
#       'airdate': '2007-04-17',
#       'airtime': '21:00',
#       'airstamp': '2007-04-18T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Brief encounter: Stars Hollow's centerpiece attraction for the annual Spring Fling brings Lorelai and Luke face-to-face. And post-grad job hunting has Rory dithering in a most un-Rory-like manner.</p>"},
#      {'id': 47636,
#       'url': 'http://www.tvmaze.com/episodes/47636/gilmore-girls-7x19-its-just-like-riding-a-bike',
#       'name': "It's Just Like Riding a Bike",
#       'season': 7,
#       'number': 19,
#       'airdate': '2007-04-24',
#       'airtime': '21:00',
#       'airstamp': '2007-04-25T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Lorelai needs help shopping for a new car. Enter Luke. Paris decides that having a boyfriend complicates her grad-school decision. Exit Doyle.</p>'},
#      {'id': 47637,
#       'url': 'http://www.tvmaze.com/episodes/47637/gilmore-girls-7x20-lorelai-lorelai',
#       'name': 'Lorelai? Lorelai?',
#       'season': 7,
#       'number': 20,
#       'airdate': '2007-05-01',
#       'airtime': '21:00',
#       'airstamp': '2007-05-02T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>On karaoke night, a tipsy Lorelai take the stage to sing...and exposes her feelings for Luke. And Logan returns to Stars Hollow with a question for Lorelai.</p>'},
#      {'id': 47638,
#       'url': 'http://www.tvmaze.com/episodes/47638/gilmore-girls-7x21-unto-the-breach',
#       'name': 'Unto the Breach',
#       'season': 7,
#       'number': 21,
#       'airdate': '2007-05-08',
#       'airtime': '21:00',
#       'airstamp': '2007-05-09T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Pomp and circumstances. Rory's graduation brings the expected: tears, hugs, a Richard-and-Emily party, a communal bottle of champagne and a diploma. And it brings the unexpected - a heartfelt suggestion from Logan.</p>"},
#      {'id': 47639,
#       'url': 'http://www.tvmaze.com/episodes/47639/gilmore-girls-7x22-bon-voyage',
#       'name': 'Bon Voyage',
#       'season': 7,
#       'number': 22,
#       'airdate': '2007-05-15',
#       'airtime': '21:00',
#       'airstamp': '2007-05-16T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>An exciting job offer for Rory and a beneficent gesture from Luke add up to a big surprise party, where every Stars Hollow friend, neighbor and eccentric exuberantly celebrates the Gilmore girls.</p>'}]},
#    {'id': 34116,
#     'url': 'http://www.tvmaze.com/seasons/34116/gilmore-girls-season-8',
#     'number': 8,
#     'name': 'Gilmore Girls: A Year in the Life',
#     'episodeOrder': 4,
#     'premiereDate': None,
#     'endDate': None,
#     'network': None,
#     'webChannel': {'id': 1, 'name': 'Netflix', 'country': None},
#     'image': None,
#     'summary': '',
#     'episodes': []}]}]

# %% [markdown]
# If the JSON is read in from a URL using the `requests` library, then the JSON object can also be accessed directly from the response.

# %%
# This code is equivalent to the above code.
data_shows = response.json()
data_shows
# Out:
# [{'id': 139,
#   'url': 'http://www.tvmaze.com/shows/139/girls',
#   'name': 'Girls',
#   'type': 'Scripted',
#   'language': 'English',
#   'genres': ['Drama', 'Romance'],
#   'status': 'Ended',
#   'runtime': 30,
#   'premiered': '2012-04-15',
#   'officialSite': 'http://www.hbo.com/girls',
#   'schedule': {'time': '22:00', 'days': ['Sunday']},
#   'rating': {'average': 6.9},
#   'weight': 75,
#   'network': {'id': 8,
#    'name': 'HBO',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'}},
#   'webChannel': None,
#   'externals': {'tvrage': 30124, 'thetvdb': 220411, 'imdb': 'tt1723816'},
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/31/78286.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/31/78286.jpg'},
#   'summary': '<p>This Emmy winning series is a comic look at the assorted humiliations and rare triumphs of a group of girls in their 20s.</p>',
#   'updated': 1577601053,
#   'cast': [{'person': {'id': 27410,
#      'url': 'http://www.tvmaze.com/people/27410/lena-dunham',
#      'name': 'Lena Dunham',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1986-05-13',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7597.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7597.jpg'}},
#     'character': {'id': 36886,
#      'url': 'http://www.tvmaze.com/characters/36886/girls-hannah-horvath',
#      'name': 'Hannah Horvath',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1954.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1954.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 11102,
#      'url': 'http://www.tvmaze.com/people/11102/allison-williams',
#      'name': 'Allison Williams',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1988-04-13',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7628.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7628.jpg'}},
#     'character': {'id': 36887,
#      'url': 'http://www.tvmaze.com/characters/36887/girls-marnie-michaels',
#      'name': 'Marnie Michaels',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1955.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1955.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 27411,
#      'url': 'http://www.tvmaze.com/people/27411/jemima-kirke',
#      'name': 'Jemima Kirke',
#      'country': {'name': 'United Kingdom',
#       'code': 'GB',
#       'timezone': 'Europe/London'},
#      'birthday': '1985-04-26',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7631.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7631.jpg'}},
#     'character': {'id': 36888,
#      'url': 'http://www.tvmaze.com/characters/36888/girls-jessa-johansson',
#      'name': 'Jessa Johansson',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1957.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1957.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 16405,
#      'url': 'http://www.tvmaze.com/people/16405/zosia-mamet',
#      'name': 'Zosia Mamet',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1988-02-02',
#      'deathday': None,
#      'gender': 'Female',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7634.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7634.jpg'}},
#     'character': {'id': 36889,
#      'url': 'http://www.tvmaze.com/characters/36889/girls-shoshanna-shapiro',
#      'name': 'Shoshanna Shapiro',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1956.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1956.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 24858,
#      'url': 'http://www.tvmaze.com/people/24858/adam-driver',
#      'name': 'Adam Driver',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1983-11-19',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/170/425572.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/170/425572.jpg'}},
#     'character': {'id': 36890,
#      'url': 'http://www.tvmaze.com/characters/36890/girls-adam-sackler',
#      'name': 'Adam Sackler',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1959.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1959.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 24970,
#      'url': 'http://www.tvmaze.com/people/24970/alex-karpovsky',
#      'name': 'Alex Karpovsky',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1975-09-23',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7638.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7638.jpg'}},
#     'character': {'id': 36891,
#      'url': 'http://www.tvmaze.com/characters/36891/girls-ray-ploshansky',
#      'name': 'Ray Ploshansky',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1958.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1958.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 27412,
#      'url': 'http://www.tvmaze.com/people/27412/andrew-rannells',
#      'name': 'Andrew Rannells',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1978-08-23',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1960.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1960.jpg'}},
#     'character': {'id': 36892,
#      'url': 'http://www.tvmaze.com/characters/36892/girls-elijah-krantz',
#      'name': 'Elijah Krantz',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38615.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38615.jpg'}},
#     'self': False,
#     'voice': False},
#    {'person': {'id': 4896,
#      'url': 'http://www.tvmaze.com/people/4896/ebon-moss-bachrach',
#      'name': 'Ebon Moss-Bachrach',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'},
#      'birthday': '1977-03-19',
#      'deathday': None,
#      'gender': 'Male',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/147/369955.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/147/369955.jpg'}},
#     'character': {'id': 37030,
#      'url': 'http://www.tvmaze.com/characters/37030/girls-desi',
#      'name': 'Desi',
#      'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38616.jpg',
#       'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38616.jpg'}},
#     'self': False,
#     'voice': False}],
#   'seasons': [{'id': 650,
#     'url': 'http://www.tvmaze.com/seasons/650/girls-season-1',
#     'number': 1,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2012-04-15',
#     'endDate': '2012-06-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114492.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114492.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10820,
#       'url': 'http://www.tvmaze.com/episodes/10820/girls-1x01-pilot',
#       'name': 'Pilot',
#       'season': 1,
#       'number': 1,
#       'airdate': '2012-04-15',
#       'airtime': '22:30',
#       'airstamp': '2012-04-16T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38639.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38639.jpg'},
#       'summary': "<p>In the premiere of this comedy about twentysomething women navigating their way through life in New York, Hannah swings and misses at two curves when her parents rescind their financial support and she loses her unpaid internship. Meanwhile, Hannah's roommate, Marnie, throws a dinner party for their nomadic friend Jessa, who's returned from yet another journey.</p>"},
#      {'id': 10821,
#       'url': 'http://www.tvmaze.com/episodes/10821/girls-1x02-vagina-panic',
#       'name': 'Vagina Panic',
#       'season': 1,
#       'number': 2,
#       'airdate': '2012-04-22',
#       'airtime': '22:30',
#       'airstamp': '2012-04-23T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38640.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38640.jpg'},
#       'summary': "<p>An appointment at a women's clinic doesn't go according to Marnie's detailed plans, mostly because Jessa will find any reason not to show up. Meanwhile, Hannah is preoccupied by an STD scare; and Shoshanna makes a startling revelation.</p>"},
#      {'id': 10822,
#       'url': 'http://www.tvmaze.com/episodes/10822/girls-1x03-all-adventurous-women-do',
#       'name': 'All Adventurous Women Do',
#       'season': 1,
#       'number': 3,
#       'airdate': '2012-04-29',
#       'airtime': '22:30',
#       'airstamp': '2012-04-30T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38641.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38641.jpg'},
#       'summary': '<p>Hannah contacts her college boyfriend to find out how she contracted an STD, but learns perhaps even more shocking news from him. Meanwhile, Marnie is smitten with a pretentious artist at a gallery opening; and Jessa lands a babysitting job.</p>'},
#      {'id': 10823,
#       'url': 'http://www.tvmaze.com/episodes/10823/girls-1x04-hannahs-diary',
#       'name': "Hannah's Diary",
#       'season': 1,
#       'number': 4,
#       'airdate': '2012-05-06',
#       'airtime': '22:30',
#       'airstamp': '2012-05-07T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38642.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38642.jpg'},
#       'summary': "<p>Adam's risqué text message sends Hannah over the edge; Jessa gets distracted while babysitting; Shoshanna reunites with a guy she knew at camp; Ray and Charlie stick their noses where they don't belong.</p>"},
#      {'id': 10824,
#       'url': 'http://www.tvmaze.com/episodes/10824/girls-1x05-hard-being-easy',
#       'name': 'Hard Being Easy',
#       'season': 1,
#       'number': 5,
#       'airdate': '2012-05-13',
#       'airtime': '22:30',
#       'airstamp': '2012-05-14T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38643.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38643.jpg'},
#       'summary': '<p>Hannah tries a different tack with her boss to counter his inappropriate office behavior—she propositions him. Meanwhile, Marnie does some soul-searching about her relationship with Charlie; and Jessa wants the last word with an ex.</p>'},
#      {'id': 10825,
#       'url': 'http://www.tvmaze.com/episodes/10825/girls-1x06-the-return',
#       'name': 'The Return',
#       'season': 1,
#       'number': 6,
#       'airdate': '2012-05-20',
#       'airtime': '22:30',
#       'airstamp': '2012-05-21T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38644.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38644.jpg'},
#       'summary': '<p>Hannah visits her parents in Michigan for their 30th anniversary, and winds up going on a date to a fund-raiser for a local family who suffered a tragic loss.</p>'},
#      {'id': 10826,
#       'url': 'http://www.tvmaze.com/episodes/10826/girls-1x07-welcome-to-bushwick-aka-the-crackcident',
#       'name': 'Welcome to Bushwick a.k.a. The Crackcident',
#       'season': 1,
#       'number': 7,
#       'airdate': '2012-05-27',
#       'airtime': '22:30',
#       'airstamp': '2012-05-28T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38645.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38645.jpg'},
#       'summary': "<p>At a raging party in the Bushwick section of Brooklyn, Hannah sees a different side of Adam; Jessa lures the sender of an anonymous text message; Marnie finds out what Charlie's been up to for the past two weeks; and Shoshanna gets a hand from Ray when she needs it most.</p>"},
#      {'id': 10827,
#       'url': 'http://www.tvmaze.com/episodes/10827/girls-1x08-weirdos-need-girlfriends-too',
#       'name': 'Weirdos Need Girlfriends Too',
#       'season': 1,
#       'number': 8,
#       'airdate': '2012-06-03',
#       'airtime': '22:40',
#       'airstamp': '2012-06-04T02:40:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38646.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38646.jpg'},
#       'summary': "<p>Marnie and Jessa bond and meet an eligible bachelor who's new in town; Hannah gets to know Adam in ways she could not have imagined.</p>"},
#      {'id': 10828,
#       'url': 'http://www.tvmaze.com/episodes/10828/girls-1x09-leave-me-alone',
#       'name': 'Leave Me Alone',
#       'season': 1,
#       'number': 9,
#       'airdate': '2012-06-10',
#       'airtime': '22:30',
#       'airstamp': '2012-06-11T02:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38647.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38647.jpg'},
#       'summary': "<p>Hannah's resentment of an old rival's literary success leads her to grudgingly accept an invitation to a reading hosted by her former professor, a pair of setbacks about which she could usually complain to Marnie—until now. Meanwhile, Jessa gets a surprise visit from her former boss; and Shoshanna schedules a date with someone she met online.</p>"},
#      {'id': 10829,
#       'url': 'http://www.tvmaze.com/episodes/10829/girls-1x10-she-did',
#       'name': 'She Did',
#       'season': 1,
#       'number': 10,
#       'airdate': '2012-06-17',
#       'airtime': '22:00',
#       'airstamp': '2012-06-18T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38648.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38648.jpg'},
#       'summary': '<p>In the first-season finale, Jessa brings everyone together for a "mystery party," but other surprises are in store when Hannah misjudges Adam\'s commitment; Marnie tries her free-spirited side on for size; and Shoshanna\'s quirkiness impresses a suitor.</p>'}]},
#    {'id': 651,
#     'url': 'http://www.tvmaze.com/seasons/651/girls-season-2',
#     'number': 2,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2013-01-13',
#     'endDate': '2013-03-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114491.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114491.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10830,
#       'url': 'http://www.tvmaze.com/episodes/10830/girls-2x01-its-about-time',
#       'name': "It's About Time",
#       'season': 2,
#       'number': 1,
#       'airdate': '2013-01-13',
#       'airtime': '21:00',
#       'airstamp': '2013-01-14T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38649.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38649.jpg'},
#       'summary': "<p>Hannah throws a housewarming party with brand-new roommate Elijah, but it's hard to move on when she's still playing nurse to Adam. Marnie gets bad news at work and a visit from her mom ; Shoshanna avoids Ray at the party; and sun-kissed Jessa returns from her honeymoon.</p>"},
#      {'id': 10831,
#       'url': 'http://www.tvmaze.com/episodes/10831/girls-2x02-i-get-ideas',
#       'name': 'I Get Ideas',
#       'season': 2,
#       'number': 2,
#       'airdate': '2013-01-20',
#       'airtime': '21:00',
#       'airstamp': '2013-01-21T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38650.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38650.jpg'},
#       'summary': '<p>Hannah gets unsolicited musical attention from heartbroken Adam and displeasing opinions on her writing from Sandy. Elijah questions his sexuality; Marnie makes a career compromise when her curatorial dreams are crushed; Jessa revels in married life; Shoshanna and Ray make magic; and Elijah and Marnie harbor a secret.</p>'},
#      {'id': 10832,
#       'url': 'http://www.tvmaze.com/episodes/10832/girls-2x03-bad-friend',
#       'name': 'Bad Friend',
#       'season': 2,
#       'number': 3,
#       'airdate': '2013-01-27',
#       'airtime': '21:00',
#       'airstamp': '2013-01-28T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38651.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38651.jpg'},
#       'summary': '<p>On a freelance writing assignment to get out of her comfort zone, Hannah befriends the junkie downstairs and parties hard with Elijah, who reveals an explosive secret. Meanwhile, Marnie has a long awaited run-in with artist Booth Jonathan.</p>'},
#      {'id': 10833,
#       'url': 'http://www.tvmaze.com/episodes/10833/girls-2x04-its-a-shame-about-ray',
#       'name': "It's a Shame About Ray",
#       'season': 2,
#       'number': 4,
#       'airdate': '2013-02-02',
#       'airtime': '22:05',
#       'airstamp': '2013-02-03T03:05:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38652.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38652.jpg'},
#       'summary': "<p>Hannah hosts a grown-up dinner party to celebrate her writing gig, but her friends' behavior doesn't live up to the setting. Marnie and Audrey square off; Shoshanna realizes she has inadvertently entered a new phase with Ray ; Jessa meets Thomas-John's parents.</p>"},
#      {'id': 10834,
#       'url': 'http://www.tvmaze.com/episodes/10834/girls-2x05-one-mans-trash',
#       'name': "One Man's Trash",
#       'season': 2,
#       'number': 5,
#       'airdate': '2013-02-10',
#       'airtime': '21:00',
#       'airstamp': '2013-02-11T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38653.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38653.jpg'},
#       'summary': '<p>Hannah is surprised to find herself drawn to a good-looking 42-year-old doctor and the trappings of his conventionally successful adult life.</p>'},
#      {'id': 10835,
#       'url': 'http://www.tvmaze.com/episodes/10835/girls-2x06-boys',
#       'name': 'Boys',
#       'season': 2,
#       'number': 6,
#       'airdate': '2013-02-17',
#       'airtime': '21:00',
#       'airstamp': '2013-02-18T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38654.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38654.jpg'},
#       'summary': "<p>Hannah signs an e-book deal with a dauntingly tight deadline; Marnie plays hostess for Booth Jonathan's art party; Adam coaxes Ray to go on a Staten Island adventure; a depressed Jessa crashes with Hannah.</p>"},
#      {'id': 10836,
#       'url': 'http://www.tvmaze.com/episodes/10836/girls-2x07-video-games',
#       'name': 'Video Games',
#       'season': 2,
#       'number': 7,
#       'airdate': '2013-02-24',
#       'airtime': '21:00',
#       'airstamp': '2013-02-25T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38655.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38655.jpg'},
#       'summary': "<p>Hannah accompanies Jessa upstate to visit Jessa's estranged father, his new-age girlfriend and her virginal teenage son, Frank.</p>"},
#      {'id': 10837,
#       'url': 'http://www.tvmaze.com/episodes/10837/girls-2x08-its-back',
#       'name': "It's Back",
#       'season': 2,
#       'number': 8,
#       'airdate': '2013-03-03',
#       'airtime': '21:00',
#       'airstamp': '2013-03-04T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38656.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38656.jpg'},
#       'summary': "<p>Hannah tries to hide mounting anxiety about her book from her visiting parents. Marnie is stunned to learn that Charlie has started a successful app company; at AA, Adam meets a boisterous woman who coaxes him into dating her daughter, Natalia ; and Ray's aversion to college parties gives Shoshanna pause.</p>"},
#      {'id': 10838,
#       'url': 'http://www.tvmaze.com/episodes/10838/girls-2x09-on-all-fours',
#       'name': 'On All Fours',
#       'season': 2,
#       'number': 9,
#       'airdate': '2013-03-10',
#       'airtime': '21:00',
#       'airstamp': '2013-03-11T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38657.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38657.jpg'},
#       'summary': "<p>Pressure from Hannah's aggressive publisher and a looming deadline further jeopardize her mental state. Adam and his new girlfriend have their first misunderstanding. At Charlie's work party, Shoshanna avoids Ray, and Marnie makes an unsettling step towards following her dreams.</p>"},
#      {'id': 10839,
#       'url': 'http://www.tvmaze.com/episodes/10839/girls-2x10-together',
#       'name': 'Together',
#       'season': 2,
#       'number': 10,
#       'airdate': '2013-03-17',
#       'airtime': '21:00',
#       'airstamp': '2013-03-18T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38658.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38658.jpg'},
#       'summary': "<p>To avoid being sued by her publisher, Hannah must write her book in a single day. Marnie misinterprets Charlie's intentions; Ray makes a career move that he hopes will impress Shoshanna.</p>"}]},
#    {'id': 652,
#     'url': 'http://www.tvmaze.com/seasons/652/girls-season-3',
#     'number': 3,
#     'name': '',
#     'episodeOrder': 12,
#     'premiereDate': '2014-01-12',
#     'endDate': '2014-03-23',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114490.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114490.jpg'},
#     'summary': None,
#     'episodes': [{'id': 10840,
#       'url': 'http://www.tvmaze.com/episodes/10840/girls-3x01-females-only',
#       'name': 'Females Only',
#       'season': 3,
#       'number': 1,
#       'airdate': '2014-01-12',
#       'airtime': '22:00',
#       'airstamp': '2014-01-13T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38595.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38595.jpg'},
#       'summary': "<p>Reeling after a nasty run-in with Natalia at Ray's new coffee and pizza place, Hannah and a reluctant Adam host dinner at their apartment with Marnie, who is living at home in New Jersey and still raw from her breakup with Charlie, and Shoshanna, who is alternating nights of sexual freedom with academia after her breakup with Ray. Meanwhile, Jessa pushes buttons, and new friend Jasper illuminates her daddy issues.</p>"},
#      {'id': 10841,
#       'url': 'http://www.tvmaze.com/episodes/10841/girls-3x02-truth-or-dare',
#       'name': 'Truth or Dare',
#       'season': 3,
#       'number': 2,
#       'airdate': '2014-01-12',
#       'airtime': '22:30',
#       'airstamp': '2014-01-13T03:30:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38596.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38596.jpg'},
#       'summary': "<p>Hannah, Shoshanna and Adam take a road trip to reunite with Jessa, leaving Marnie feeling left out as she moves into her own place. On the trip, Hannah looks futilely for writing inspiration in order to meet her editor's deadline.</p>"},
#      {'id': 10842,
#       'url': 'http://www.tvmaze.com/episodes/10842/girls-3x03-she-said-ok',
#       'name': 'She Said OK',
#       'season': 3,
#       'number': 3,
#       'airdate': '2014-01-19',
#       'airtime': '22:00',
#       'airstamp': '2014-01-20T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38597.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38597.jpg'},
#       'summary': "<p>When Caroline, Adam's eccentric and emotionally toxic sister, shows up unannounced, Hannah offers her a place to stay, despite Adam's protests. Marnie's control-freak tendencies reach full tilt at Hannah's 25th birthday party. Ray settles into his role as manager at the new restaurant, but has a harder time keeping cool around Shoshanna.</p>"},
#      {'id': 10843,
#       'url': 'http://www.tvmaze.com/episodes/10843/girls-3x04-dead-inside',
#       'name': 'Dead Inside',
#       'season': 3,
#       'number': 4,
#       'airdate': '2014-01-26',
#       'airtime': '22:00',
#       'airstamp': '2014-01-27T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38598.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38598.jpg'},
#       'summary': '<p>Hannah tries to process an untimely death, but seems more concerned about its impact on her eBook deal. Jessa tracks down an old friend she thought was dead. Marnie is horrified to discover a video Charlie posted online.</p>'},
#      {'id': 10844,
#       'url': 'http://www.tvmaze.com/episodes/10844/girls-3x05-only-child',
#       'name': 'Only Child',
#       'season': 3,
#       'number': 5,
#       'airdate': '2014-02-01',
#       'airtime': '22:00',
#       'airstamp': '2014-02-02T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38599.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38599.jpg'},
#       'summary': '<p>Hannah is thrilled to attend an event alongside members of the literary illuminati, until she learns that her eBook deal may be in jeopardy. Later, she tries to help Adam and Caroline work through their anger issues; Jessa makes positive changes; and Ray gives Marnie candid advice.</p>'},
#      {'id': 10845,
#       'url': 'http://www.tvmaze.com/episodes/10845/girls-3x06-free-snacks',
#       'name': 'Free Snacks',
#       'season': 3,
#       'number': 6,
#       'airdate': '2014-02-09',
#       'airtime': '22:00',
#       'airstamp': '2014-02-10T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38600.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38600.jpg'},
#       'summary': "<p>Hannah gets a job writing advertorials at GQ, but worries that the corporate environment will kill her creative mojo. Shoshanna rethinks her breakup in light of Ray's newfound success, while he and Marnie butt heads over lunch.</p>"},
#      {'id': 10846,
#       'url': 'http://www.tvmaze.com/episodes/10846/girls-3x07-beach-house',
#       'name': 'Beach House',
#       'season': 3,
#       'number': 7,
#       'airdate': '2014-02-16',
#       'airtime': '22:00',
#       'airstamp': '2014-02-17T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38601.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38601.jpg'},
#       'summary': "<p>During a Long Island weekend getaway with the girls, Hannah runs into Elijah and invites him and his friends to their beach house, hoping to take the pressure off of Marnie's rigorous schedule for honesty and healing.</p>"},
#      {'id': 10847,
#       'url': 'http://www.tvmaze.com/episodes/10847/girls-3x08-incidentals',
#       'name': 'Incidentals',
#       'season': 3,
#       'number': 8,
#       'airdate': '2014-02-23',
#       'airtime': '22:00',
#       'airstamp': '2014-02-24T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38602.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38602.jpg'},
#       'summary': "<p>During a GQ advertorial interview, Patti LuPone warns Hannah that Adam's new career path may cause unexpected problems. Meanwhile, Jessa's boredom at work is interrupted by a surprise visit from an old acquaintance. Later, Hannah is assigned to review the Gramercy Park Hotel, and the group celebrates good news with Adam's new friend Desi, whom Marnie finds particularly captivating.</p>"},
#      {'id': 10848,
#       'url': 'http://www.tvmaze.com/episodes/10848/girls-3x09-flo',
#       'name': 'Flo',
#       'season': 3,
#       'number': 9,
#       'airdate': '2014-03-02',
#       'airtime': '22:00',
#       'airstamp': '2014-03-03T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38603.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38603.jpg'},
#       'summary': '<p>While visiting her ailing grandmother in the hospital, Hannah is surprised by a strange request from her mother. Later, Hannah shares an uncomfortable drink with Rebecca, her overachieving med student cousin.</p>'},
#      {'id': 10849,
#       'url': 'http://www.tvmaze.com/episodes/10849/girls-3x10-role-play',
#       'name': 'Role-Play',
#       'season': 3,
#       'number': 10,
#       'airdate': '2014-03-09',
#       'airtime': '22:00',
#       'airstamp': '2014-03-10T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38604.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38604.jpg'},
#       'summary': "<p>Alarmed by Adam's indifference when she fails to come home after a night out with co-workers, Hannah worries that the spark may be gone in their relationship. Marnie begins working at Soo Jin's art gallery, though not in the role she expected; later, Desi helps her rediscover her voice. Shoshanna has a surprise for Jessa.</p>"},
#      {'id': 10850,
#       'url': 'http://www.tvmaze.com/episodes/10850/girls-3x11-i-saw-you',
#       'name': 'I Saw You',
#       'season': 3,
#       'number': 11,
#       'airdate': '2014-03-16',
#       'airtime': '22:00',
#       'airstamp': '2014-03-17T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38605.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38605.jpg'},
#       'summary': "<p>Hannah gets a glimpse of some harsh realities when she invites Elijah to join her in her quest to complete an unfinished assignment. Jessa searches for a job. Hannah, Shoshanna and Elijah attend Marnie's open-mic performance.</p>"},
#      {'id': 10851,
#       'url': 'http://www.tvmaze.com/episodes/10851/girls-3x12-two-plane-rides',
#       'name': 'Two Plane Rides',
#       'season': 3,
#       'number': 12,
#       'airdate': '2014-03-23',
#       'airtime': '22:00',
#       'airstamp': '2014-03-24T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38606.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38606.jpg'},
#       'summary': "<p>On the day of Adam's opening night, Hannah gets news that could change the direction of her career and their relationship. Marnie chooses an inopportune moment to divulge a secret to Shoshanna, who is dealing with her own unexpected news. Jessa's boss asks for an unusual favor.</p>"}]},
#    {'id': 653,
#     'url': 'http://www.tvmaze.com/seasons/653/girls-season-4',
#     'number': 4,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2015-01-11',
#     'endDate': '2015-03-22',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/45/114489.jpg',
#      'original': 'http://static.tvmaze.com/uploads/images/original_untouched/45/114489.jpg'},
#     'summary': None,
#     'episodes': [{'id': 40963,
#       'url': 'http://www.tvmaze.com/episodes/40963/girls-4x01-iowa',
#       'name': 'Iowa',
#       'season': 4,
#       'number': 1,
#       'airdate': '2015-01-11',
#       'airtime': '21:00',
#       'airstamp': '2015-01-12T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/15/38594.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38594.jpg'},
#       'summary': '<p>After a congratulatory dinner with her parents, Hannah and Adam pack up the last of her boxes and discuss "the plan" for their soon-to-be long-distance relationship. Marnie and Desi perform as part of a jazz brunch for a distracted crowd at a downtown restaurant. Shoshanna signs for her diploma with her parents, who make a bigger deal out of the event than she thinks necessary. Jessa is confronted by Beedie\'s daughter, Rickie, and later seems nonplussed by Hannah\'s impending departure.</p>'},
#      {'id': 93523,
#       'url': 'http://www.tvmaze.com/episodes/93523/girls-4x02-triggering',
#       'name': 'Triggering',
#       'season': 4,
#       'number': 2,
#       'airdate': '2015-01-18',
#       'airtime': '21:00',
#       'airstamp': '2015-01-19T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/7/19527.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/7/19527.jpg'},
#       'summary': "<p>In her first days as a grad student, Hannah discovers she can get more for her money, rent-wise, in Iowa. Later, during a video chat, she slyly prods Marnie for intel about Adam. At her first seminar, Hannah warns her fellow workshop writers that her piece might trigger some intense emotions - but doesn't get the feedback she had hoped for.</p>"},
#      {'id': 93524,
#       'url': 'http://www.tvmaze.com/episodes/93524/girls-4x03-female-author',
#       'name': 'Female Author',
#       'season': 4,
#       'number': 3,
#       'airdate': '2015-01-25',
#       'airtime': '21:00',
#       'airstamp': '2015-01-26T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/7/19836.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/7/19836.jpg'},
#       'summary': "<p>With only one class a week, Hannah finds herself doing a lot of nothing in her free time, while a visiting Elijah has become the social butterfly of Iowa. Ray gives Marnie a wake-up call about Desi's true intentions before their meeting with a record label. Shoshanna aces, then blows, a job interview. Adam unwittingly gets drawn into Jessa's chaotic web after an AA meeting. At a poets' party in Iowa, Hannah rants about the undue expectations put on women writers, and takes things too far in critiquing her classmates.</p>"},
#      {'id': 108508,
#       'url': 'http://www.tvmaze.com/episodes/108508/girls-4x04-cubbies',
#       'name': 'Cubbies',
#       'season': 4,
#       'number': 4,
#       'airdate': '2015-02-08',
#       'airtime': '21:00',
#       'airstamp': '2015-02-09T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/21344.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/21344.jpg'},
#       'summary': '<p>Hannah is confronted by her classmates after leaving a non-apology apology letter in their cubbies. After being rejected at yet another job interview, a frustrated Shoshanna spends a day with Ray. Creative and romantic tensions between Marnie and Desi reach a breaking point.</p>'},
#      {'id': 120501,
#       'url': 'http://www.tvmaze.com/episodes/120501/girls-4x05-sit-in',
#       'name': 'Sit-In',
#       'season': 4,
#       'number': 5,
#       'airdate': '2015-02-15',
#       'airtime': '21:00',
#       'airstamp': '2015-02-16T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/21752.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/21752.jpg'},
#       'summary': '<p>Friends try to help Hannah through a crisis; Hannah and Adam have an honest conversation about their relationship.</p><p><br><br></p>'},
#      {'id': 120502,
#       'url': 'http://www.tvmaze.com/episodes/120502/girls-4x06-close-up',
#       'name': 'Close-Up',
#       'season': 4,
#       'number': 6,
#       'airdate': '2015-02-22',
#       'airtime': '21:00',
#       'airstamp': '2015-02-23T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/8/22209.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/8/22209.jpg'},
#       'summary': '<p>Soul-searching leads Hannah to an epiphany. Meanwhile, another disastrous interview for Shoshanna ends in a positive; Ray attempts to solve his neighborhood noise issue at a community board meeting; Marnie and Desi disagree on how to define their sound; Adam is shocked by a revelation.</p>'},
#      {'id': 131210,
#       'url': 'http://www.tvmaze.com/episodes/131210/girls-4x07-ask-me-my-name',
#       'name': 'Ask Me My Name',
#       'season': 4,
#       'number': 7,
#       'airdate': '2015-03-01',
#       'airtime': '21:00',
#       'airstamp': '2015-03-02T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/22748.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/22748.jpg'},
#       'summary': "<p>Hannah goes for drinks with Fran, a new coworker, before attending an unusual art show. Later, she spends time alone with Mimi-Rose, while Adam is unnerved by Ace, Mimi-Rose's friend. Meanwhile, Shoshanna helps Ray with his community board election campaign.</p>"},
#      {'id': 131211,
#       'url': 'http://www.tvmaze.com/episodes/131211/girls-4x08-tad-loreen-avi-shanaz',
#       'name': 'Tad & Loreen & Avi & Shanaz',
#       'season': 4,
#       'number': 8,
#       'airdate': '2015-03-08',
#       'airtime': '21:00',
#       'airstamp': '2015-03-09T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/23230.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/23230.jpg'},
#       'summary': '<p>Hannah spends an afternoon with a new young friend; Marnie and Desi fight over money; Jessa gives Shoshanna advice on the art of seduction; Loreen and Tad have a tense dinner party with their friends Avi and Shanaz.</p>'},
#      {'id': 131212,
#       'url': 'http://www.tvmaze.com/episodes/131212/girls-4x09-daddy-issues',
#       'name': 'Daddy Issues',
#       'season': 4,
#       'number': 9,
#       'airdate': '2015-03-15',
#       'airtime': '21:00',
#       'airstamp': '2015-03-16T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/23943.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/23943.jpg'},
#       'summary': "<p>Hannah's maturity is called into question after she is confronted with a family dilemma; Jessa, Ace, Mimi-Rose and Adam have an awkward encounter; Marnie makes an announcement at Ray's campaign party.</p>"},
#      {'id': 131213,
#       'url': 'http://www.tvmaze.com/episodes/131213/girls-4x10-home-birth',
#       'name': 'Home Birth',
#       'season': 4,
#       'number': 10,
#       'airdate': '2015-03-22',
#       'airtime': '21:00',
#       'airstamp': '2015-03-23T01:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/9/24316.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/9/24316.jpg'},
#       'summary': "<p>Hannah, Adam and Jessa each try to convince Caroline and Laird to forgo their planned home birth. Shoshanna faces a crucial decision when presented with a unique job opportunity. After Marnie and Desi's meeting with a record label exec, Ray lets Desi know what he really thinks of him.</p>"}]},
#    {'id': 21282,
#     'url': 'http://www.tvmaze.com/seasons/21282/girls-season-5',
#     'number': 5,
#     'name': '',
#     'episodeOrder': 10,
#     'premiereDate': '2016-02-21',
#     'endDate': '2016-04-17',
#     'network': {'id': 8,
#      'name': 'HBO',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': None,
#     'summary': '',
#     'episodes': [{'id': 409239,
#       'url': 'http://www.tvmaze.com/episodes/409239/girls-5x01-wedding-day',
#       'name': 'Wedding Day',
#       'season': 5,
#       'number': 1,
#       'airdate': '2016-02-21',
#       'airtime': '22:00',
#       'airstamp': '2016-02-22T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/46/115008.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/46/115008.jpg'},
#       'summary': "<p>Marnie micromanages her upstate wedding to Desi while trying to maintain the facade of the breezy bride, and tasks Shoshanna with kicking out Fran, Hannah's date, so the girls can get ready. Banished to the boys' den, Fran has an awkward moment with Adam. A dejected Ray steps in to help Desi with his wedding-day jitters.</p>"},
#      {'id': 530407,
#       'url': 'http://www.tvmaze.com/episodes/530407/girls-5x02-good-man',
#       'name': 'Good Man',
#       'season': 5,
#       'number': 2,
#       'airdate': '2016-02-28',
#       'airtime': '22:00',
#       'airstamp': '2016-02-29T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/47/117623.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/47/117623.jpg'},
#       'summary': '<p>In New York, an erratic roommate leads Fran to move in with Hannah. Later, Hannah gets an urgent call from her dad, who is trying to navigate a new type of dating. After a run-in at an AA meeting, Adam and Jessa spend the day together. Ray fears that the new cafe across the street is hurting his business. Elijah is hit on by a famous news anchor.</p>'},
#      {'id': 530408,
#       'url': 'http://www.tvmaze.com/episodes/530408/girls-5x03-japan',
#       'name': 'Japan',
#       'season': 5,
#       'number': 3,
#       'airdate': '2016-03-06',
#       'airtime': '22:00',
#       'airstamp': '2016-03-07T03:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/47/119821.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/47/119821.jpg'},
#       'summary': '<p>Thriving at her new job in Japan, Shoshanna flirts with the boss, but reminds her work friends that she has a "kind of" boyfriend back in America. Hannah makes a shocking discovery on Fran\'s phone and struggles with how to react. After viewing Adam\'s performance on a TV police procedural, Jessa shares her insights into his character.</p>'},
#      {'id': 530409,
#       'url': 'http://www.tvmaze.com/episodes/530409/girls-5x04-old-loves',
#       'name': 'Old Loves',
#       'season': 5,
#       'number': 4,
#       'airdate': '2016-03-13',
#       'airtime': '22:00',
#       'airstamp': '2016-03-14T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/175/438842.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/175/438842.jpg'},
#       'summary': "<p>Hannah and Fran disagree about their teaching methods. Marnie fumes over Desi's decision to launch a major construction project in their studio apartment. Jessa pushes Hannah away over an awkward rice-pudding meetup. Elijah gets closer to Dill Harcourt.</p>"},
#      {'id': 530410,
#       'url': 'http://www.tvmaze.com/episodes/530410/girls-5x05-queen-for-two-days',
#       'name': 'Queen for Two Days',
#       'season': 5,
#       'number': 5,
#       'airdate': '2016-03-20',
#       'airtime': '22:00',
#       'airstamp': '2016-03-21T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/49/124456.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/49/124456.jpg'},
#       'summary': '<p>Hannah and her mom, Loreen, embark on a female-empowerment retreat, where Loreen hopes for clarity in her situation with Tad, and Hannah relishes time away from Fran. In Tokyo, Shoshanna enjoys her budding romance with Yoshi, and gets a surprise visitor from the U.S. Jessa meets up with her sister Minerva and asks for a favor.</p>'},
#      {'id': 530411,
#       'url': 'http://www.tvmaze.com/episodes/530411/girls-5x06-the-panic-in-central-park',
#       'name': 'The Panic in Central Park',
#       'season': 5,
#       'number': 6,
#       'airdate': '2016-03-27',
#       'airtime': '22:00',
#       'airstamp': '2016-03-28T02:00:00+00:00',
#       'runtime': 30,
#       'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_landscape/50/127185.jpg',
#        'original': 'http://static.tvmaze.com/uploads/images/original_untouched/50/127185.jpg'},
# ...
#      {'id': 47613,
#       'url': 'http://www.tvmaze.com/episodes/47613/gilmore-girls-6x18-the-real-paul-anka',
#       'name': 'The Real Paul Anka',
#       'season': 6,
#       'number': 18,
#       'airdate': '2006-04-11',
#       'airtime': '21:00',
#       'airstamp': '2006-04-12T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>In the city of Brotherly Love for April's field trip, Luke visits Jess at his electric publishing house. Someone else drops in: Rory, who's growing weary of Logan's drinking and pranks.</p>"},
#      {'id': 47614,
#       'url': 'http://www.tvmaze.com/episodes/47614/gilmore-girls-6x19-i-get-a-sidekick-out-of-you',
#       'name': 'I Get a Sidekick Out of You',
#       'season': 6,
#       'number': 19,
#       'airdate': '2006-04-18',
#       'airtime': '21:00',
#       'airstamp': '2006-04-19T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Lane and Zach's wedding day is a glorious mix of Buddhist and Christian, red silk and white satin, ceremonial awe and awesome partying. Lorelai suddenly realizes that Rory may be next...and she may be never.</p>"},
#      {'id': 47615,
#       'url': 'http://www.tvmaze.com/episodes/47615/gilmore-girls-6x20-super-cool-party-people',
#       'name': 'Super Cool Party People',
#       'season': 6,
#       'number': 20,
#       'airdate': '2006-04-25',
#       'airtime': '21:00',
#       'airstamp': '2006-04-26T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Major disaster: Logan, unconscious and badly hurt after a Life-and-Death-Brigade stunt goes wrong. Minor disaster: April's birthday celebration, hosted by wholehearted but fun-challenged Luke.</p>"},
#      {'id': 47616,
#       'url': 'http://www.tvmaze.com/episodes/47616/gilmore-girls-6x21-driving-miss-gilmore',
#       'name': 'Driving Miss Gilmore',
#       'season': 6,
#       'number': 21,
#       'airdate': '2006-05-02',
#       'airtime': '21:00',
#       'airstamp': '2006-05-03T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Lorelai chauffeurs Emily, who's recovering from eye surgery. Paris and Doyle take care of Logan, home from the hospital. And Sookie and Jackson try to play it cool as they dispose of bags and bags of pot someone grew on their property.</p>"},
#      {'id': 47617,
#       'url': 'http://www.tvmaze.com/episodes/47617/gilmore-girls-6x22-partings',
#       'name': 'Partings',
#       'season': 6,
#       'number': 22,
#       'airdate': '2006-05-09',
#       'airtime': '21:00',
#       'airstamp': '2006-05-10T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Goodbye. The town troubadour departs Stars Hollow for his Neil Young gig (creating a stampede of would-be troubadours to town). Logan graduates and leaves for London. And the Lorelai-Luke love affair may be ciao, adios, game over.</p>'}]},
#    {'id': 2086,
#     'url': 'http://www.tvmaze.com/seasons/2086/gilmore-girls-season-7',
#     'number': 7,
#     'name': '',
#     'episodeOrder': 22,
#     'premiereDate': '2006-09-26',
#     'endDate': '2007-05-15',
#     'network': {'id': 5,
#      'name': 'The CW',
#      'country': {'name': 'United States',
#       'code': 'US',
#       'timezone': 'America/New_York'}},
#     'webChannel': None,
#     'image': None,
#     'summary': '',
#     'episodes': [{'id': 47618,
#       'url': 'http://www.tvmaze.com/episodes/47618/gilmore-girls-7x01-the-long-morrow',
#       'name': 'The Long Morrow',
#       'season': 7,
#       'number': 1,
#       'airdate': '2006-09-26',
#       'airtime': '21:00',
#       'airstamp': '2006-09-27T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>From bed to worse. The morning after her blowup with Luke, Lorelai wakes up next to...well, someone else. And complications definitely ensue. Logan leaves Rory a puzzling parting gift.</p>'},
#      {'id': 47619,
#       'url': 'http://www.tvmaze.com/episodes/47619/gilmore-girls-7x02-thats-what-you-get-folks-for-makin-whoopee',
#       'name': "That's What You Get, Folks, for Makin' Whoopee",
#       'season': 7,
#       'number': 2,
#       'airdate': '2006-10-03',
#       'airtime': '21:00',
#       'airstamp': '2006-10-04T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Mexico sucks: Lane returns from her honeymoon with a flinty attitude towards sex, an interesting parasite and a souvenir. And Luke has a tough time telling TJ and Liz that his engagement is disengaged.</p>'},
#      {'id': 47620,
#       'url': 'http://www.tvmaze.com/episodes/47620/gilmore-girls-7x03-lorelais-first-cotillion',
#       'name': "Lorelai's First Cotillion",
#       'season': 7,
#       'number': 3,
#       'airdate': '2006-10-10',
#       'airtime': '21:00',
#       'airstamp': '2006-10-11T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>"What if I don\'t want to do what I want to do because I want to do it, but because they don\'t want me to?" Friday dinner and a pop tart get Lorelai wondering what has been motivating her actions for over 20 years.</p>'},
#      {'id': 47621,
#       'url': 'http://www.tvmaze.com/episodes/47621/gilmore-girls-7x04-s-wonderful-s-marvelous',
#       'name': "'S Wonderful, 'S Marvelous",
#       'season': 7,
#       'number': 4,
#       'airdate': '2006-10-17',
#       'airtime': '21:00',
#       'airstamp': '2006-10-18T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Togetherness: Lorelai and Christopher start dating. Rory meets some artistic new friends. April moves in with Luke short-term and Emily gets up close and personal with the local constabulary.</p>'},
#      {'id': 47622,
#       'url': 'http://www.tvmaze.com/episodes/47622/gilmore-girls-7x05-the-great-stink',
#       'name': 'The Great Stink',
#       'season': 7,
#       'number': 5,
#       'airdate': '2006-10-24',
#       'airtime': '21:00',
#       'airstamp': '2006-10-25T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>A dill wind. A derailed trainload of pickles lends Stars Hollow a certain air. And that's not the only sour situation: Lorelai and Christopher quarrel about his ex's sudden devotion to motherhood.</p>"},
#      {'id': 47623,
#       'url': 'http://www.tvmaze.com/episodes/47623/gilmore-girls-7x06-go-bulldogs',
#       'name': 'Go, Bulldogs!',
#       'season': 7,
#       'number': 6,
#       'airdate': '2006-11-07',
#       'airtime': '21:00',
#       'airstamp': '2006-11-08T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>A perfect autumn weekend finds Lorelai and Christopher attending Parents' Weekend at Yale - with Richard and Emily. Meanwhile, Luke has a date with a vegan. Yeah, that's going to work out.</p>"},
#      {'id': 47624,
#       'url': 'http://www.tvmaze.com/episodes/47624/gilmore-girls-7x07-french-twist',
#       'name': 'French Twist',
#       'season': 7,
#       'number': 7,
#       'airdate': '2006-11-14',
#       'airtime': '21:00',
#       'airstamp': '2006-11-15T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>In Stars Hollow, Rory is clueless about her future. In Paris, Christopher has his and Lorelai's future all mapped out. In panic mode, Lane discovers her future: She's expecting twins.</p>"},
#      {'id': 47625,
#       'url': 'http://www.tvmaze.com/episodes/47625/gilmore-girls-7x08-introducing-lorelai-planetarium',
#       'name': 'Introducing Lorelai Planetarium',
#       'season': 7,
#       'number': 8,
#       'airdate': '2006-11-21',
#       'airtime': '21:00',
#       'airstamp': '2006-11-22T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Christopher knows exactly how Rory will feel when he and Lorelai tell her they're married: happy! They tell her. How does she feel? Not happy. And when April falls ill, Luke calls the one person he can depend on: Lorelai.</p>"},
#      {'id': 47626,
#       'url': 'http://www.tvmaze.com/episodes/47626/gilmore-girls-7x09-knit-people-knit',
#       'name': 'Knit, People, Knit!',
#       'season': 7,
#       'number': 9,
#       'airdate': '2006-11-28',
#       'airtime': '21:00',
#       'airstamp': '2006-11-29T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Odd man out! Eager to make Christopher part of Stars Hollow community, Lorelai sets him up on a man date with Jackson. After holding his newborn niece, Luke makes a big decision about April.</p>'},
#      {'id': 47627,
#       'url': 'http://www.tvmaze.com/episodes/47627/gilmore-girls-7x10-merry-fisticuffs',
#       'name': 'Merry Fisticuffs',
#       'season': 7,
#       'number': 10,
#       'airdate': '2006-12-05',
#       'airtime': '21:00',
#       'airstamp': '2006-12-06T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Peace on Earth. The Yuletide finds everyone spoiling for a fight: Rory vs. Logan, Rory vs. Lucy, Luke vs. Anna, Luke vs. Christopher, Lorelai vs. Christopher, and Kirk vs. the local middle-school kids.</p>'},
#      {'id': 47628,
#       'url': 'http://www.tvmaze.com/episodes/47628/gilmore-girls-7x11-santas-secret-stuff',
#       'name': "Santa's Secret Stuff",
#       'season': 7,
#       'number': 11,
#       'airdate': '2007-01-23',
#       'airtime': '21:00',
#       'airstamp': '2007-01-24T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Big problem: an XXL-sized Lane fears motherhood means the end of personhood. Big secret: Lorelai writes Luke a character reference for his custody case...but doesn't tell Christopher.</p>"},
#      {'id': 47629,
#       'url': 'http://www.tvmaze.com/episodes/47629/gilmore-girls-7x12-to-whom-it-may-concern',
#       'name': 'To Whom It May Concern',
#       'season': 7,
#       'number': 12,
#       'airdate': '2007-01-30',
#       'airtime': '21:00',
#       'airstamp': '2007-01-31T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>This is all a new marriage needs : Christopher finds the reference Lorelai wrote for Luke...and freaks. And what more could an established marriage need? Jackson and Sookie find out.</p>'},
#      {'id': 47630,
#       'url': 'http://www.tvmaze.com/episodes/47630/gilmore-girls-7x13-id-rather-be-in-philadelphia',
#       'name': "I'd Rather Be in Philadelphia",
#       'season': 7,
#       'number': 13,
#       'airdate': '2007-02-06',
#       'airtime': '21:00',
#       'airstamp': '2007-02-07T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>After Richard's heart attack, Lorelai, Rory and Emily anxiously await news in the hospital waiting room. Then Logan arrives. Then Luke. But - despite frantic repeated phone calls from Lorelai - not Christopher.</p>"},
#      {'id': 47631,
#       'url': 'http://www.tvmaze.com/episodes/47631/gilmore-girls-7x14-farewell-my-pet',
#       'name': 'Farewell, My Pet',
#       'season': 7,
#       'number': 14,
#       'airdate': '2007-02-13',
#       'airtime': '21:00',
#       'airstamp': '2007-02-14T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>When one of Michel's beloved chows goes to that great doggy house in the sky, Lorelai organizes a memorial service. Maybe she ought to organize another memorial service, too - for her marriage.</p>"},
#      {'id': 47632,
#       'url': 'http://www.tvmaze.com/episodes/47632/gilmore-girls-7x15-im-a-kayak-hear-me-roar',
#       'name': "I'm a Kayak, Hear Me Roar",
#       'season': 7,
#       'number': 15,
#       'airdate': '2007-02-20',
#       'airtime': '21:00',
#       'airstamp': '2007-02-21T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Lorelai finally gets up the nerve to tell Emily that she and Christopher are phfffft. And Logan thought he bought an internet company. Instead his dreams of entrepreneurial glory bought the farm.</p>'},
#      {'id': 47633,
#       'url': 'http://www.tvmaze.com/episodes/47633/gilmore-girls-7x16-will-you-be-my-lorelai-gilmore',
#       'name': 'Will You Be My Lorelai Gilmore?',
#       'season': 7,
#       'number': 16,
#       'airdate': '2007-02-27',
#       'airtime': '21:00',
#       'airstamp': '2007-02-28T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Just before Lane's baby shower, Lorelai must mediate a Kim family grudge match. And Logan finally tells Rory that his business has gone belly-up...then takes off for Vegas with his old prankster buddies.</p>"},
#      {'id': 47634,
#       'url': 'http://www.tvmaze.com/episodes/47634/gilmore-girls-7x17-gilmore-girls-only',
#       'name': 'Gilmore Girls Only',
#       'season': 7,
#       'number': 17,
#       'airdate': '2007-03-06',
#       'airtime': '21:00',
#       'airstamp': '2007-03-07T02:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>All three Gilmore girls hit the road for North Carolina and Mia's wedding. With Lane due any minute, Zack turns to Luke for advice on being a dad. And - surprise! - Logan may be growing up at last.</p>"},
#      {'id': 47635,
#       'url': 'http://www.tvmaze.com/episodes/47635/gilmore-girls-7x18-hay-bale-maze',
#       'name': 'Hay Bale Maze',
#       'season': 7,
#       'number': 18,
#       'airdate': '2007-04-17',
#       'airtime': '21:00',
#       'airstamp': '2007-04-18T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Brief encounter: Stars Hollow's centerpiece attraction for the annual Spring Fling brings Lorelai and Luke face-to-face. And post-grad job hunting has Rory dithering in a most un-Rory-like manner.</p>"},
#      {'id': 47636,
#       'url': 'http://www.tvmaze.com/episodes/47636/gilmore-girls-7x19-its-just-like-riding-a-bike',
#       'name': "It's Just Like Riding a Bike",
#       'season': 7,
#       'number': 19,
#       'airdate': '2007-04-24',
#       'airtime': '21:00',
#       'airstamp': '2007-04-25T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>Lorelai needs help shopping for a new car. Enter Luke. Paris decides that having a boyfriend complicates her grad-school decision. Exit Doyle.</p>'},
#      {'id': 47637,
#       'url': 'http://www.tvmaze.com/episodes/47637/gilmore-girls-7x20-lorelai-lorelai',
#       'name': 'Lorelai? Lorelai?',
#       'season': 7,
#       'number': 20,
#       'airdate': '2007-05-01',
#       'airtime': '21:00',
#       'airstamp': '2007-05-02T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>On karaoke night, a tipsy Lorelai take the stage to sing...and exposes her feelings for Luke. And Logan returns to Stars Hollow with a question for Lorelai.</p>'},
#      {'id': 47638,
#       'url': 'http://www.tvmaze.com/episodes/47638/gilmore-girls-7x21-unto-the-breach',
#       'name': 'Unto the Breach',
#       'season': 7,
#       'number': 21,
#       'airdate': '2007-05-08',
#       'airtime': '21:00',
#       'airstamp': '2007-05-09T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': "<p>Pomp and circumstances. Rory's graduation brings the expected: tears, hugs, a Richard-and-Emily party, a communal bottle of champagne and a diploma. And it brings the unexpected - a heartfelt suggestion from Logan.</p>"},
#      {'id': 47639,
#       'url': 'http://www.tvmaze.com/episodes/47639/gilmore-girls-7x22-bon-voyage',
#       'name': 'Bon Voyage',
#       'season': 7,
#       'number': 22,
#       'airdate': '2007-05-15',
#       'airtime': '21:00',
#       'airstamp': '2007-05-16T01:00:00+00:00',
#       'runtime': 60,
#       'image': None,
#       'summary': '<p>An exciting job offer for Rory and a beneficent gesture from Luke add up to a big surprise party, where every Stars Hollow friend, neighbor and eccentric exuberantly celebrates the Gilmore girls.</p>'}]},
#    {'id': 34116,
#     'url': 'http://www.tvmaze.com/seasons/34116/gilmore-girls-season-8',
#     'number': 8,
#     'name': 'Gilmore Girls: A Year in the Life',
#     'episodeOrder': 4,
#     'premiereDate': None,
#     'endDate': None,
#     'network': None,
#     'webChannel': {'id': 1, 'name': 'Netflix', 'country': None},
#     'image': None,
#     'summary': '',
#     'episodes': []}]}]

# %% [markdown]
# Now let's investigate the JSON data that we just loaded, again being careful not to print out all of data. Let's start by looking at the top-level variables associated with each TV show.

# %%
show = data_shows[0] # data for the show "Girls"
show.keys()
# Out:
# dict_keys(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime', 'premiered', 'officialSite', 'schedule', 'rating', 'weight', 'network', 'webChannel', 'externals', 'image', 'summary', 'updated', 'cast', 'seasons'])

# %% [markdown]
# We see variables like **runtime** and **premiered** which contain a single value for each show.

# %%
show["runtime"]
# Out:
# 30

# %%
show["premiered"]
# Out:
# '2012-04-15'

# %% [markdown]
# But we also see "variables" like **schedule** and **network** which contain dictionaries.

# %%
show["schedule"]
# Out:
# {'time': '22:00', 'days': ['Sunday']}

# %%
show["network"]
# Out:
# {'id': 8,
#  'name': 'HBO',
#  'country': {'name': 'United States',
#   'code': 'US',
#   'timezone': 'America/New_York'}}

# %% [markdown]
# And we also see "variables" like **cast** and **seasons**, which contain multiple values.

# %%
show["cast"]
# Out:
# [{'person': {'id': 27410,
#    'url': 'http://www.tvmaze.com/people/27410/lena-dunham',
#    'name': 'Lena Dunham',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1986-05-13',
#    'deathday': None,
#    'gender': 'Female',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7597.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7597.jpg'}},
#   'character': {'id': 36886,
#    'url': 'http://www.tvmaze.com/characters/36886/girls-hannah-horvath',
#    'name': 'Hannah Horvath',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1954.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1954.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 11102,
#    'url': 'http://www.tvmaze.com/people/11102/allison-williams',
#    'name': 'Allison Williams',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1988-04-13',
#    'deathday': None,
#    'gender': 'Female',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7628.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7628.jpg'}},
#   'character': {'id': 36887,
#    'url': 'http://www.tvmaze.com/characters/36887/girls-marnie-michaels',
#    'name': 'Marnie Michaels',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1955.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1955.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 27411,
#    'url': 'http://www.tvmaze.com/people/27411/jemima-kirke',
#    'name': 'Jemima Kirke',
#    'country': {'name': 'United Kingdom',
#     'code': 'GB',
#     'timezone': 'Europe/London'},
#    'birthday': '1985-04-26',
#    'deathday': None,
#    'gender': 'Female',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7631.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7631.jpg'}},
#   'character': {'id': 36888,
#    'url': 'http://www.tvmaze.com/characters/36888/girls-jessa-johansson',
#    'name': 'Jessa Johansson',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1957.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1957.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 16405,
#    'url': 'http://www.tvmaze.com/people/16405/zosia-mamet',
#    'name': 'Zosia Mamet',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1988-02-02',
#    'deathday': None,
#    'gender': 'Female',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7634.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7634.jpg'}},
#   'character': {'id': 36889,
#    'url': 'http://www.tvmaze.com/characters/36889/girls-shoshanna-shapiro',
#    'name': 'Shoshanna Shapiro',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1956.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1956.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 24858,
#    'url': 'http://www.tvmaze.com/people/24858/adam-driver',
#    'name': 'Adam Driver',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1983-11-19',
#    'deathday': None,
#    'gender': 'Male',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/170/425572.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/170/425572.jpg'}},
#   'character': {'id': 36890,
#    'url': 'http://www.tvmaze.com/characters/36890/girls-adam-sackler',
#    'name': 'Adam Sackler',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1959.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1959.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 24970,
#    'url': 'http://www.tvmaze.com/people/24970/alex-karpovsky',
#    'name': 'Alex Karpovsky',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1975-09-23',
#    'deathday': None,
#    'gender': 'Male',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7638.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7638.jpg'}},
#   'character': {'id': 36891,
#    'url': 'http://www.tvmaze.com/characters/36891/girls-ray-ploshansky',
#    'name': 'Ray Ploshansky',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1958.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1958.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 27412,
#    'url': 'http://www.tvmaze.com/people/27412/andrew-rannells',
#    'name': 'Andrew Rannells',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1978-08-23',
#    'deathday': None,
#    'gender': 'Male',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1960.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1960.jpg'}},
#   'character': {'id': 36892,
#    'url': 'http://www.tvmaze.com/characters/36892/girls-elijah-krantz',
#    'name': 'Elijah Krantz',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38615.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38615.jpg'}},
#   'self': False,
#   'voice': False},
#  {'person': {'id': 4896,
#    'url': 'http://www.tvmaze.com/people/4896/ebon-moss-bachrach',
#    'name': 'Ebon Moss-Bachrach',
#    'country': {'name': 'United States',
#     'code': 'US',
#     'timezone': 'America/New_York'},
#    'birthday': '1977-03-19',
#    'deathday': None,
#    'gender': 'Male',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/147/369955.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/147/369955.jpg'}},
#   'character': {'id': 37030,
#    'url': 'http://www.tvmaze.com/characters/37030/girls-desi',
#    'name': 'Desi',
#    'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/15/38616.jpg',
#     'original': 'http://static.tvmaze.com/uploads/images/original_untouched/15/38616.jpg'}},
#   'self': False,
#   'voice': False}]

# %% [markdown]
# A "variable" (like **cast**) with multiple values is called a _repeated field_. A repeated field might itself contain a repeated field (e.g., each show has multiple seasons, and each season in turn has multiple episodes), creating a hierarchy of variables. Repeated fields are represented as lists or arrays in JSON.

# %% [markdown]
# Let's take a closer look at how each cast member is represented, by zooming in on the first cast member.

# %%
show["cast"][0]
# Out:
# {'person': {'id': 27410,
#   'url': 'http://www.tvmaze.com/people/27410/lena-dunham',
#   'name': 'Lena Dunham',
#   'country': {'name': 'United States',
#    'code': 'US',
#    'timezone': 'America/New_York'},
#   'birthday': '1986-05-13',
#   'deathday': None,
#   'gender': 'Female',
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/3/7597.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/3/7597.jpg'}},
#  'character': {'id': 36886,
#   'url': 'http://www.tvmaze.com/characters/36886/girls-hannah-horvath',
#   'name': 'Hannah Horvath',
#   'image': {'medium': 'http://static.tvmaze.com/uploads/images/medium_portrait/0/1954.jpg',
#    'original': 'http://static.tvmaze.com/uploads/images/original_untouched/0/1954.jpg'}},
#  'self': False,
#  'voice': False}

# %% [markdown]
# It appears that each cast member is itself a dictionary with four keys: **person** (i.e., the actor), **character**, **self**, and **voice**. The first two attributes are themselves dictionaries containing further information about the actor and the character, while the last two attributes are booleans.
#
# If we wanted to get the complete list of actors who appeared in these shows, excluding voice actors, we could traverse the levels using nested loops:

# %%
actors = []
for show in data_shows:
    for cast in show["cast"]:
        # exclude voice actors
        if not cast["voice"]:
            actors.append(cast["person"]["name"])

actors
# Out:
# ['Lena Dunham',
#  'Allison Williams',
#  'Jemima Kirke',
#  'Zosia Mamet',
#  'Adam Driver',
#  'Alex Karpovsky',
#  'Andrew Rannells',
#  'Ebon Moss-Bachrach',
#  'Bea Arthur',
#  'Betty White',
#  'Rue McClanahan',
#  'Estelle Getty',
#  'Christina Hendricks',
#  'Manny Montana',
#  'Reno Wilson',
#  'Matthew Lillard',
#  'Retta',
#  'Mae Whitman',
#  'Lidya Jewett',
#  'Izzy Stannard',
#  'Laura Chinn',
#  'Melanie Field',
#  'Laci Mosley',
#  'Patty Guggenheim',
#  'Annie LeBlanc',
#  'Brooke Butler',
#  'Hayden Summerall',
#  'Dylan Conrique',
#  'Riley Lewis',
#  'Carson Lueders',
#  'Mads Lewis',
#  'Indiana Massara',
#  'Greg Marks',
#  'Caden Conrique',
#  'Aliyah Moulden',
#  'Rush Holland Butler',
#  'Brec Bassinger',
#  'Jeremiah Perkins',
#  'Ariel Martin',
#  'Jenna Davis',
#  'Talin Silva',
#  'Kelsey Leon',
#  'Erin Reese DeJarnette',
#  'Matt Sato',
#  'Grant Knoche',
#  'Aidette Cancino',
#  'Luke Patrick Dodge',
#  'Kaylyn Slevin',
#  'Lily Chee',
#  'Isabel Marcus',
#  'Jay Ulloa',
#  'Paul Toweh',
#  'Sean Cavaliere',
#  'Marlhy Murphy',
#  'Hayley LeBlanc',
#  'Kathy Kiera Clarke',
#  "Jamie-Lee O'Donnell",
#  'Tommy Tiernan',
#  'Saoirse-Monica Jackson',
#  'Louisa Harland',
#  'Nicola Coughlan',
#  'Ian McElhinney',
#  'Dylan Llewellyn',
#  "Tara Lynne O'Neill",
#  'Siobhan McSweeney',
#  'Jamie Beamish',
#  'Peter Campion',
#  'Peter Outerbridge',
#  'Charlotte Hegele',
#  'Lisa Norton',
#  'Richard Fitzpatrick',
#  'Carlyn Burchell',
#  'Kassandra Santos',
#  'Meg Tilly',
#  'Brittany Allen',
#  'Anastasia Phillips',
#  'Ali Liebert',
#  'Kate Hennig',
#  'Jodi Balfour',
#  'Natasha Greenblatt',
#  'Antonio Cupo',
#  'Sebastian Pigott',
#  'Lauren Graham',
#  'Alexis Bledel',
#  'Scott Patterson',
#  'Melissa McCarthy',
#  'Kelly Bishop',
#  'Sean Gunn',
#  'Keiko Agena',
#  'Liza Weil',
#  'Yanic Truesdale',
#  'Edward Herrmann',
#  'Jared Padalecki',
#  'Matt Czuchry',
#  'Milo Ventimiglia',
#  'Chris Eigeman']

# %% [markdown]
# However, it is often easier to work with hierarchical data by first flattening it to a `DataFrame`.

# %% [markdown]
# # Flattening Hierarchical Data
#
# Although hierarchical data cannot be efficiently represented using a `DataFrame`, most questions do not require working with the full data. In these cases, it is helpful to first "flatten" the JSON data into a `DataFrame`.

# %% [markdown]
# For example, suppose we want to know the average runtime of shows. To answer this question, it suffices to work with a `DataFrame` with one row per show. We can use the `json_normalize()` function in `pandas` to flatten the data into a `DataFrame` of this form.

# %%
import pandas as pd

df_shows = pd.json_normalize(data_shows)
df_shows
# Out:
#       id                                                url
# 0    139              http://www.tvmaze.com/shows/139/girls  \
# 1    722   http://www.tvmaze.com/shows/722/the-golden-girls
# 2  23542       http://www.tvmaze.com/shows/23542/good-girls
# 3   6771  http://www.tvmaze.com/shows/6771/the-powerpuff...
# 4  42726    http://www.tvmaze.com/shows/42726/florida-girls
# 5  32087    http://www.tvmaze.com/shows/32087/chicken-girls
# 6  33320      http://www.tvmaze.com/shows/33320/derry-girls
# 7   1955  http://www.tvmaze.com/shows/1955/the-powerpuff...
# 8   1073        http://www.tvmaze.com/shows/1073/bomb-girls
# 9    525      http://www.tvmaze.com/shows/525/gilmore-girls
#
#                   name       type language                             genres
# 0                Girls   Scripted  English                   [Drama, Romance]  \
# 1     The Golden Girls   Scripted  English                    [Drama, Comedy]
# 2           Good Girls   Scripted  English             [Drama, Comedy, Crime]
# 3  The Powerpuff Girls  Animation  English  [Comedy, Action, Science-Fiction]
# 4        Florida Girls   Scripted  English                           [Comedy]
# 5        Chicken Girls   Scripted  English           [Drama, Children, Music]
# 6          Derry Girls   Scripted  English                           [Comedy]
# 7  The Powerpuff Girls  Animation  English          [Action, Children, Crime]
# 8           Bomb Girls   Scripted  English              [Drama, Romance, War]
# 9        Gilmore Girls   Scripted  English           [Drama, Comedy, Romance]
#
#     status  runtime   premiered
# 0    Ended       30  2012-04-15  \
# 1    Ended       30  1985-09-14
# 2  Running       60  2018-02-26
# 3  Running       15  2016-04-04
# 4  Running       30  2019-07-10
# 5  Running       16  2017-09-05
# 6  Running       30  2018-01-04
# 7    Ended       30  1998-11-18
# 8    Ended       60  2012-01-04
# 9    Ended       60  2000-10-05
#
#                                         officialSite  ...  externals.thetvdb
# 0                           http://www.hbo.com/girls  ...             220411  \
# 1                                               None  ...              71292
# 2               https://www.nbc.com/good-girls?nbc=1  ...             328577
# 3  https://www.cartoonnetwork.com/video/powerpuff...  ...             307473
# 4                     https://poptv.com/floridagirls  ...             363682
# 5  https://www.youtube.com/playlist?list=PLVewHiZ...  ...             339854
# 6     http://www.channel4.com/programmes/derry-girls  ...             338903
# 7                                               None  ...              76200
# 8                                               None  ...             254378
# 9                                               None  ...              76568
#
#    externals.imdb                                       image.medium
# 0       tt1723816  http://static.tvmaze.com/uploads/images/medium...  \
# 1       tt0088526  http://static.tvmaze.com/uploads/images/medium...
# 2       tt6474378  http://static.tvmaze.com/uploads/images/medium...
# 3       tt4718304  http://static.tvmaze.com/uploads/images/medium...
# 4       tt8548870  http://static.tvmaze.com/uploads/images/medium...
# 5            None  http://static.tvmaze.com/uploads/images/medium...
# 6       tt7120662  http://static.tvmaze.com/uploads/images/medium...
# 7       tt0175058  http://static.tvmaze.com/uploads/images/medium...
# 8       tt1955311  http://static.tvmaze.com/uploads/images/medium...
# 9       tt0238784  http://static.tvmaze.com/uploads/images/medium...
#
#                                       image.original network webChannel.id
# 0  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN  \
# 1  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 2  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 3  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 4  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 5  http://static.tvmaze.com/uploads/images/origin...     NaN         274.0
# 6  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 7  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 8  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
# 9  http://static.tvmaze.com/uploads/images/origin...     NaN           NaN
#
#   webChannel.name webChannel.country.name  webChannel.country.code
# 0             NaN                     NaN                      NaN  \
# 1             NaN                     NaN                      NaN
# 2             NaN                     NaN                      NaN
# 3             NaN                     NaN                      NaN
# 4             NaN                     NaN                      NaN
# 5            Brat           United States                       US
# 6             NaN                     NaN                      NaN
# 7             NaN                     NaN                      NaN
# 8             NaN                     NaN                      NaN
# 9             NaN                     NaN                      NaN
#
#    webChannel.country.timezone
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5             America/New_York
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
#
# [10 rows x 35 columns]

# %% [markdown]
# Using this DataFrame, we can compute the mean runtime of these shows as usual.

# %%
df_shows["runtime"].mean()
# Out:
# 36.1

# %% [markdown]
# Let us take a closer look at the columns of this `DataFrame`.

# %%
df_shows.keys()
# Since df_shows is a DataFrame, this is equivalent to: df_shows.columns
# Out:
# Index(['id', 'url', 'name', 'type', 'language', 'genres', 'status', 'runtime',
#        'premiered', 'officialSite', 'weight', 'webChannel', 'summary',
#        'updated', 'cast', 'seasons', 'schedule.time', 'schedule.days',
#        'rating.average', 'network.id', 'network.name', 'network.country.name',
#        'network.country.code', 'network.country.timezone', 'externals.tvrage',
#        'externals.thetvdb', 'externals.imdb', 'image.medium', 'image.original',
#        'network', 'webChannel.id', 'webChannel.name',
#        'webChannel.country.name', 'webChannel.country.code',
#        'webChannel.country.timezone'],
#       dtype='object')

# %% [markdown]
# Notice that variables that were themselves dictionaries, such as **schedule** and **network**, have been expanded into multiple columns, with names like **schedule.time**, **schedule.days**, etc.
#
# Repeated fields, like **genres**, **cast**, and **seasons**, are also columns in this `DataFrame`. These columns just contain a dump of the raw JSON. The information in these columns is not readily accessible.

# %%
df_shows["seasons"]
# Out:
# 0    [{'id': 650, 'url': 'http://www.tvmaze.com/sea...
# 1    [{'id': 2923, 'url': 'http://www.tvmaze.com/se...
# 2    [{'id': 58294, 'url': 'http://www.tvmaze.com/s...
# 3    [{'id': 20323, 'url': 'http://www.tvmaze.com/s...
# 4    [{'id': 97695, 'url': 'http://www.tvmaze.com/s...
# 5    [{'id': 75322, 'url': 'http://www.tvmaze.com/s...
# 6    [{'id': 77973, 'url': 'http://www.tvmaze.com/s...
# 7    [{'id': 7073, 'url': 'http://www.tvmaze.com/se...
# 8    [{'id': 4998, 'url': 'http://www.tvmaze.com/se...
# 9    [{'id': 2080, 'url': 'http://www.tvmaze.com/se...
# Name: seasons, dtype: object

# %% [markdown]
# What if we wanted to identify the show with the most episodes? It is difficult to calculate this from the `DataFrame` above, since the episodes are buried within the **seasons** column. It would be preferable to have a `DataFrame` where each row represents a season of a show.
#
# The `json_normalize()` function also accepts an additional argument specifying the variable that we want to be the rows of the `DataFrame`. So if we wanted a `DataFrame` where each row represents a season, we would pass in the name of that variable in the JSON data (i.e., **seasons**) to `json_normalize()`.

# %%
df_seasons = pd.json_normalize(data_shows, "seasons")
df_seasons
# Out:
#         id                                                url  number
# 0      650   http://www.tvmaze.com/seasons/650/girls-season-1       1  \
# 1      651   http://www.tvmaze.com/seasons/651/girls-season-2       2
# 2      652   http://www.tvmaze.com/seasons/652/girls-season-3       3
# 3      653   http://www.tvmaze.com/seasons/653/girls-season-4       4
# 4    21282  http://www.tvmaze.com/seasons/21282/girls-seas...       5
# 5    48205  http://www.tvmaze.com/seasons/48205/girls-seas...       6
# 6     2923  http://www.tvmaze.com/seasons/2923/the-golden-...       1
# 7     2924  http://www.tvmaze.com/seasons/2924/the-golden-...       2
# 8     2925  http://www.tvmaze.com/seasons/2925/the-golden-...       3
# 9     2926  http://www.tvmaze.com/seasons/2926/the-golden-...       4
# 10    2927  http://www.tvmaze.com/seasons/2927/the-golden-...       5
# 11    2928  http://www.tvmaze.com/seasons/2928/the-golden-...       6
# 12    2929  http://www.tvmaze.com/seasons/2929/the-golden-...       7
# 13   58294  http://www.tvmaze.com/seasons/58294/good-girls...       1
# 14   91910  http://www.tvmaze.com/seasons/91910/good-girls...       2
# 15   97069  http://www.tvmaze.com/seasons/97069/good-girls...       3
# 16   20323  http://www.tvmaze.com/seasons/20323/the-powerp...       1
# 17   62073  http://www.tvmaze.com/seasons/62073/the-powerp...       2
# 18   85384  http://www.tvmaze.com/seasons/85384/the-powerp...       3
# 19   97695  http://www.tvmaze.com/seasons/97695/florida-gi...       1
# 20   75322  http://www.tvmaze.com/seasons/75322/chicken-gi...       1
# 21   81396  http://www.tvmaze.com/seasons/81396/chicken-gi...       2
# 22   85534  http://www.tvmaze.com/seasons/85534/chicken-gi...       3
# 23   93873  http://www.tvmaze.com/seasons/93873/chicken-gi...       4
# 24  103143  http://www.tvmaze.com/seasons/103143/chicken-g...       5
# 25   77973  http://www.tvmaze.com/seasons/77973/derry-girl...       1
# 26   93954  http://www.tvmaze.com/seasons/93954/derry-girl...       2
# 27    7073  http://www.tvmaze.com/seasons/7073/the-powerpu...       1
# 28    7074  http://www.tvmaze.com/seasons/7074/the-powerpu...       2
# 29    7075  http://www.tvmaze.com/seasons/7075/the-powerpu...       3
# 30    7076  http://www.tvmaze.com/seasons/7076/the-powerpu...       4
# 31    7077  http://www.tvmaze.com/seasons/7077/the-powerpu...       5
# 32    7078  http://www.tvmaze.com/seasons/7078/the-powerpu...       6
# 33    4998  http://www.tvmaze.com/seasons/4998/bomb-girls-...       1
# 34    4999  http://www.tvmaze.com/seasons/4999/bomb-girls-...       2
# 35    2080  http://www.tvmaze.com/seasons/2080/gilmore-gir...       1
# 36    2081  http://www.tvmaze.com/seasons/2081/gilmore-gir...       2
# 37    2082  http://www.tvmaze.com/seasons/2082/gilmore-gir...       3
# 38    2083  http://www.tvmaze.com/seasons/2083/gilmore-gir...       4
# 39    2084  http://www.tvmaze.com/seasons/2084/gilmore-gir...       5
# 40    2085  http://www.tvmaze.com/seasons/2085/gilmore-gir...       6
# 41    2086  http://www.tvmaze.com/seasons/2086/gilmore-gir...       7
# 42   34116  http://www.tvmaze.com/seasons/34116/gilmore-gi...       8
#
#                                  name  episodeOrder premiereDate     endDate
# 0                                              10.0   2012-04-15  2012-06-17  \
# 1                                              10.0   2013-01-13  2013-03-17
# 2                                              12.0   2014-01-12  2014-03-23
# 3                                              10.0   2015-01-11  2015-03-22
# 4                                              10.0   2016-02-21  2016-04-17
# 5                                              10.0   2017-02-12  2017-04-16
# 6                                              25.0   1985-09-14  1986-05-10
# 7                                              26.0   1986-09-27  1987-05-16
# 8                                              25.0   1987-09-19  1988-05-07
# 9                                              26.0   1988-10-08  1989-05-13
# 10                                             26.0   1989-09-23  1990-05-05
# 11                                             26.0   1990-09-22  1991-05-04
# 12                                             26.0   1991-09-21  1992-05-09
# 13                                              NaN   2018-02-26  2018-04-30
# 14                                             13.0   2019-03-03  2019-05-26
# 15                                             16.0   2020-02-16  2020-03-01
# 16                                             39.0   2016-04-04  2016-12-24
# 17                                             41.0   2017-03-03  2018-05-13
# 18                                             39.0   2018-05-13  2019-06-16
# 19                                             10.0   2019-07-10  2019-08-07
# 20                                             11.0   2017-09-05  2017-12-19
# 21                                             11.0   2018-02-14  2018-05-15
# 22                                             13.0   2018-09-04  2018-12-11
# 23                                             11.0   2019-03-19  2019-05-28
# 24                                             11.0   2019-09-03  2019-11-13
# 25                                              6.0   2018-01-04  2018-02-08
# 26                                              6.0   2019-03-05  2019-04-09
# 27                                             13.0   1998-11-18  1999-05-27
# 28                                             13.0   1999-06-25  2000-06-30
# 29                                             13.0   2000-07-28  2001-10-12
# 30                                             10.0   2001-04-20  2002-07-12
# 31                                             14.0   2002-12-06  2003-11-10
# 32                                             15.0   2004-04-02  2004-08-27
# 33                                              NaN   2012-01-04  2012-02-08
# 34                                              NaN   2013-01-02  2013-04-29
# 35                                             21.0   2000-10-05  2001-05-10
# 36                                             22.0   2001-10-09  2002-05-21
# 37                                             22.0   2002-09-24  2003-05-20
# 38                                             22.0   2003-09-23  2004-05-18
# 39                                             22.0   2004-09-21  2005-05-17
# 40                                             22.0   2005-09-13  2006-05-09
# 41                                             22.0   2006-09-26  2007-05-15
# 42  Gilmore Girls: A Year in the Life           4.0         None        None
#
#     webChannel                                            summary
# 0          NaN                                               None  \
# 1          NaN                                               None
# 2          NaN                                               None
# 3          NaN                                               None
# 4          NaN
# 5          NaN                                               None
# 6          NaN                                               None
# 7          NaN                                               None
# 8          NaN                                               None
# 9          NaN                                               None
# 10         NaN                                               None
# 11         NaN                                               None
# 12         NaN                                               None
# 13         NaN                                               None
# 14         NaN                                               None
# 15         NaN                                               None
# 16         NaN  <p>They're back... Blossom, Bubbles and Butter...
# 17         NaN                                               None
# 18         NaN                                               None
# 19         NaN                                               None
# 20         NaN                                               None
# 21         NaN                                               None
# 22         NaN                                               None
# 23         NaN                                               None
# 24         NaN                                               None
# 25         NaN                                               None
# 26         NaN                                               None
# 27         NaN                                               None
# 28         NaN                                               None
# 29         NaN                                               None
# 30         NaN                                               None
# 31         NaN                                               None
# 32         NaN                                               None
# 33         NaN
# 34         NaN
# 35         NaN                                               None
# 36         NaN                                               None
# 37         NaN                                               None
# 38         NaN                                               None
# 39         NaN                                               None
# 40         NaN                                               None
# 41         NaN
# 42         NaN
#
#                                              episodes  ...
# 0   [{'id': 10820, 'url': 'http://www.tvmaze.com/e...  ...  \
# 1   [{'id': 10830, 'url': 'http://www.tvmaze.com/e...  ...
# 2   [{'id': 10840, 'url': 'http://www.tvmaze.com/e...  ...
# 3   [{'id': 40963, 'url': 'http://www.tvmaze.com/e...  ...
# 4   [{'id': 409239, 'url': 'http://www.tvmaze.com/...  ...
# 5   [{'id': 1127016, 'url': 'http://www.tvmaze.com...  ...
# 6   [{'id': 63861, 'url': 'http://www.tvmaze.com/e...  ...
# 7   [{'id': 63886, 'url': 'http://www.tvmaze.com/e...  ...
# 8   [{'id': 63912, 'url': 'http://www.tvmaze.com/e...  ...
# 9   [{'id': 63937, 'url': 'http://www.tvmaze.com/e...  ...
# 10  [{'id': 63963, 'url': 'http://www.tvmaze.com/e...  ...
# 11  [{'id': 63989, 'url': 'http://www.tvmaze.com/e...  ...
# 12  [{'id': 64041, 'url': 'http://www.tvmaze.com/e...  ...
# 13  [{'id': 1357377, 'url': 'http://www.tvmaze.com...  ...
# 14  [{'id': 1580115, 'url': 'http://www.tvmaze.com...  ...
# 15  [{'id': 1753736, 'url': 'http://www.tvmaze.com...  ...
# 16  [{'id': 657308, 'url': 'http://www.tvmaze.com/...  ...
# 17  [{'id': 1076814, 'url': 'http://www.tvmaze.com...  ...
# 18  [{'id': 1454434, 'url': 'http://www.tvmaze.com...  ...
# 19  [{'id': 1673951, 'url': 'http://www.tvmaze.com...  ...
# 20  [{'id': 1343986, 'url': 'http://www.tvmaze.com...  ...
# 21  [{'id': 1493693, 'url': 'http://www.tvmaze.com...  ...
# 22  [{'id': 1474437, 'url': 'http://www.tvmaze.com...  ...
# 23  [{'id': 1620118, 'url': 'http://www.tvmaze.com...  ...
# 24  [{'id': 1762124, 'url': 'http://www.tvmaze.com...  ...
# 25  [{'id': 1370217, 'url': 'http://www.tvmaze.com...  ...
# 26  [{'id': 1612947, 'url': 'http://www.tvmaze.com...  ...
# 27  [{'id': 160178, 'url': 'http://www.tvmaze.com/...  ...
# 28  [{'id': 160191, 'url': 'http://www.tvmaze.com/...  ...
# 29  [{'id': 160204, 'url': 'http://www.tvmaze.com/...  ...
# 30  [{'id': 160217, 'url': 'http://www.tvmaze.com/...  ...
# 31  [{'id': 160255, 'url': 'http://www.tvmaze.com/...  ...
# 32  [{'id': 160257, 'url': 'http://www.tvmaze.com/...  ...
# 33  [{'id': 108007, 'url': 'http://www.tvmaze.com/...  ...
# 34  [{'id': 108025, 'url': 'http://www.tvmaze.com/...  ...
# 35  [{'id': 47487, 'url': 'http://www.tvmaze.com/e...  ...
# 36  [{'id': 47508, 'url': 'http://www.tvmaze.com/e...  ...
# 37  [{'id': 47530, 'url': 'http://www.tvmaze.com/e...  ...
# 38  [{'id': 47552, 'url': 'http://www.tvmaze.com/e...  ...
# 39  [{'id': 47574, 'url': 'http://www.tvmaze.com/e...  ...
# 40  [{'id': 47596, 'url': 'http://www.tvmaze.com/e...  ...
# 41  [{'id': 47618, 'url': 'http://www.tvmaze.com/e...  ...
# 42                                                 []  ...
#
#                                          image.medium
# 0   http://static.tvmaze.com/uploads/images/medium...  \
# 1   http://static.tvmaze.com/uploads/images/medium...
# 2   http://static.tvmaze.com/uploads/images/medium...
# 3   http://static.tvmaze.com/uploads/images/medium...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
#
#                                        image.original image network
# 0   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN  \
# 1   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 2   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 3   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 4                                                 NaN   NaN     NaN
# 5                                                 NaN   NaN     NaN
# 6                                                 NaN   NaN     NaN
# 7                                                 NaN   NaN     NaN
# 8                                                 NaN   NaN     NaN
# 9                                                 NaN   NaN     NaN
# 10                                                NaN   NaN     NaN
# 11                                                NaN   NaN     NaN
# 12                                                NaN   NaN     NaN
# 13                                                NaN   NaN     NaN
# 14                                                NaN   NaN     NaN
# 15                                                NaN   NaN     NaN
# 16                                                NaN   NaN     NaN
# 17                                                NaN   NaN     NaN
# 18                                                NaN   NaN     NaN
# 19                                                NaN   NaN     NaN
# 20                                                NaN   NaN     NaN
# 21                                                NaN   NaN     NaN
# 22                                                NaN   NaN     NaN
# 23                                                NaN   NaN     NaN
# 24                                                NaN   NaN     NaN
# 25                                                NaN   NaN     NaN
# 26                                                NaN   NaN     NaN
# 27                                                NaN   NaN     NaN
# 28                                                NaN   NaN     NaN
# 29                                                NaN   NaN     NaN
# 30                                                NaN   NaN     NaN
# 31                                                NaN   NaN     NaN
# 32                                                NaN   NaN     NaN
# 33                                                NaN   NaN     NaN
# 34                                                NaN   NaN     NaN
# 35                                                NaN   NaN     NaN
# 36                                                NaN   NaN     NaN
# 37                                                NaN   NaN     NaN
# 38                                                NaN   NaN     NaN
# 39                                                NaN   NaN     NaN
# 40                                                NaN   NaN     NaN
# 41                                                NaN   NaN     NaN
# 42                                                NaN   NaN     NaN
#
#    webChannel.id webChannel.name webChannel.country  webChannel.country.name
# 0            NaN             NaN                NaN                      NaN  \
# 1            NaN             NaN                NaN                      NaN
# 2            NaN             NaN                NaN                      NaN
# 3            NaN             NaN                NaN                      NaN
# 4            NaN             NaN                NaN                      NaN
# 5            NaN             NaN                NaN                      NaN
# 6            NaN             NaN                NaN                      NaN
# 7            NaN             NaN                NaN                      NaN
# 8            NaN             NaN                NaN                      NaN
# 9            NaN             NaN                NaN                      NaN
# 10           NaN             NaN                NaN                      NaN
# 11           NaN             NaN                NaN                      NaN
# 12           NaN             NaN                NaN                      NaN
# 13           NaN             NaN                NaN                      NaN
# 14           NaN             NaN                NaN                      NaN
# 15           NaN             NaN                NaN                      NaN
# 16           NaN             NaN                NaN                      NaN
# 17           NaN             NaN                NaN                      NaN
# 18           NaN             NaN                NaN                      NaN
# 19           NaN             NaN                NaN                      NaN
# 20          21.0         YouTube                NaN                      NaN
# 21         274.0            Brat                NaN            United States
# 22         274.0            Brat                NaN            United States
# 23         274.0            Brat                NaN            United States
# 24         274.0            Brat                NaN            United States
# 25           NaN             NaN                NaN                      NaN
# 26           NaN             NaN                NaN                      NaN
# 27           NaN             NaN                NaN                      NaN
# 28           NaN             NaN                NaN                      NaN
# 29           NaN             NaN                NaN                      NaN
# 30           NaN             NaN                NaN                      NaN
# 31           NaN             NaN                NaN                      NaN
# 32           NaN             NaN                NaN                      NaN
# 33           NaN             NaN                NaN                      NaN
# 34           NaN             NaN                NaN                      NaN
# 35           NaN             NaN                NaN                      NaN
# 36           NaN             NaN                NaN                      NaN
# 37           NaN             NaN                NaN                      NaN
# 38           NaN             NaN                NaN                      NaN
# 39           NaN             NaN                NaN                      NaN
# 40           NaN             NaN                NaN                      NaN
# 41           NaN             NaN                NaN                      NaN
# 42           1.0         Netflix                NaN                      NaN
#
#     webChannel.country.code  webChannel.country.timezone
# 0                       NaN                          NaN
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
# 5                       NaN                          NaN
# 6                       NaN                          NaN
# 7                       NaN                          NaN
# 8                       NaN                          NaN
# 9                       NaN                          NaN
# 10                      NaN                          NaN
# 11                      NaN                          NaN
# 12                      NaN                          NaN
# 13                      NaN                          NaN
# 14                      NaN                          NaN
# 15                      NaN                          NaN
# 16                      NaN                          NaN
# 17                      NaN                          NaN
# 18                      NaN                          NaN
# 19                      NaN                          NaN
# 20                      NaN                          NaN
# 21                       US             America/New_York
# 22                       US             America/New_York
# 23                       US             America/New_York
# 24                       US             America/New_York
# 25                      NaN                          NaN
# 26                      NaN                          NaN
# 27                      NaN                          NaN
# 28                      NaN                          NaN
# 29                      NaN                          NaN
# 30                      NaN                          NaN
# 31                      NaN                          NaN
# 32                      NaN                          NaN
# 33                      NaN                          NaN
# 34                      NaN                          NaN
# 35                      NaN                          NaN
# 36                      NaN                          NaN
# 37                      NaN                          NaN
# 38                      NaN                          NaN
# 39                      NaN                          NaN
# 40                      NaN                          NaN
# 41                      NaN                          NaN
# 42                      NaN                          NaN
#
# [43 rows x 25 columns]

# %% [markdown]
# There is just one problem. We now have a `DataFrame` of seasons, without any indication of which TV show they came from. This is because when we used `json_normalize()`, it automatically discarded variables from all levels above the one that we flattened to. (Since we flattened to the "season" level, we lost all variables associated with the "show".) If there are any variables from the higher levels that we want to keep, then they have to be specified explicitly in the `meta=` argument. Since we want the name of the TV show, which is stored in the "name" key of each show, we specify `meta="name"`.
#
# (We also specify a prefix in the `meta_prefix=` argument to avoid column name clashes, since the `DataFrame` already has a column called **name**. This is not necessary if the column names do not clash.)

# %%
df_seasons = pd.json_normalize(data_shows, "seasons",
                               meta="name", meta_prefix="show.")
df_seasons
# Out:
#         id                                                url  number
# 0      650   http://www.tvmaze.com/seasons/650/girls-season-1       1  \
# 1      651   http://www.tvmaze.com/seasons/651/girls-season-2       2
# 2      652   http://www.tvmaze.com/seasons/652/girls-season-3       3
# 3      653   http://www.tvmaze.com/seasons/653/girls-season-4       4
# 4    21282  http://www.tvmaze.com/seasons/21282/girls-seas...       5
# 5    48205  http://www.tvmaze.com/seasons/48205/girls-seas...       6
# 6     2923  http://www.tvmaze.com/seasons/2923/the-golden-...       1
# 7     2924  http://www.tvmaze.com/seasons/2924/the-golden-...       2
# 8     2925  http://www.tvmaze.com/seasons/2925/the-golden-...       3
# 9     2926  http://www.tvmaze.com/seasons/2926/the-golden-...       4
# 10    2927  http://www.tvmaze.com/seasons/2927/the-golden-...       5
# 11    2928  http://www.tvmaze.com/seasons/2928/the-golden-...       6
# 12    2929  http://www.tvmaze.com/seasons/2929/the-golden-...       7
# 13   58294  http://www.tvmaze.com/seasons/58294/good-girls...       1
# 14   91910  http://www.tvmaze.com/seasons/91910/good-girls...       2
# 15   97069  http://www.tvmaze.com/seasons/97069/good-girls...       3
# 16   20323  http://www.tvmaze.com/seasons/20323/the-powerp...       1
# 17   62073  http://www.tvmaze.com/seasons/62073/the-powerp...       2
# 18   85384  http://www.tvmaze.com/seasons/85384/the-powerp...       3
# 19   97695  http://www.tvmaze.com/seasons/97695/florida-gi...       1
# 20   75322  http://www.tvmaze.com/seasons/75322/chicken-gi...       1
# 21   81396  http://www.tvmaze.com/seasons/81396/chicken-gi...       2
# 22   85534  http://www.tvmaze.com/seasons/85534/chicken-gi...       3
# 23   93873  http://www.tvmaze.com/seasons/93873/chicken-gi...       4
# 24  103143  http://www.tvmaze.com/seasons/103143/chicken-g...       5
# 25   77973  http://www.tvmaze.com/seasons/77973/derry-girl...       1
# 26   93954  http://www.tvmaze.com/seasons/93954/derry-girl...       2
# 27    7073  http://www.tvmaze.com/seasons/7073/the-powerpu...       1
# 28    7074  http://www.tvmaze.com/seasons/7074/the-powerpu...       2
# 29    7075  http://www.tvmaze.com/seasons/7075/the-powerpu...       3
# 30    7076  http://www.tvmaze.com/seasons/7076/the-powerpu...       4
# 31    7077  http://www.tvmaze.com/seasons/7077/the-powerpu...       5
# 32    7078  http://www.tvmaze.com/seasons/7078/the-powerpu...       6
# 33    4998  http://www.tvmaze.com/seasons/4998/bomb-girls-...       1
# 34    4999  http://www.tvmaze.com/seasons/4999/bomb-girls-...       2
# 35    2080  http://www.tvmaze.com/seasons/2080/gilmore-gir...       1
# 36    2081  http://www.tvmaze.com/seasons/2081/gilmore-gir...       2
# 37    2082  http://www.tvmaze.com/seasons/2082/gilmore-gir...       3
# 38    2083  http://www.tvmaze.com/seasons/2083/gilmore-gir...       4
# 39    2084  http://www.tvmaze.com/seasons/2084/gilmore-gir...       5
# 40    2085  http://www.tvmaze.com/seasons/2085/gilmore-gir...       6
# 41    2086  http://www.tvmaze.com/seasons/2086/gilmore-gir...       7
# 42   34116  http://www.tvmaze.com/seasons/34116/gilmore-gi...       8
#
#                                  name  episodeOrder premiereDate     endDate
# 0                                              10.0   2012-04-15  2012-06-17  \
# 1                                              10.0   2013-01-13  2013-03-17
# 2                                              12.0   2014-01-12  2014-03-23
# 3                                              10.0   2015-01-11  2015-03-22
# 4                                              10.0   2016-02-21  2016-04-17
# 5                                              10.0   2017-02-12  2017-04-16
# 6                                              25.0   1985-09-14  1986-05-10
# 7                                              26.0   1986-09-27  1987-05-16
# 8                                              25.0   1987-09-19  1988-05-07
# 9                                              26.0   1988-10-08  1989-05-13
# 10                                             26.0   1989-09-23  1990-05-05
# 11                                             26.0   1990-09-22  1991-05-04
# 12                                             26.0   1991-09-21  1992-05-09
# 13                                              NaN   2018-02-26  2018-04-30
# 14                                             13.0   2019-03-03  2019-05-26
# 15                                             16.0   2020-02-16  2020-03-01
# 16                                             39.0   2016-04-04  2016-12-24
# 17                                             41.0   2017-03-03  2018-05-13
# 18                                             39.0   2018-05-13  2019-06-16
# 19                                             10.0   2019-07-10  2019-08-07
# 20                                             11.0   2017-09-05  2017-12-19
# 21                                             11.0   2018-02-14  2018-05-15
# 22                                             13.0   2018-09-04  2018-12-11
# 23                                             11.0   2019-03-19  2019-05-28
# 24                                             11.0   2019-09-03  2019-11-13
# 25                                              6.0   2018-01-04  2018-02-08
# 26                                              6.0   2019-03-05  2019-04-09
# 27                                             13.0   1998-11-18  1999-05-27
# 28                                             13.0   1999-06-25  2000-06-30
# 29                                             13.0   2000-07-28  2001-10-12
# 30                                             10.0   2001-04-20  2002-07-12
# 31                                             14.0   2002-12-06  2003-11-10
# 32                                             15.0   2004-04-02  2004-08-27
# 33                                              NaN   2012-01-04  2012-02-08
# 34                                              NaN   2013-01-02  2013-04-29
# 35                                             21.0   2000-10-05  2001-05-10
# 36                                             22.0   2001-10-09  2002-05-21
# 37                                             22.0   2002-09-24  2003-05-20
# 38                                             22.0   2003-09-23  2004-05-18
# 39                                             22.0   2004-09-21  2005-05-17
# 40                                             22.0   2005-09-13  2006-05-09
# 41                                             22.0   2006-09-26  2007-05-15
# 42  Gilmore Girls: A Year in the Life           4.0         None        None
#
#     webChannel                                            summary
# 0          NaN                                               None  \
# 1          NaN                                               None
# 2          NaN                                               None
# 3          NaN                                               None
# 4          NaN
# 5          NaN                                               None
# 6          NaN                                               None
# 7          NaN                                               None
# 8          NaN                                               None
# 9          NaN                                               None
# 10         NaN                                               None
# 11         NaN                                               None
# 12         NaN                                               None
# 13         NaN                                               None
# 14         NaN                                               None
# 15         NaN                                               None
# 16         NaN  <p>They're back... Blossom, Bubbles and Butter...
# 17         NaN                                               None
# 18         NaN                                               None
# 19         NaN                                               None
# 20         NaN                                               None
# 21         NaN                                               None
# 22         NaN                                               None
# 23         NaN                                               None
# 24         NaN                                               None
# 25         NaN                                               None
# 26         NaN                                               None
# 27         NaN                                               None
# 28         NaN                                               None
# 29         NaN                                               None
# 30         NaN                                               None
# 31         NaN                                               None
# 32         NaN                                               None
# 33         NaN
# 34         NaN
# 35         NaN                                               None
# 36         NaN                                               None
# 37         NaN                                               None
# 38         NaN                                               None
# 39         NaN                                               None
# 40         NaN                                               None
# 41         NaN
# 42         NaN
#
#                                              episodes  ...
# 0   [{'id': 10820, 'url': 'http://www.tvmaze.com/e...  ...  \
# 1   [{'id': 10830, 'url': 'http://www.tvmaze.com/e...  ...
# 2   [{'id': 10840, 'url': 'http://www.tvmaze.com/e...  ...
# 3   [{'id': 40963, 'url': 'http://www.tvmaze.com/e...  ...
# 4   [{'id': 409239, 'url': 'http://www.tvmaze.com/...  ...
# 5   [{'id': 1127016, 'url': 'http://www.tvmaze.com...  ...
# 6   [{'id': 63861, 'url': 'http://www.tvmaze.com/e...  ...
# 7   [{'id': 63886, 'url': 'http://www.tvmaze.com/e...  ...
# 8   [{'id': 63912, 'url': 'http://www.tvmaze.com/e...  ...
# 9   [{'id': 63937, 'url': 'http://www.tvmaze.com/e...  ...
# 10  [{'id': 63963, 'url': 'http://www.tvmaze.com/e...  ...
# 11  [{'id': 63989, 'url': 'http://www.tvmaze.com/e...  ...
# 12  [{'id': 64041, 'url': 'http://www.tvmaze.com/e...  ...
# 13  [{'id': 1357377, 'url': 'http://www.tvmaze.com...  ...
# 14  [{'id': 1580115, 'url': 'http://www.tvmaze.com...  ...
# 15  [{'id': 1753736, 'url': 'http://www.tvmaze.com...  ...
# 16  [{'id': 657308, 'url': 'http://www.tvmaze.com/...  ...
# 17  [{'id': 1076814, 'url': 'http://www.tvmaze.com...  ...
# 18  [{'id': 1454434, 'url': 'http://www.tvmaze.com...  ...
# 19  [{'id': 1673951, 'url': 'http://www.tvmaze.com...  ...
# 20  [{'id': 1343986, 'url': 'http://www.tvmaze.com...  ...
# 21  [{'id': 1493693, 'url': 'http://www.tvmaze.com...  ...
# 22  [{'id': 1474437, 'url': 'http://www.tvmaze.com...  ...
# 23  [{'id': 1620118, 'url': 'http://www.tvmaze.com...  ...
# 24  [{'id': 1762124, 'url': 'http://www.tvmaze.com...  ...
# 25  [{'id': 1370217, 'url': 'http://www.tvmaze.com...  ...
# 26  [{'id': 1612947, 'url': 'http://www.tvmaze.com...  ...
# 27  [{'id': 160178, 'url': 'http://www.tvmaze.com/...  ...
# 28  [{'id': 160191, 'url': 'http://www.tvmaze.com/...  ...
# 29  [{'id': 160204, 'url': 'http://www.tvmaze.com/...  ...
# 30  [{'id': 160217, 'url': 'http://www.tvmaze.com/...  ...
# 31  [{'id': 160255, 'url': 'http://www.tvmaze.com/...  ...
# 32  [{'id': 160257, 'url': 'http://www.tvmaze.com/...  ...
# 33  [{'id': 108007, 'url': 'http://www.tvmaze.com/...  ...
# 34  [{'id': 108025, 'url': 'http://www.tvmaze.com/...  ...
# 35  [{'id': 47487, 'url': 'http://www.tvmaze.com/e...  ...
# 36  [{'id': 47508, 'url': 'http://www.tvmaze.com/e...  ...
# 37  [{'id': 47530, 'url': 'http://www.tvmaze.com/e...  ...
# 38  [{'id': 47552, 'url': 'http://www.tvmaze.com/e...  ...
# 39  [{'id': 47574, 'url': 'http://www.tvmaze.com/e...  ...
# 40  [{'id': 47596, 'url': 'http://www.tvmaze.com/e...  ...
# 41  [{'id': 47618, 'url': 'http://www.tvmaze.com/e...  ...
# 42                                                 []  ...
#
#                                        image.original image network
# 0   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN  \
# 1   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 2   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 3   http://static.tvmaze.com/uploads/images/origin...   NaN     NaN
# 4                                                 NaN   NaN     NaN
# 5                                                 NaN   NaN     NaN
# 6                                                 NaN   NaN     NaN
# 7                                                 NaN   NaN     NaN
# 8                                                 NaN   NaN     NaN
# 9                                                 NaN   NaN     NaN
# 10                                                NaN   NaN     NaN
# 11                                                NaN   NaN     NaN
# 12                                                NaN   NaN     NaN
# 13                                                NaN   NaN     NaN
# 14                                                NaN   NaN     NaN
# 15                                                NaN   NaN     NaN
# 16                                                NaN   NaN     NaN
# 17                                                NaN   NaN     NaN
# 18                                                NaN   NaN     NaN
# 19                                                NaN   NaN     NaN
# 20                                                NaN   NaN     NaN
# 21                                                NaN   NaN     NaN
# 22                                                NaN   NaN     NaN
# 23                                                NaN   NaN     NaN
# 24                                                NaN   NaN     NaN
# 25                                                NaN   NaN     NaN
# 26                                                NaN   NaN     NaN
# 27                                                NaN   NaN     NaN
# 28                                                NaN   NaN     NaN
# 29                                                NaN   NaN     NaN
# 30                                                NaN   NaN     NaN
# 31                                                NaN   NaN     NaN
# 32                                                NaN   NaN     NaN
# 33                                                NaN   NaN     NaN
# 34                                                NaN   NaN     NaN
# 35                                                NaN   NaN     NaN
# 36                                                NaN   NaN     NaN
# 37                                                NaN   NaN     NaN
# 38                                                NaN   NaN     NaN
# 39                                                NaN   NaN     NaN
# 40                                                NaN   NaN     NaN
# 41                                                NaN   NaN     NaN
# 42                                                NaN   NaN     NaN
#
#    webChannel.id webChannel.name webChannel.country webChannel.country.name
# 0            NaN             NaN                NaN                     NaN  \
# 1            NaN             NaN                NaN                     NaN
# 2            NaN             NaN                NaN                     NaN
# 3            NaN             NaN                NaN                     NaN
# 4            NaN             NaN                NaN                     NaN
# 5            NaN             NaN                NaN                     NaN
# 6            NaN             NaN                NaN                     NaN
# 7            NaN             NaN                NaN                     NaN
# 8            NaN             NaN                NaN                     NaN
# 9            NaN             NaN                NaN                     NaN
# 10           NaN             NaN                NaN                     NaN
# 11           NaN             NaN                NaN                     NaN
# 12           NaN             NaN                NaN                     NaN
# 13           NaN             NaN                NaN                     NaN
# 14           NaN             NaN                NaN                     NaN
# 15           NaN             NaN                NaN                     NaN
# 16           NaN             NaN                NaN                     NaN
# 17           NaN             NaN                NaN                     NaN
# 18           NaN             NaN                NaN                     NaN
# 19           NaN             NaN                NaN                     NaN
# 20          21.0         YouTube                NaN                     NaN
# 21         274.0            Brat                NaN           United States
# 22         274.0            Brat                NaN           United States
# 23         274.0            Brat                NaN           United States
# 24         274.0            Brat                NaN           United States
# 25           NaN             NaN                NaN                     NaN
# 26           NaN             NaN                NaN                     NaN
# 27           NaN             NaN                NaN                     NaN
# 28           NaN             NaN                NaN                     NaN
# 29           NaN             NaN                NaN                     NaN
# 30           NaN             NaN                NaN                     NaN
# 31           NaN             NaN                NaN                     NaN
# 32           NaN             NaN                NaN                     NaN
# 33           NaN             NaN                NaN                     NaN
# 34           NaN             NaN                NaN                     NaN
# 35           NaN             NaN                NaN                     NaN
# 36           NaN             NaN                NaN                     NaN
# 37           NaN             NaN                NaN                     NaN
# 38           NaN             NaN                NaN                     NaN
# 39           NaN             NaN                NaN                     NaN
# 40           NaN             NaN                NaN                     NaN
# 41           NaN             NaN                NaN                     NaN
# 42           1.0         Netflix                NaN                     NaN
#
#     webChannel.country.code  webChannel.country.timezone            show.name
# 0                       NaN                          NaN                Girls
# 1                       NaN                          NaN                Girls
# 2                       NaN                          NaN                Girls
# 3                       NaN                          NaN                Girls
# 4                       NaN                          NaN                Girls
# 5                       NaN                          NaN                Girls
# 6                       NaN                          NaN     The Golden Girls
# 7                       NaN                          NaN     The Golden Girls
# 8                       NaN                          NaN     The Golden Girls
# 9                       NaN                          NaN     The Golden Girls
# 10                      NaN                          NaN     The Golden Girls
# 11                      NaN                          NaN     The Golden Girls
# 12                      NaN                          NaN     The Golden Girls
# 13                      NaN                          NaN           Good Girls
# 14                      NaN                          NaN           Good Girls
# 15                      NaN                          NaN           Good Girls
# 16                      NaN                          NaN  The Powerpuff Girls
# 17                      NaN                          NaN  The Powerpuff Girls
# 18                      NaN                          NaN  The Powerpuff Girls
# 19                      NaN                          NaN        Florida Girls
# 20                      NaN                          NaN        Chicken Girls
# 21                       US             America/New_York        Chicken Girls
# 22                       US             America/New_York        Chicken Girls
# 23                       US             America/New_York        Chicken Girls
# 24                       US             America/New_York        Chicken Girls
# 25                      NaN                          NaN          Derry Girls
# 26                      NaN                          NaN          Derry Girls
# 27                      NaN                          NaN  The Powerpuff Girls
# 28                      NaN                          NaN  The Powerpuff Girls
# 29                      NaN                          NaN  The Powerpuff Girls
# 30                      NaN                          NaN  The Powerpuff Girls
# 31                      NaN                          NaN  The Powerpuff Girls
# 32                      NaN                          NaN  The Powerpuff Girls
# 33                      NaN                          NaN           Bomb Girls
# 34                      NaN                          NaN           Bomb Girls
# 35                      NaN                          NaN        Gilmore Girls
# 36                      NaN                          NaN        Gilmore Girls
# 37                      NaN                          NaN        Gilmore Girls
# 38                      NaN                          NaN        Gilmore Girls
# 39                      NaN                          NaN        Gilmore Girls
# 40                      NaN                          NaN        Gilmore Girls
# 41                      NaN                          NaN        Gilmore Girls
# 42                      NaN                          NaN        Gilmore Girls
#
# [43 rows x 26 columns]

# %% [markdown]
# From here, it is straightforward to calculate the total number of episodes for each show. First, we determine the number of episodes in each season by calculating the length of each episodes list, storing the result in a new column called **num_episodes**. Then, we calculate the sum of **num_episodes** for each **show.name**.

# %%
df_seasons["num_episodes"] = df_seasons["episodes"].apply(len)
df_seasons.groupby("show.name")["num_episodes"].sum()
# Out:
# show.name
# Bomb Girls              19
# Chicken Girls           76
# Derry Girls             12
# Florida Girls           10
# Gilmore Girls          153
# Girls                   63
# Good Girls              26
# The Golden Girls       181
# The Powerpuff Girls    201
# Name: num_episodes, dtype: int64

# %% [markdown]
# Alternatively, we could have answered this question by flattening the JSON data to the episode level. Since "episodes" are nested underneath "seasons", we have to specify the path to the "episodes" variable in the JSON data.

# %%
df_episodes = pd.json_normalize(data_shows, ["seasons", "episodes"], meta="name", meta_prefix="show.")
df_episodes
# Out:
#         id                                                url
# 0    10820  http://www.tvmaze.com/episodes/10820/girls-1x0...  \
# 1    10821  http://www.tvmaze.com/episodes/10821/girls-1x0...
# 2    10822  http://www.tvmaze.com/episodes/10822/girls-1x0...
# 3    10823  http://www.tvmaze.com/episodes/10823/girls-1x0...
# 4    10824  http://www.tvmaze.com/episodes/10824/girls-1x0...
# ..     ...                                                ...
# 736  47635  http://www.tvmaze.com/episodes/47635/gilmore-g...
# 737  47636  http://www.tvmaze.com/episodes/47636/gilmore-g...
# 738  47637  http://www.tvmaze.com/episodes/47637/gilmore-g...
# 739  47638  http://www.tvmaze.com/episodes/47638/gilmore-g...
# 740  47639  http://www.tvmaze.com/episodes/47639/gilmore-g...
#
#                              name  season  number     airdate airtime
# 0                           Pilot       1     1.0  2012-04-15   22:30  \
# 1                    Vagina Panic       1     2.0  2012-04-22   22:30
# 2        All Adventurous Women Do       1     3.0  2012-04-29   22:30
# 3                  Hannah's Diary       1     4.0  2012-05-06   22:30
# 4                 Hard Being Easy       1     5.0  2012-05-13   22:30
# ..                            ...     ...     ...         ...     ...
# 736                 Hay Bale Maze       7    18.0  2007-04-17   21:00
# 737  It's Just Like Riding a Bike       7    19.0  2007-04-24   21:00
# 738             Lorelai? Lorelai?       7    20.0  2007-05-01   21:00
# 739               Unto the Breach       7    21.0  2007-05-08   21:00
# 740                    Bon Voyage       7    22.0  2007-05-15   21:00
#
#                       airstamp  runtime
# 0    2012-04-16T02:30:00+00:00       30  \
# 1    2012-04-23T02:30:00+00:00       30
# 2    2012-04-30T02:30:00+00:00       30
# 3    2012-05-07T02:30:00+00:00       30
# 4    2012-05-14T02:30:00+00:00       30
# ..                         ...      ...
# 736  2007-04-18T01:00:00+00:00       60
# 737  2007-04-25T01:00:00+00:00       60
# 738  2007-05-02T01:00:00+00:00       60
# 739  2007-05-09T01:00:00+00:00       60
# 740  2007-05-16T01:00:00+00:00       60
#
#                                                summary
# 0    <p>In the premiere of this comedy about twenty...  \
# 1    <p>An appointment at a women's clinic doesn't ...
# 2    <p>Hannah contacts her college boyfriend to fi...
# 3    <p>Adam's risqué text message sends Hannah ove...
# 4    <p>Hannah tries a different tack with her boss...
# ..                                                 ...
# 736  <p>Brief encounter: Stars Hollow's centerpiece...
# 737  <p>Lorelai needs help shopping for a new car. ...
# 738  <p>On karaoke night, a tipsy Lorelai take the ...
# 739  <p>Pomp and circumstances. Rory's graduation b...
# 740  <p>An exciting job offer for Rory and a benefi...
#
#                                           image.medium
# 0    http://static.tvmaze.com/uploads/images/medium...  \
# 1    http://static.tvmaze.com/uploads/images/medium...
# 2    http://static.tvmaze.com/uploads/images/medium...
# 3    http://static.tvmaze.com/uploads/images/medium...
# 4    http://static.tvmaze.com/uploads/images/medium...
# ..                                                 ...
# 736                                                NaN
# 737                                                NaN
# 738                                                NaN
# 739                                                NaN
# 740                                                NaN
#
#                                         image.original  image      show.name
# 0    http://static.tvmaze.com/uploads/images/origin...    NaN          Girls
# 1    http://static.tvmaze.com/uploads/images/origin...    NaN          Girls
# 2    http://static.tvmaze.com/uploads/images/origin...    NaN          Girls
# 3    http://static.tvmaze.com/uploads/images/origin...    NaN          Girls
# 4    http://static.tvmaze.com/uploads/images/origin...    NaN          Girls
# ..                                                 ...    ...            ...
# 736                                                NaN    NaN  Gilmore Girls
# 737                                                NaN    NaN  Gilmore Girls
# 738                                                NaN    NaN  Gilmore Girls
# 739                                                NaN    NaN  Gilmore Girls
# 740                                                NaN    NaN  Gilmore Girls
#
# [741 rows x 14 columns]

# %% [markdown]
# Since the observational unit is already an episode, we simply count the number of times each show appears in this `DataFrame`.

# %%
df_episodes["show.name"].value_counts()
# Out:
# show.name
# The Powerpuff Girls    201
# The Golden Girls       181
# Gilmore Girls          153
# Chicken Girls           76
# Girls                   63
# Good Girls              26
# Bomb Girls              19
# Derry Girls             12
# Florida Girls           10
# Name: count, dtype: int64

# %% [markdown]
# # RESTful Web Services
#
# One way that organizations expose their data to the public is through RESTful web services. In a typical RESTful service, the user specifies the desired data in an HTTP request, and the server responds with the requested data. JSON is a common format for the response data.

# %% [markdown]
# For example, the JSON data that we have been analyzing in this lesson was retrieved from the [TVMaze API](http://www.tvmaze.com/api). Most APIs come with accompanying documentation explaining how to construct HTTP requests to fetch data. For example, to query the TVMaze API for TV shows related to the term "office", we would issue a request to the following URL: http://api.tvmaze.com/search/shows?q=office. Try visiting this URL in a browser; you should see a long string of JSON instead of a rendered webpage!
#
# We can import this JSON into our Python session using the `requests` library, as above.

# %%
import requests
response = requests.get("http://api.tvmaze.com/search/shows?q=office")
data_office = response.json()

# Print the first 1000 characters.
str(data_office)[:1000]
# Out:
# "[{'score': 0.70251113, 'show': {'id': 526, 'url': 'https://www.tvmaze.com/shows/526/the-office', 'name': 'The Office', 'type': 'Scripted', 'language': 'English', 'genres': ['Comedy'], 'status': 'Ended', 'runtime': 30, 'averageRuntime': 30, 'premiered': '2005-03-24', 'ended': '2013-05-16', 'officialSite': 'http://www.nbc.com/the-office', 'schedule': {'time': '21:00', 'days': ['Thursday']}, 'rating': {'average': 8.4}, 'weight': 98, 'network': {'id': 1, 'name': 'NBC', 'country': {'name': 'United States', 'code': 'US', 'timezone': 'America/New_York'}, 'officialSite': 'https://www.nbc.com/'}, 'webChannel': None, 'dvdCountry': None, 'externals': {'tvrage': 6061, 'thetvdb': 73244, 'imdb': 'tt0386676'}, 'image': {'medium': 'https://static.tvmaze.com/uploads/images/medium_portrait/271/678637.jpg', 'original': 'https://static.tvmaze.com/uploads/images/original_untouched/271/678637.jpg'}, 'summary': '<p>Steve Carell stars in <b>The Office</b>, a fresh and funny mockumentary-style glimpse into the"

# %% [markdown]
# This JSON can then be processed using the techniques discussed above.
#
# Although many RESTful APIs work similarly, there is no universal standard, so you will usually have to carefully read the documentation for the API that you want to use.

# %% [markdown]
# [You can find some REST APIs here](https://publicapi.dev/)

# %% [markdown]
# # Ethics Tidbit: Staggering Requests
#
# Suppose we want information about the individual episodes of each show we found above.

# %%
df_office = pd.json_normalize(data_office)
df_office
# Out:
#       score  show.id                                           show.url
# 0  0.702511      526        https://www.tvmaze.com/shows/526/the-office  \
# 1  0.700170     1292       https://www.tvmaze.com/shows/1292/the-office
# 2  0.664103    57704      https://www.tvmaze.com/shows/57704/the-office
# 3  0.657895    25637  https://www.tvmaze.com/shows/25637/radiant-office
# 4  0.645963    44432    https://www.tvmaze.com/shows/44432/office-watch
# 5  0.633565    57168      https://www.tvmaze.com/shows/57168/the-office
# 6  0.607360    28775      https://www.tvmaze.com/shows/28775/box-office
# 7  0.578757    44011  https://www.tvmaze.com/shows/44011/african-off...
# 8  0.570307    59025    https://www.tvmaze.com/shows/59025/death-office
# 9  0.565267    69044  https://www.tvmaze.com/shows/69044/the-office-...
#
#                show.name  show.type show.language               show.genres
# 0             The Office   Scripted       English                  [Comedy]  \
# 1             The Office   Scripted       English                  [Comedy]
# 2             The Office   Scripted         Hindi                  [Comedy]
# 3         Radiant Office   Scripted        Korean  [Drama, Comedy, Romance]
# 4           Office Watch   Scripted        Korean  [Drama, Comedy, Romance]
# 5             The Office   Scripted       English                  [Comedy]
# 6             Box Office    Variety       English                        []
# 7  African Office Worker  Animation      Japanese           [Comedy, Anime]
# 8           Death Office   Scripted      Japanese   [Drama, Anime, Fantasy]
# 9   The Office Australia   Scripted       English                  [Comedy]
#
#       show.status  show.runtime  show.averageRuntime  ...
# 0           Ended          30.0                 30.0  ...  \
# 1           Ended          30.0                 30.0  ...
# 2           Ended           NaN                 25.0  ...
# 3           Ended          65.0                 65.0  ...
# 4           Ended           5.0                  5.0  ...
# 5           Ended          30.0                 30.0  ...
# 6           Ended          30.0                 30.0  ...
# 7           Ended           NaN                 30.0  ...
# 8           Ended          30.0                 30.0  ...
# 9  In Development           NaN                  NaN  ...
#
#           show._links.previousepisode.href show.network show.webChannel.id
# 0   https://api.tvmaze.com/episodes/711203          NaN                NaN  \
# 1   https://api.tvmaze.com/episodes/110286          NaN                NaN
# 2  https://api.tvmaze.com/episodes/2173965          NaN              164.0
# 3  https://api.tvmaze.com/episodes/1099572          NaN                NaN
# 4  https://api.tvmaze.com/episodes/1734133          NaN              122.0
# 5  https://api.tvmaze.com/episodes/2156555          NaN                NaN
# 6  https://api.tvmaze.com/episodes/1199441          NaN                NaN
# 7  https://api.tvmaze.com/episodes/1729642          NaN              139.0
# 8  https://api.tvmaze.com/episodes/2306191          NaN              342.0
# 9                                      NaN          NaN                3.0
#
#   show.webChannel.name show.webChannel.country  show.webChannel.officialSite
# 0                  NaN                     NaN                           NaN  \
# 1                  NaN                     NaN                           NaN
# 2      Disney+ Hotstar                     NaN                          None
# 3                  NaN                     NaN                           NaN
# 4               V LIVE                     NaN     https://www.vlive.tv/home
# 5                  NaN                     NaN                           NaN
# 6                  NaN                     NaN                           NaN
# 7   Docomo Anime Store                     NaN                          None
# 8               Paravi                     NaN                          None
# 9          Prime Video                     NaN    https://www.primevideo.com
#
#    show.webChannel.country.name  show.webChannel.country.code
# 0                           NaN                           NaN  \
# 1                           NaN                           NaN
# 2                           NaN                           NaN
# 3                           NaN                           NaN
# 4            Korea, Republic of                            KR
# 5                           NaN                           NaN
# 6                           NaN                           NaN
# 7                         Japan                            JP
# 8                         Japan                            JP
# 9                           NaN                           NaN
#
#   show.webChannel.country.timezone show.image
# 0                              NaN        NaN
# 1                              NaN        NaN
# 2                              NaN        NaN
# 3                              NaN        NaN
# 4                       Asia/Seoul        NaN
# 5                              NaN        NaN
# 6                              NaN        NaN
# 7                       Asia/Tokyo        NaN
# 8                       Asia/Tokyo        NaN
# 9                              NaN        NaN
#
# [10 rows x 43 columns]

# %% [markdown]
# From [the documentation](http://www.tvmaze.com/api#show-episode-list), we see that the episodes can be retrieved using the ID in the **show.id** column, by constructing a URL of the form http://api.tvmaze.com/shows/[ID]/episodes.
#
# It is straightforward enough to write a loop that replaces [ID] in this URL by the actual ID of each show. However, a script can easily issue hundreds, even thousands, of queries per second, and we want to avoid spamming the server. In fact, most RESTful services have [rate limiting policies](http://www.tvmaze.com/api#rate-limiting), which means that they automatically block users if they receive too many requests from that user within a window of time. Many RESTful services also require that API keys be supplied with every request, allowing the website to block the API keys of abusers.

# %% [markdown]
# Out of respect for the host, who is often providing this service for free, we stagger our requests by inserting a time delay in our code. This can be done using `time.sleep()`, which will suspend execution of the script for the given number of seconds. We will add a half second delay (so that we make no more than 2 queries per second) between requests.

# %%
import time

episodes = []
for show_id in df_office["show.id"]:

    # get the episodes for the show from the REST API
    response = requests.get(f"http://api.tvmaze.com/shows/{show_id}/episodes")
    episodes.extend(response.json())

    # add a 0.5 second delay between each query
    time.sleep(0.5)

# Now we have a list of episodes in JSON format.
# We can convert this to a DataFrame of episodes using json_normalize.
pd.json_normalize(episodes)
# Out:
#           id                                                url
# 0      47640  https://www.tvmaze.com/episodes/47640/the-offi...  \
# 1      47641  https://www.tvmaze.com/episodes/47641/the-offi...
# 2      47642  https://www.tvmaze.com/episodes/47642/the-offi...
# 3      47643  https://www.tvmaze.com/episodes/47643/the-offi...
# 4      47644  https://www.tvmaze.com/episodes/47644/the-offi...
# ..       ...                                                ...
# 306  2217715  https://www.tvmaze.com/episodes/2217715/death-...
# 307  2217714  https://www.tvmaze.com/episodes/2217714/death-...
# 308  2217716  https://www.tvmaze.com/episodes/2217716/death-...
# 309  2217717  https://www.tvmaze.com/episodes/2217717/death-...
# 310  2306191  https://www.tvmaze.com/episodes/2306191/death-...
#
#               name  season  number     type     airdate airtime
# 0            Pilot       1       1  regular  2005-03-24   21:30  \
# 1    Diversity Day       1       2  regular  2005-03-29   21:30
# 2      Health Care       1       3  regular  2005-04-05   21:30
# 3     The Alliance       1       4  regular  2005-04-12   21:00
# 4       Basketball       1       5  regular  2005-04-19   21:00
# ..             ...     ...     ...      ...         ...     ...
# 306      Episode 6       1       6  regular  2019-11-21   23:45
# 307      Episode 7       1       7  regular  2019-11-28   23:45
# 308      Episode 8       1       8  regular  2019-12-05   23:45
# 309      Episode 9       1       9  regular  2019-12-12   23:45
# 310     Episode 10       1      10  regular  2019-12-19   23:45
#
#                       airstamp  runtime
# 0    2005-03-25T02:30:00+00:00       30  \
# 1    2005-03-30T02:30:00+00:00       30
# 2    2005-04-06T01:30:00+00:00       30
# 3    2005-04-13T01:00:00+00:00       30
# 4    2005-04-20T01:00:00+00:00       30
# ..                         ...      ...
# 306  2019-11-21T14:45:00+00:00       30
# 307  2019-11-28T14:45:00+00:00       30
# 308  2019-12-05T14:45:00+00:00       30
# 309  2019-12-12T14:45:00+00:00       30
# 310  2019-12-19T14:45:00+00:00       30
#
#                                                summary  rating.average
# 0    <p>A documentary crew arrives at Dundler Miffl...             7.6  \
# 1    <p>Corporate sends in a consultant after Micha...             8.1
# 2    <p>Dwight ends up in charge of picking a new h...             8.0
# 3    <p>With Dwight worried about downsizing, Jim a...             8.1
# 4    <p>Michael challenges the warehouse staff to a...             8.5
# ..                                                 ...             ...
# 306                                               None             NaN
# 307                                               None             NaN
# 308                                               None             NaN
# 309                                               None             NaN
# 310                                               None             NaN
#
#                                           image.medium
# 0    https://static.tvmaze.com/uploads/images/mediu...  \
# 1    https://static.tvmaze.com/uploads/images/mediu...
# 2    https://static.tvmaze.com/uploads/images/mediu...
# 3    https://static.tvmaze.com/uploads/images/mediu...
# 4    https://static.tvmaze.com/uploads/images/mediu...
# ..                                                 ...
# 306  https://static.tvmaze.com/uploads/images/mediu...
# 307  https://static.tvmaze.com/uploads/images/mediu...
# 308  https://static.tvmaze.com/uploads/images/mediu...
# 309  https://static.tvmaze.com/uploads/images/mediu...
# 310  https://static.tvmaze.com/uploads/images/mediu...
#
#                                         image.original
# 0    https://static.tvmaze.com/uploads/images/origi...  \
# 1    https://static.tvmaze.com/uploads/images/origi...
# 2    https://static.tvmaze.com/uploads/images/origi...
# 3    https://static.tvmaze.com/uploads/images/origi...
# 4    https://static.tvmaze.com/uploads/images/origi...
# ..                                                 ...
# 306  https://static.tvmaze.com/uploads/images/origi...
# 307  https://static.tvmaze.com/uploads/images/origi...
# 308  https://static.tvmaze.com/uploads/images/origi...
# 309  https://static.tvmaze.com/uploads/images/origi...
# 310  https://static.tvmaze.com/uploads/images/origi...
#
#                             _links.self.href
# 0      https://api.tvmaze.com/episodes/47640  \
# 1      https://api.tvmaze.com/episodes/47641
# 2      https://api.tvmaze.com/episodes/47642
# 3      https://api.tvmaze.com/episodes/47643
# 4      https://api.tvmaze.com/episodes/47644
# ..                                       ...
# 306  https://api.tvmaze.com/episodes/2217715
# 307  https://api.tvmaze.com/episodes/2217714
# 308  https://api.tvmaze.com/episodes/2217716
# 309  https://api.tvmaze.com/episodes/2217717
# 310  https://api.tvmaze.com/episodes/2306191
#
#                        _links.show.href  image
# 0      https://api.tvmaze.com/shows/526    NaN
# 1      https://api.tvmaze.com/shows/526    NaN
# 2      https://api.tvmaze.com/shows/526    NaN
# 3      https://api.tvmaze.com/shows/526    NaN
# 4      https://api.tvmaze.com/shows/526    NaN
# ..                                  ...    ...
# 306  https://api.tvmaze.com/shows/59025    NaN
# 307  https://api.tvmaze.com/shows/59025    NaN
# 308  https://api.tvmaze.com/shows/59025    NaN
# 309  https://api.tvmaze.com/shows/59025    NaN
# 310  https://api.tvmaze.com/shows/59025    NaN
#
# [311 rows x 17 columns]
